# %%
import requests, time, random
from bs4 import BeautifulSoup
from selenium import webdriver
import pandas as pd
import time

# %%
browser = webdriver.Chrome('C:/Users/Admin/Desktop/LinkedIn-Profile-Scrapper-in-Python-master/chromedriver.exe')
browser.get('https://www.linkedin.com/uas/login')
file = open('config.txt')
lines = file.readlines()
username = lines[0]
password = lines[1]


elementID = browser.find_element_by_id('username')
elementID.send_keys(username)

elementID = browser.find_element_by_id('password')
elementID.send_keys(password)

elementID.submit()

# %%
browser = webdriver.Chrome('C:/Users/Admin/Desktop/LinkedIn-Profile-Scrapper-in-Python-master/chromedriver.exe')
browser.get('https://www.linkedin.com/uas/login')
file = open('config.txt')
lines = file.readlines()
username = lines[0]
password = lines[1]


elementID = browser.find_element_by_id('username')
elementID.send_keys(username)

elementID = browser.find_element_by_id('password')
elementID.send_keys(password)

elementID.submit()

# %%
link = 'https://www.linkedin.com/in/charan-nadendla-858a17120/'
browser.get(link)

# %%
SCROLL_PAUSE_TIME = 5

# Get scroll height
last_height = browser.execute_script("return document.body.scrollHeight")

for i in range(3):
    # Scroll down to bottom
    browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = browser.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

# %%
src = browser.page_source
soup = BeautifulSoup(src, 'lxml')
soup
# Out:
# <html class="artdeco windows" lang="en"><head>
# <script async="" src="https://platform.linkedin.com/js/analytics.js"></script><script type="application/javascript">!function(i,n){void 0!==i.addEventListener&&void 0!==i.hidden&&(n.liVisibilityChangeListener=function(){i.hidden&&(n.liHasWindowHidden=!0)},i.addEventListener("visibilitychange",n.liVisibilityChangeListener))}(document,window);</script>
# <title>(13) Charan Nadendla | LinkedIn</title>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="" name="description"/>
# <meta content="notranslate" name="google"/>
# <meta content="false" name="is-http2"/>
# <meta content="voyager-web" name="service"/>
# <meta content="#0077B5" name="theme-color"/>
# <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0" name="viewport"/>
# <link href="/voyager/manifest.json" rel="manifest"/>
# <link href="https://static-exp1.licdn.com/sc/h/br/10gtx1wtbbp3gjnd4ue0pa1md" rel="stylesheet"/>
# <meta content="%7B%22modulePrefix%22%3A%22extended%22%2C%22environment%22%3A%22production%22%2C%22ember-a11y-testing%22%3A%7B%22componentOptions%22%3A%7B%22turnAuditOff%22%3Atrue%2C%22excludeAxeCore%22%3Atrue%2C%22axeOptions%22%3A%7B%22iframes%22%3Afalse%2C%22reporter%22%3A%22v2%22%2C%22resultTypes%22%3A%5B%22violations%22%5D%2C%22rules%22%3A%7B%22duplicate-id%22%3A%7B%22enabled%22%3Afalse%7D%2C%22duplicate-id-active%22%3A%7B%22enabled%22%3Afalse%7D%2C%22duplicate-id-aria%22%3A%7B%22enabled%22%3Afalse%7D%7D%7D%7D%7D%2C%22client-sensor-web%22%3A%7B%22mpName%22%3A%22voyager-web%22%7D%2C%22ember-media-player%22%3A%7B%22lazyLoad%22%3Atrue%7D%2C%22ember-pem%22%3A%7B%22trackingTerminationLixKey%22%3A%22pem.degradation-tracking-kill-switch.voyager-web%22%7D%2C%22rootURL%22%3A%22%2F%22%2C%22routerRootURL%22%3A%22%2F%22%2C%22deviceFormFactor%22%3A%22DESKTOP%22%2C%22emberStrictResolver%22%3Afalse%2C%22locationType%22%3A%22voyager-location%22%2C%22namespace%22%3A%22voyager%2Fapi%22%2C%22EmberENV%22%3A%7B%22FEATURES%22%3A%7B%7D%2C%22_APPLICATION_TEMPLATE_WRAPPER%22%3Afalse%2C%22_DEFAULT_ASYNC_OBSERVERS%22%3Atrue%2C%22_JQUERY_INTEGRATION%22%3Afalse%2C%22_TEMPLATE_ONLY_GLIMMER_COMPONENTS%22%3Atrue%7D%2C%22APP%22%3A%7B%22locale%22%3A%22en_US%22%2C%22rumConfig%22%3A%7B%22pageKeyPrefix%22%3A%22d_%22%2C%22beacon-service%22%3A%22tracking%22%2C%22beacon-url%22%3A%22%2Fli%2Ftrack%22%2C%22event-name%22%3A%22RealUserMonitoringEvent%22%2C%22enable-cdn-tracking%22%3Atrue%2C%22enable-pop-tracking%22%3Atrue%2C%22user-timing-mark-enabled%22%3Atrue%7D%2C%22name%22%3A%22extended%22%2C%22version%22%3A%22voyager-web_1.6.5520%2Bbc0f9c0d%22%7D%2C%22contentSecurityPolicy%22%3A%7B%22default-src%22%3A%22%5C%22none%5C%22%20*.licdn.com%20*.licdn-ei.com%22%2C%22script-src%22%3A%22%5C%22self%5C%22%20%5C%22unsafe-inline%5C%22%20*.licdn.com%20*.licdn-ei.com%20*.linkedin.com%22%2C%22font-src%22%3A%22%5C%22self%5C%22%20*.licdn.com%20*.licdn-ei.com%20*.slidesharecdn.com%22%2C%22frame-src%22%3A%22*.youtube.com%20*.slideshare.net%22%2C%22connect-src%22%3A%22%5C%22self%5C%22%20localhost%3A*%20*.linkedin.com%22%2C%22img-src%22%3A%22%5C%22self%5C%22%20*.slidesharecdn.com%20*.licdn.com%20*.licdn-ei.com%20spdy.linkedin.com%20spdy.linkedin-ei.com%20*.youtube.com%22%2C%22style-src%22%3A%22%5C%22self%5C%22%20%5C%22unsafe-inline%5C%22%20*.licdn.com%20*.licdn-ei.com%22%2C%22media-src%22%3A%22%5C%22self%5C%22%20*.slidesharecdn.com%20*.licdn.com%20*.licdn-ei.com%22%7D%2C%22tracking%22%3A%7B%22validation%22%3A%7B%22throwOnError%22%3Atrue%7D%2C%22appId%22%3A%22com.linkedin.flagship3.d_web%22%2C%22pageKeyPrefix%22%3A%22d_%22%2C%22pveTrackingInfo%22%3A%7B%22osName%22%3A%22phone_web%22%7D%2C%22impression%22%3A%7B%22timeThreshold%22%3A300%2C%22percentageThreshold%22%3A50%2C%22viewportOffset%22%3A%7B%22top%22%3A52%2C%22bottom%22%3A0%2C%22left%22%3A0%2C%22right%22%3A0%7D%7D%2C%22comScore%22%3A%7B%22enabled%22%3Atrue%7D%7D%2C%22skeleton%22%3A%7B%22data%22%3A%7B%7D%2C%22template%22%3A%22.%2Fskeleton%2Floader.hbs%22%7D%2C%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets%2Fimg%2Fchina-icp-filing.png%22%2C%22assets%2Fimg%2Forganization%2Fdesktop-screenshot.png%22%2C%22assets%2Fimg%2Forganization%2Fmobile-screenshot.png%22%2C%22assets%2Fimg%2Fprofile%2Fdesktop-photo-upload-add-photo.png%22%2C%22assets%2Fhighcharts%2Fhighcharts.js%22%2C%22assets%2Fhighcharts%2Fmodules%2Fmap.js%22%2C%22assets%2Fhighcharts%2Fmodules%2Faccessibility.js%22%2C%22assets%2FcloudSDK%2FOneDriveSDK.js%22%2C%22assets%2FcloudSDK%2FDropboxSDK.js%22%2C%22assets%2Fproj4.js%22%2C%22assets%2Fspectroscopy-worker.js%22%2C%22assets%2Fworld.js%22%2C%22assets%2Fsrc%2Fchartbeat.js%22%2C%22assets%2Fpowerpoint-coach%2FCoachPackage.js%22%2C%22assets%2Ffavicon.ico%22%2C%22assets%2Ffavicon-notification.ico%22%2C%22assets%2Fimg%2Fhiring%2Fonboarding%2Fnew-poster-desktop-modal-image%402x.png%22%2C%22assets%2Fimg%2Fpremium%2Fproducts%2Fslides%2Fjob_seeker_featured_applicant_650x468_v1.png%22%2C%22assets%2Fimg%2Fpremium%2Fproducts%2Fs ...
# <!-- EMBER_CLI_FASTBOOT_TITLE --><!-- EMBER_CLI_FASTBOOT_HEAD -->
# <link href="https://static-exp1.licdn.com/sc/h/1bt1uwq5akv756knzdj4l6cdc" id="favicon-ico" rel="shortcut icon"/>
# <link href="https://static-exp1.licdn.com/sc/h/2if24wp7oqlodqdlgei1n1520" rel="apple-touch-icon"/>
# <link href="https://static-exp1.licdn.com/sc/h/eahiplrwoq61f4uan012ia17i" rel="apple-touch-icon-precomposed"/>
# <link href="https://static-exp1.licdn.com/sc/h/2if24wp7oqlodqdlgei1n1520" rel="apple-touch-icon-precomposed" sizes="57x57"/>
# <link href="https://static-exp1.licdn.com/sc/h/eahiplrwoq61f4uan012ia17i" rel="apple-touch-icon-precomposed" sizes="144x144"/>
# <link href="https://static-exp1.licdn.com/sc/h/br/9ta9ebo3hkuajtestycpxwpj8" rel="stylesheet"/>
# <link href="https://static-exp1.licdn.com/sc/h/br/eotgwz5wle6ksatih2va9w71j" rel="stylesheet"/>
# <meta content='{"assets/img/china-icp-filing.png":"https://static-exp1.licdn.com/sc/h/cbn91jpp9vuid7olk3y6qmbpj","assets/img/organization/desktop-screenshot.png":"https://static-exp1.licdn.com/sc/h/ev2ewp91pnvtl0gcyt4xht0b5","assets/img/organization/mobile-screenshot.png":"https://static-exp1.licdn.com/sc/h/3v3wzhnr3kapuzwpk1zt6r1jt","assets/img/profile/desktop-photo-upload-add-photo.png":"https://static-exp1.licdn.com/sc/h/c5ybm82ti04zuasz2a0ubx7bu","assets/highcharts/highcharts.js":"https://static-exp1.licdn.com/sc/h/br/3gz6uyw7tnqpbhl8fe277swbp","assets/highcharts/modules/map.js":"https://static-exp1.licdn.com/sc/h/br/emp4qn95u3dapai0gby9efjak","assets/highcharts/modules/accessibility.js":"https://static-exp1.licdn.com/sc/h/br/7j8d68spn8mp00zhl3vmqcka3","assets/cloudSDK/OneDriveSDK.js":"https://static-exp1.licdn.com/sc/h/br/45bhd02gokyndidefhx1ptdvt","assets/cloudSDK/DropboxSDK.js":"https://static-exp1.licdn.com/sc/h/br/874gdyhk2zgt1hdrm1rvxih7g","assets/proj4.js":"https://static-exp1.licdn.com/sc/h/br/a52rm6mz15bfb6b25ex2fl8mr","assets/spectroscopy-worker.js":"https://static-exp1.licdn.com/sc/h/br/69miyr75u4gp5utz4wgun9dya","assets/world.js":"https://static-exp1.licdn.com/sc/h/br/2s51vhg4vrr7k24sjaop3o56b","assets/src/chartbeat.js":"https://static-exp1.licdn.com/sc/h/br/dudi1lzgkt9xq5lg3f0j1c66p","assets/powerpoint-coach/CoachPackage.js":"https://static-exp1.licdn.com/sc/h/br/5bgqmlfah2j3phsfvchqusuiv","assets/favicon.ico":"https://static-exp1.licdn.com/sc/h/al2o9zrvru7aqj8e1x2rzsrca","assets/favicon-notification.ico":"https://static-exp1.licdn.com/sc/h/1bt1uwq5akv756knzdj4l6cdc","assets/img/hiring/onboarding/new-poster-desktop-modal-image@2x.png":"https://static-exp1.licdn.com/sc/h/ewdoimk3v63x2o3nsi6rharus","assets/img/premium/products/slides/job_seeker_featured_applicant_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/6gl4ufmcgffyhuu4lti3us9mr","assets/img/premium/products/slides/job_seeker_inmail_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/194ufzr1ibusivbechyc149ox","assets/img/premium/products/slides/job_seeker_job_insights_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/b9qvh5p1l68rq61pvb6f3dpin","assets/img/premium/products/slides/job_seeker_professional_learning_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/75zb38b8070xlgfvx5ta8ksg5","assets/img/premium/products/slides/job_seeker_professional_wvmp_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/85swj4u5h27rp1gv0gtu5568","assets/img/premium/products/slides/job_seeker_resume_builder_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/b7ybzpxcq6ma06b6jrssqcu5v","assets/img/premium/products/slides/job_seeker_interview_prep_648x468_v1.png":"https://static-exp1.licdn.com/sc/h/dxj16dv0q0dlpveh17ftnocke","assets/img/premium/products/slides/learning_certificates_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/583fidw259ymymoncldari2wo","assets/img/premium/products/slides/learning_experts_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/c6188n1g55fuxv51sx0ldfc9a","assets/img/premium/products/slides/learning_practice_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/cu8z4dheitoo3j58t2hzsnriu","assets/img/premium/products/slides/learning_recommendations_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/czbqzystj2cf6vcdikti5qpxl","assets/img/premium/products/slides/learning_time_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/f13ctg6tjp7cnaf9orkc9m1lz","assets/img/premium/products/slides/learning_topics_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/eazvcix8vc8qb5vead285sqcq","assets/img/premium/products/slides/learning_unlimited_access_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/ctrkfni1bhv3uyokx49xwtr3o","assets/img/premium/products/slides/professional_browse_profiles_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/1ehgbakjab9ljkoavygzhtoa3","assets/img/premium/products/slides/professional_company_research_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/2wxmom0vvkzhp4tfdd0cpa4ib","assets/img/premium/products/slides ...
# <meta content="en_US" name="i18nDefaultLocale"/>
# <meta content="en_US" name="i18nLocale"/>
# <meta content="https://static-exp1.licdn.com/sc/h/br/aanly5o5blk5l977rvjksluux" name="i18nIntlPolyfillUrl"/>
# <meta content="ca" name="requestIpCountryCode"/>
# <meta content="urn:li:page:bpr;lItQhFISTgCCWKD1UT/8wQ==" name="bprPageInstance"/>
# <meta content='{"applicationUrn": "urn:li:application:(voyager-web,voyager-web)", "version": "1.6.5520", "trackingId": [-71, -100, -64, -107, -115, 33, 65, -83, -99, -68, -77, -3, 100, -111, 39, -56]}' name="applicationInstance"/>
# <meta content="OsvNqKFETBKnaesdgCe7nw==" name="clientPageInstanceId"/>
# <meta content="voyager-web" name="service"/>
# <meta content="i001" name="serviceInstance"/>
# <meta content="1.6.5520" name="serviceVersion"/>
# <meta content="c8fRusjOEBbAsARUWCsAAA==" name="treeID"/>
# <meta content="none" name="liamOrLisa"/>
# <meta content='{"lix":{"voyager.client.engage-flash-dynamic-text-size":{"treatment":"control","trackingInfo":{"segmentIndex":1,"treatmentIndex":0,"experimentId":3088028,"urn":"urn:li:member:801379952"},"testKey":"voyager.client.engage-flash-dynamic-text-size"},"voyager.web.feed.text-view-model-migration-sponsored":{"treatment":"control","trackingInfo":null,"testKey":"voyager.web.feed.text-view-model-migration-sponsored"},"voyager.web.nav.job-posting-jobs-led-entry-points":{"treatment":"control","trackingInfo":null,"testKey":"voyager.web.nav.job-posting-jobs-led-entry-points"},"voyager.web.news-editor-to-news-copy-change":{"treatment":"control","trackingInfo":{"segmentIndex":1,"treatmentIndex":0,"experimentId":3093944,"urn":"urn:li:member:801379952"},"testKey":"voyager.web.news-editor-to-news-copy-change"},"voyager.iac.web.import-communities":{"treatment":"control","trackingInfo":null,"testKey":"voyager.iac.web.import-communities"},"voyager.web.mynetwork-heathrow-contextual-pymk":{"treatment":"enabled","trackingInfo":{"segmentIndex":1,"treatmentIndex":1,"experimentId":3070058,"urn":"urn:li:member:801379952"},"testKey":"voyager.web.mynetwork-heathrow-contextual-pymk"},"voyager.web.infraux-new-global-nav-hide-work-donut":{"treatment":"control","trackingInfo":{"segmentIndex":2,"treatmentIndex":0,"experimentId":3100336,"urn":"urn:li:member:801379952"},"testKey":"voyager.web.infraux-new-global-nav-hide-work-donut"},"voyager.web.premium.sales-nav-for-professionals-nav-identity-upsell":{"treatment":"control","trackingInfo":null,"testKey":"voyager.web.premium.sales-nav-for-professionals-nav-identity-upsell"},"voyager.web.jobs-home-responsive-jobs-flavor":{"treatment":"control","trackingInfo":null,"testKey":"voyager.web.jobs-home-responsive-jobs-flavor"},"voyager.web.groups-promotions-experience":{"treatment":"control","trackingInfo":{"segmentIndex":1,"treatmentIndex":0,"experimentId":2934529,"urn":"urn:li:member:801379952"},"testKey":"voyager.web.groups-promotions-experience"},"voyager.web.engage-use-update-token-expiry":{"treatment":"control","trackingInfo":null,"testKey":"voyager.web.engage-use-update-token-expiry"},"voyager.web.organization-admin-post-free-job":{"treatment":"control","trackingInfo":{"segmentIndex":6,"treatmentIndex":0,"experimentId":3089272,"urn":"urn:li:member:801379952"},"testKey":"voyager.web.organization-admin-post-free-job"},"voyager.web.professional-events-enable-attendee-education-module":{"treatment":"control","trackingInfo":null,"testKey":"voyager.web.professional-events-enable-attendee-education-module"},"voyager.web.news-module-covid19-special-edition":{"treatment":"enabled","trackingInfo":null,"testKey":"voyager.web.news-module-covid19-special-edition"},"voyager.ignite.web.slideshare-migration":{"treatment":"control","trackingInfo":null,"testKey":"voyager.ignite.web.slideshare-migration"},"voyager.web.participate-use-feed-entry-share-box-in-event-feed":{"treatment":"control","trackingInfo":{"segmentIndex":1,"treatmentIndex":0,"experimentId":3096344,"urn":"urn:li:member:801379952"},"testKey":"voyager.web.participate-use-feed-entry-share-box-in-event-feed"},"voyager.web.infra-ux-new-global-nav":{"treatment":"control","trackingInfo":{"segmentIndex":3,"treatmentIndex":0,"experimentId":3101805,"urn":"urn:li:member:801379952"},"testKey":"voyager.web.infra-ux-new-global-nav"},"voyager.web.profile-deferred-component-match-data":{"treatment":"control","trackingInfo":{"segmentIndex":1,"treatmentIndex":0,"experimentId":3094563,"urn":"urn:li:member:801379952"},"testKey":"voyager.web.profile-deferred-component-match-data"},"voyager.mynetwork.web.segments-businesscards":{"treatment":"enabled","trackingInfo":null,"testKey":"voyager.mynetwork.web.segments-businesscards"},"voyager.web.messaging-fetch-data-refactor":{"treatment":"control","trackingInfo":null,"testKey":"voyager.web.messaging-fetch-data-refactor"},"voyager.nav.web.lang-country-sales-solutions-link":{"treatment":"control","trackingInfo":null,"testKey":"voyag ...
# <meta content="false" name="isGuest"/>
# <meta data-mode="BIGPIPE" name="renderingMode"/>
# <!--%SSR_HEAD*[]%-->
# <meta content="12000" name="bigpipeResponseTimeout"/>
# <meta content="false" name="bigpipeJetRethrowError"/>
# <meta content='["static\\.licdn\\.com","media\\.licdn\\.com","voyager/api/typeahead/hits"]' name="bigpipeBlacklistUrls"/>
# <meta content="false" name="isQueryTunnelRequestSupported"/>
# <script src="https://static-exp1.licdn.com/sc/h/br/a9r8138k1irfu2dd3nc8lsbix"></script>
# <meta content="%7B%7D" name="abi/config/environment"/>
# <meta content="%7B%7D" name="article-reader/config/environment"/>
# <meta content="%7B%7D" name="career-services/config/environment"/>
# <meta content="%7B%7D" name="colleagues/config/environment"/>
# <meta content="%7B%7D" name="company-creation/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="events/config/environment"/>
# <meta content="%7B%7D" name="feed/config/environment"/>
# <meta content="%7B%7D" name="feed-detail/config/environment"/>
# <meta content="%7B%7D" name="feed-shared/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="groups/config/environment"/>
# <meta content="%7B%7D" name="hiring/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="inshare/config/environment"/>
# <meta content="%7B%7D" name="interview-prep/config/environment"/>
# <meta content="%7B%7D" name="jobs/config/environment"/>
# <meta content="%7B%22googleAnalytics%22%3A%7B%22trackingId%22%3A%22UA-62256447-1%22%7D%7D" name="jobs-search/config/environment"/>
# <meta content="%7B%7D" name="lead-capture/config/environment"/>
# <meta content="%7B%7D" name="me/config/environment"/>
# <meta content="%7B%7D" name="me-ca/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="messaging/config/environment"/>
# <meta content="%7B%7D" name="msg-conversation-ui/config/environment"/>
# <meta content="%7B%7D" name="msg-mentions/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="msg-overlay/config/environment"/>
# <meta content="%7B%7D" name="msg-referrals/config/environment"/>
# <meta content="%7B%7D" name="msg-rich-media/config/environment"/>
# <meta content="%7B%7D" name="msg-shared-modals/config/environment"/>
# <meta content="%7B%7D" name="msg-spinmail/config/environment"/>
# <meta content="%7B%7D" name="msg-ui-base/config/environment"/>
# <meta content="%7B%7D" name="mynetwork/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="news/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="notifications/config/environment"/>
# <meta content="%7B%7D" name="onboarding/config/environment"/>
# <meta content="%7B%7D" name="opportunities/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="organization/config/environment"/>
# <meta content="%7B%7D" name="organization-about/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="organization-admin/config/environment"/>
# <meta content="%7B%7D" name="organization-content-suggestions/config/environment"/>
# <meta content="%7B%7D" name="organization-employee-experience/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="organization-events/config/environment"/>
# <meta content="%7B%7D" name="organization-insights/config/environment"/>
# <meta content="%7B%7D" name="organization-jobs/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="organization-life/config/environment"/>
# <meta content="%7B%7D" name="organization-people/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="organization-videos/config/environment"/>
# <meta content="%7B%7D" name="participate-text-editor/config/environment"/>
# <meta content="%7B%7D" name="premium/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="products/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="profile/config/environment"/>
# <meta content="%7B%22environment%22%3A%22production%22%2C%22ember-a11y-testing%22%3A%7B%22componentOptions%22%3A%7B%22turnAuditOff%22%3Atrue%2C%22excludeAxeCore%22%3Atrue%2C%22axeOptions%22%3A%7B%22iframes%22%3Afalse%2C%22reporter%22%3A%22v2%22%2C%22resultTypes%22%3A%5B%22violations%22%5D%2C%22rules%22%3A%7B%22duplicate-id%22%3A%7B%22enabled%22%3Afalse%7D%2C%22duplicate-id-active%22%3A%7B%22enabled%22%3Afalse%7D%2C%22duplicate-id-aria%22%3A%7B%22enabled%22%3Afalse%7D%7D%7D%7D%7D%7D" name="profile-edit/config/environment"/>
# <meta content="%7B%7D" name="profile-ge/config/environment"/>
# <meta content="%7B%7D" name="profile-opportunities/config/environment"/>
# <meta content="%7B%7D" name="profile-search-analytics/config/environment"/>
# <meta content="%7B%7D" name="profile-skill-assessments/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="profile-subroutes/config/environment"/>
# <meta content="%7B%7D" name="profile-tetris/config/environment"/>
# <meta content="%7B%7D" name="publishing/config/environment"/>
# <meta content="%7B%7D" name="publishing-entity/config/environment"/>
# <meta content="%7B%7D" name="resume-builder/config/environment"/>
# <meta content="%7B%7D" name="salary/config/environment"/>
# <meta content="%7B%7D" name="search/config/environment"/>
# <meta content="%7B%7D" name="service-marketplace/config/environment"/>
# <meta content="%7B%7D" name="sharing-v2/config/environment"/>
# <meta content="%7B%7D" name="slideshare-migration/config/environment"/>
# <meta content="%7B%7D" name="tenor-gif/config/environment"/>
# <meta content="%7B%7D" name="unemployment/config/environment"/>
# <meta content="%7B%7D" name="video-engine/config/environment"/>
# <meta content="%7B%7D" name="workflow/config/environment"/>
# <meta content="https://static-exp1.licdn.com/sc/h/9dsxtvn2eeufiq8s02fxwykme" id="artdeco-icons/static/images/icons.svg" name="asset-url"/>
# <meta content='{"bundles":{"abi":{"assets":[{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/1uv3fxhcomjdyjelnylq5nq6l"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/50saacujiio3i69qg3vaxjtqt"},{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/14weoa1hqh5dzbvmz97fv4pfe"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/7vumvsludsfsoy0xhtqvclia1"}],"dependencies":[]},"article-reader":{"assets":[{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/9bkz7io7zb804t16wretn53p5"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/46z8mh44irwsp4wsnukme7i5s"},{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/arb6muts4hv5qzpmolp244vlm"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/9cma8lucylh69la4h2fl1e53y"}],"dependencies":["feed-shared"]},"career-services":{"assets":[{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/bwmocoxyey2y5gyuw8wsil879"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/xnzyj7hnx8wxihvfppel7kz4"},{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/5g0fasr01tcj9enszvh42cb3b"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/rk9voirtwn21tikzso6kvvnh"}],"dependencies":[]},"colleagues":{"assets":[{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/b4rtz9eh99r9omyeniv4ro21h"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/6ap9b689uafoejsrhb4w2jcip"},{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/7r85sch831o5svd9sj2ten1wa"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/dvmlfp8mn2xyci667p1kzhdoa"}],"dependencies":[]},"company-creation":{"assets":[{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/9jixrz6rje6avr7pvvtfiqhl9"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/7nl41j5vpupf4di4aysbu763r"},{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/464y818ef77vnx2i0s2lxjdnx"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/51tjp4kbuytgkrpdryeyz9pdd"}],"dependencies":[]},"content-analytics":{"assets":[],"dependencies":null},"events":{"assets":[{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/c2pwl4bip5ofe2hxq1ppra32w"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/842p10189zpk21m8lkmrwunl6"},{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/842vbyqs622uifqjug3ujz05e"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/7snn9oro3zzb46agmy67gw6t9"},{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/632atuxe9daxajnuqozpv5td1"}],"dependencies":["feed-shared"]},"feed-detail":{"assets":[{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/8ix4jsg23460ttwand409ahgi"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/e7f52rqyt98e4p6k7dxcneewi"},{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/c78dk4gz61rwvyck1q2h1v9mg"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/2oan33dtjl5iyc3kzzts8gkty"},{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/632atuxe9daxajnuqozpv5td1"}],"dependencies":["feed","feed-shared"]},"feed-shared":{"assets":[{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/bkhneyvyop4uyttw387uxvdv1"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/ehhs5rkoeug8zh4ya3gwvx711"},{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/5mah8dy3kb5wovazpe009y8el"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/34wnqs8cm8czip5xl5uww4a9n"}],"dependencies":null},"feed":{"assets":[{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/deicavrnf9ww92qzxoyk2dp4j"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/4rvwkrdmsmqgjtog3fwl4qrtg"},{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/au0eb7l32yqd824gh1vlg9o9u"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/96qv5nkt2p9dqyopmamg1uft8"},{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/632atuxe9daxajnuqozpv5td1"}],"dependencies":["feed-shared"]},"groups":{"assets":[{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/3vetgt9erkqj04 ...
# <link href="https://static-exp1.licdn.com/sc/h/br/61aie1arqx3119nt8jbfikgvc" rel="stylesheet"/><link href="https://static-exp1.licdn.com/sc/h/br/mcvaasvoucj4az6imnmmbrbb" rel="stylesheet"/><link href="https://static-exp1.licdn.com/sc/h/br/ehhs5rkoeug8zh4ya3gwvx711" rel="stylesheet"/><link href="https://static-exp1.licdn.com/sc/h/br/34wnqs8cm8czip5xl5uww4a9n" rel="stylesheet"/>
# <link class="lazy-css" href="https://static-exp1.licdn.com/sc/h/br/51eoh0emdptbbi8aluw5lvmv3" rel="stylesheet"/>
# <style>%INLINE_CRITICAL_STYLES%</style>
# <meta content="app-id=288429040, affiliate-data=ct=campaign_vw_smart_app_banner&amp;pt=10746, app-argument=voyager://in/charan-nadendla-858a17120/?trk=vw_smart_app_banner" name="apple-itunes-app"/>
# <script src="https://static-exp1.licdn.com/sc/h/br/ezee7ogieiw4490sxl3cr26ob"></script><script src="https://static-exp1.licdn.com/sc/h/br/61ovkyx0mhxcr2h4dtwlcd4f2"></script><link href="https://static-exp1.licdn.com/sc/h/br/cywv19vidvpd2vhjyddhuwj60" rel="stylesheet"/><script src="https://static-exp1.licdn.com/sc/h/br/5k5zzxq30xgmxrqmci9ox9pfp"></script><link href="https://static-exp1.licdn.com/sc/h/br/30ug87yte4r7l15qu3ee712jy" rel="stylesheet"/><script src="https://static-exp1.licdn.com/sc/h/br/1hf66fjqam0s35tztfh5deda9"></script><link href="https://static-exp1.licdn.com/sc/h/br/38qo06qmam21cup26dwlch5ae" rel="stylesheet"/><script src="https://static-exp1.licdn.com/sc/h/br/coa7f3ykpl4n59lxspa6n42h5"></script><script src="https://static-exp1.licdn.com/sc/h/br/7fbz53o8lfd5sbmolpqp1p7v"></script><link href="https://static-exp1.licdn.com/sc/h/br/7qshs74coqub3x1n0q18oxicc" rel="stylesheet"/><script src="https://static-exp1.licdn.com/sc/h/br/e0f4pnnqpzajo43borp6q30h6"></script><link href="https://static-exp1.licdn.com/sc/h/br/dwidosgxj6iugdot4ko86c32h" rel="stylesheet"/><script src="https://static-exp1.licdn.com/sc/h/br/a9wjf3e9u4tsg0a28j39vawbq"></script><script src="https://static-exp1.licdn.com/sc/h/br/846h3c391n72cebyeqsxd23ug"></script><link href="https://static-exp1.licdn.com/sc/h/br/1o7lfob3dplygo5mt0elf1kwy" rel="stylesheet"/><script src="https://static-exp1.licdn.com/sc/h/br/4b7snm2ry7qsea45v0zlspbc9"></script><link href="https://static-exp1.licdn.com/sc/h/br/4v24cmoh8ww98tn1afz72c22q" rel="stylesheet"/><script src="https://static-exp1.licdn.com/sc/h/br/hhs7g6x31dpzd7oudqn4om50"></script><link href="https://static-exp1.licdn.com/sc/h/br/divi9fu3q6kjbqi5vayfl8dsm" rel="stylesheet"/></head>
# <body class="render-mode-BIGPIPE nav-v2 theme theme--classic ember-application boot-complete icons-loaded" data-t-link-to-event-attached="true" dir="ltr">
# <!-- HUED-11420 -->
# <div id="artdeco-toasts__wormhole"> <section class="artdeco-toasts" id="artdeco-toasts">
# <header class="artdeco-toasts__header">
# <h2 class="artdeco-toasts__title">
#         0 notifications total
#       </h2>
# </header>
# <!-- -->
# <ul aria-atomic="true" aria-live="assertive" class="artdeco-toasts_toasts">
# <!-- --> </ul>
# </section>
# </div>
# <div id="a11y-menu"> <div class="a11y-menu-container ember-view" id="ember15"><button class="mr4 artdeco-button artdeco-button--muted artdeco-button--2 artdeco-button--secondary ember-view" id="ember16"><!-- -->
# <span class="artdeco-button__text">
#     Skip to search
# </span></button>
# <a class="artdeco-button artdeco-button--muted artdeco-button--secondary" data-ember-action="" data-ember-action-17="17" href="#skip-link">
#   Skip to main content
# </a>
# <button class="a11y-menu__close artdeco-button artdeco-button--circle artdeco-button--muted artdeco-button--2 artdeco-button--tertiary ember-view" id="ember18"> <li-icon aria-hidden="true" class="artdeco-button__icon" type="cancel-icon"><svg data-supported-dps="24x24" fill="currentColor" focusable="false" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M20 5.32L13.32 12 20 18.68 18.66 20 12 13.33 5.34 20 4 18.68 10.68 12 4 5.32 5.32 4 12 10.69 18.68 4z"></path>
# </svg></li-icon>
# <span class="artdeco-button__text">
#     Close jump menu
# </span></button>
# </div>
# </div><header class="extended-nav nav-main-container global-alert-offset-top is-loading-nav" data-test-main-nav="true" id="extended-nav" role="banner" style="display: block;" tabindex="-1"><div class="nav-main__content full-height display-flex align-items-center"><div class="nav-main__inbug-container"><div class="nav-item--inbug" id="inbug-nav-item" lang="en"><a class="nav-item__link js-nav-item-link" data-alias="" data-control-name="" data-link-to="feed" data-resource="feed/badge" href="/feed/"><span class="nav-item__icon nav-item__icon--inbug" lang="en" role="presentation"><li-icon aria-hidden="true" color="brand" size="34dp" type="linkedin-bug"><svg focusable="false" preserveaspectratio="xMinYMin meet" xmlns="http://www.w3.org/2000/svg"><g class="scaling-icon" style="fill-opacity: 1"><defs></defs><g class="bug-14dp" fill="none" fill-rule="evenodd" stroke="none" stroke-width="1"><g class="dp-1"><path class="bug-text-color" d="M14,1.25 L14,12.75 C14,13.44 13.44,14 12.75,14 L1.25,14 C0.56,14 0,13.44 0,12.75 L0,1.25 C0,0.56 0.56,0 1.25,0 L12.75,0 C13.44,0 14,0.56 14,1.25" fill="#FFFFFF"></path><path class="background" d="M14,1.25 L14,12.75 C14,13.44 13.44,14 12.75,14 L1.25,14 C0.56,14 0,13.44 0,12.75 L0,1.25 C0,0.56 0.56,0 1.25,0 L12.75,0 C13.44,0 14,0.56 14,1.25 Z M5,5 L6.85,5 L6.85,6.016 L6.893,6.016 C7.259,5.541 8.018,4.938 9.25,4.938 C11.125,4.938 12,5.808 12,8 L12,12 L10,12 L10,8.75 C10,7.313 9.672,6.875 8.632,6.875 C7.5,6.875 7,7.75 7,9 L7,12 L5,12 L5,5 Z M2,12 L4,12 L4,5 L2,5 L2,12 Z M4.335,3 C4.335,3.737 3.737,4.335 3,4.335 C2.263,4.335 1.665,3.737 1.665,3 C1.665,2.263 2.263,1.665 3,1.665 C3.737,1.665 4.335,2.263 4.335,3 Z" fill="#0073B2"></path></g><g class="dpi-gt1" transform="scale(0.2917)"><rect class="bug-text-color" fill="#FFFFFF" height="46" rx="4" width="46" x="1" y="1"></rect><path class="background" d="M0,4.00989318 C0,1.79529033 1.79405245,0 4.00989318,0 L43.9901068,0 C46.2047097,0 48,1.79405245 48,4.00989318 L48,43.9901068 C48,46.2047097 46.2059475,48 43.9901068,48 L4.00989318,48 C1.79529033,48 0,46.2059475 0,43.9901068 L0,4.00989318 Z M19,18.3 L25.5,18.3 L25.5,21.566 C26.437,19.688 28.838,18 32.445,18 C39.359,18 41,21.738 41,28.597 L41,41.3 L34,41.3 L34,30.159 C34,26.253 33.063,24.05 30.68,24.05 C27.375,24.05 26,26.425 26,30.159 L26,41.3 L19,41.3 L19,18.3 Z M7,41 L14,41 L14,18 L7,18 L7,41 Z M15,10.5 C15,12.985 12.985,15 10.5,15 C8.015,15 6,12.985 6,10.5 C6,8.015 8.015,6 10.5,6 C12.985,6 15,8.015 15,10.5 Z" fill="#0077B5"></path></g></g><g class="bug-21dp" fill="none" fill-rule="evenodd" stroke="none" stroke-width="1"><g class="dp-1"><path class="bug-text-color" d="M19.479,0 L1.583,0 C0.728,0 0,0.677 0,1.511 L0,19.488 C0,20.323 0.478,21 1.333,21 L19.229,21 C20.086,21 21,20.323 21,19.488 L21,1.511 C21,0.677 20.336,0 19.479,0" fill="#FFFFFF"></path><path class="background" d="M19.479,0 L1.583,0 C0.728,0 0,0.677 0,1.511 L0,19.488 C0,20.323 0.478,21 1.333,21 L19.229,21 C20.086,21 21,20.323 21,19.488 L21,1.511 C21,0.677 20.336,0 19.479,0 Z M8,8 L10.827,8 L10.827,9.441 L10.858,9.441 C11.289,8.664 12.562,7.875 14.136,7.875 C17.157,7.875 18,9.479 18,12.45 L18,18 L15,18 L15,12.997 C15,11.667 14.469,10.5 13.227,10.5 C11.719,10.5 11,11.521 11,13.197 L11,18 L8,18 L8,8 Z M3,18 L6,18 L6,8 L3,8 L3,18 Z M6.375,4.5 C6.375,5.536 5.536,6.375 4.5,6.375 C3.464,6.375 2.625,5.536 2.625,4.5 C2.625,3.464 3.464,2.625 4.5,2.625 C5.536,2.625 6.375,3.464 6.375,4.5 Z" fill="#0077B5"></path></g><g class="dpi-gt1" transform="scale(0.4375)"><rect class="bug-text-color" fill="#FFFFFF" height="46" rx="4" width="46" x="1" y="1"></rect><path class="background" d="M0,4.00989318 C0,1.79529033 1.79405245,0 4.00989318,0 L43.9901068,0 C46.2047097,0 48,1.79405245 48,4.00989318 L48,43.9901068 C48,46.2047097 46.2059475,48 43.9901068,48 L4.00989318,48 C1.79529033,48 0,46.2059475 0,43.9901068 L0,4.00989318 Z M19,18.3 L25.5,18.3 L25.5,21.566 C26.437,19.688 28.838,18 32.445,18 C39.359,18 41,21.738 41,28.597 L41,41.3 L34,41.3 L34,30.159 C34,26.253 33.063,24 ...
# <div class="search-global-typeahead ember-view" id="ember39"><div class="search-typeahead-v2 search-global-typeahead__typeahead ember-view" id="global-nav-typeahead"> <div class="ember-view" id="ember41"><input aria-activedescendant="" aria-autocomplete="list" aria-expanded="false" aria-label="Search" aria-owns="" class="search-global-typeahead__input always-show-placeholder" placeholder="Search" role="combobox" type="text"/></div>
# <!-- -->
# </div><div class="search-global-typeahead__controls">
# <button class="search-global-typeahead__button" data-control-name="nav.search_button" data-ember-action="" data-ember-action-42="42" tabindex="-1" type="button">
# <li-icon aria-label="Search" class="search-global-typeahead__icon" role="img" size="medium" type="search-icon"><svg data-supported-dps="24x24" fill="currentColor" focusable="false" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M21 19.67l-5.44-5.44a7 7 0 10-1.33 1.33L19.67 21zm-11-4.54A5.13 5.13 0 1115.13 10 5.13 5.13 0 0110 15.13z"></path>
# </svg></li-icon>
# </button>
# </div>
# <div class="ember-view" id="ember43"><!-- --></div>
# </div>
# </div>
# </div></div></form><nav aria-label="Primary" class="display-flex full-height" data-nav="main"><ul class="nav-main nav-container display-flex full-height"><li class="nav-item nav-item--feed" id="feed-nav-item" lang="en"><a class="nav-item__link nav-item__link--underline js-nav-item-link" data-alias="" data-control-name="" data-link-to="feed" data-resource="feed/badge" href="/feed/"><span class="nav-item__badge nav-item__badge--doughnut"><span aria-hidden="true" class="nav-item__badge-count">3</span><span class="visually-hidden">3</span></span><span class="nav-item__icon" id="feed-tab-icon" lang="en" role="presentation"><li-icon aria-hidden="true" color="true" type="nav-small-home-icon"><svg class="nav-icon" focusable="false" height="24px" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" xmlns="http://www.w3.org/2000/svg" y="0"><path class="active-item" d="M22,9.45,12.85,3.26A1.52,1.52,0,0,0,12,3a1.49,1.49,0,0,0-.84.26L2,9.45,3.06,11,4,10.37V20a1,1,0,0,0,1,1h5V16h4v5h5a1,1,0,0,0,1-1V10.37l.94.63Z" style="fill-opacity: 1"></path><path class="inactive-item" d="M22,9.45L12.85,3.26a1.5,1.5,0,0,0-1.69,0L2,9.45,3.06,11,4,10.37V20a1,1,0,0,0,1,1h6V16h2v5h6a1,1,0,0,0,1-1V10.37L20.94,11ZM18,19H15V15a1,1,0,0,0-1-1H10a1,1,0,0,0-1,1v4H6V8.89l6-4,6,4V19Z" style="fill: currentColor"></path></svg></li-icon></span><span class="nav-item__title">Home</span></a></li><li class="nav-item nav-item--mynetwork" id="mynetwork-nav-item" lang="en"><a class="nav-item__link nav-item__link--underline js-nav-item-link" data-alias="relationships" data-control-name="" data-link-to="mynetwork" data-resource="voyagerCommunicationsTabBadges" href="/mynetwork/"><span class="nav-item__badge"><span aria-hidden="true" class="nav-item__badge-count">1</span><span class="visually-hidden">1 new network update.</span></span><span class="nav-item__icon" id="mynetwork-tab-icon" lang="en" role="presentation"><li-icon aria-hidden="true" color="true" type="nav-small-people-icon"><svg class="nav-icon" focusable="false" height="24px" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" xmlns="http://www.w3.org/2000/svg" y="0"><path class="active-item" d="M16,17.85V20a1,1,0,0,1-1,1H1a1,1,0,0,1-1-1V17.85a4,4,0,0,1,2.55-3.73l2.95-1.2V11.71l-0.73-1.3A6,6,0,0,1,4,7.47V6a4,4,0,0,1,4.39-4A4.12,4.12,0,0,1,12,6.21V7.47a6,6,0,0,1-.77,2.94l-0.73,1.3v1.21l2.95,1.2A4,4,0,0,1,16,17.85Zm4.75-3.65L19,13.53v-1a6,6,0,0,0,1-3.31V9a3,3,0,0,0-6,0V9.18a6,6,0,0,0,.61,2.58A3.61,3.61,0,0,0,16,13a3.62,3.62,0,0,1,2,3.24V21h4a1,1,0,0,0,1-1V17.47A3.5,3.5,0,0,0,20.75,14.2Z" style="fill-opacity: 1"></path><path class="inactive-item" d="M20.74,14.2L19,13.54V12.86l0.25-.41A5,5,0,0,0,20,9.82V9a3,3,0,0,0-6,0V9.82a5,5,0,0,0,.75,2.63L15,12.86v0.68l-1,.37a4,4,0,0,0-.58-0.28l-2.45-1V10.83A8,8,0,0,0,12,7V6A4,4,0,0,0,4,6V7a8,8,0,0,0,1,3.86v1.84l-2.45,1A4,4,0,0,0,0,17.35V20a1,1,0,0,0,1,1H22a1,1,0,0,0,1-1V17.47A3.5,3.5,0,0,0,20.74,14.2ZM16,8.75a1,1,0,0,1,2,0v1.44a3,3,0,0,1-.38,1.46l-0.33.6a0.25,0.25,0,0,1-.22.13H16.93a0.25,0.25,0,0,1-.22-0.13l-0.33-.6A3,3,0,0,1,16,10.19V8.75ZM6,5.85a2,2,0,0,1,4,0V7.28a6,6,0,0,1-.71,2.83L9,10.72a1,1,0,0,1-.88.53H7.92A1,1,0,0,1,7,10.72l-0.33-.61A6,6,0,0,1,6,7.28V5.85ZM14,19H2V17.25a2,2,0,0,1,1.26-1.86L7,13.92v-1a3,3,0,0,0,1,.18H8a3,3,0,0,0,1-.18v1l3.72,1.42A2,2,0,0,1,14,17.21V19Zm7,0H16V17.35a4,4,0,0,0-.55-2l1.05-.4V14.07a2,2,0,0,0,.4.05h0.2a2,2,0,0,0,.4-0.05v0.88l2.53,1a1.5,1.5,0,0,1,1,1.4V19Z" style="fill: currentColor"></path></svg></li-icon></span><span class="nav-item__title">My Network</span></a></li><li class="nav-item nav-item--jobs" id="jobs-nav-item" lang="en"><a class="nav-item__link nav-item__link--underline js-nav-item-link" data-alias="" data-control-name="" data-link-to="jobs" data-resource="" href="/jobs/"><span class="nav-item__icon" id="jobs-tab-icon" lang="en" role="presentation"><li-icon aria-hidden="true" color="true" type="nav-small-jobs-icon"><svg class="nav-icon" focusable="false" height="24px" preserveaspectratio="xMinY ...
# <div class="nav-item__dropdown artdeco-dropdown artdeco-dropdown--placement-bottom artdeco-dropdown--justification-left ember-view" id="nav-settings__dropdown"><button aria-expanded="false" class="nav-item__link nav-item__dropdown-trigger t-14 t-black--light t-bold artdeco-dropdown__trigger artdeco-dropdown__trigger--placement-bottom ember-view" data-control-name="nav.settings" id="ember23" tabindex="0" type="button"> <img alt="mike patel" class="nav-item__profile-member-photo nav-item__icon ghost-person ember-view" height="24" id="ember24" src="..." width="24"/>
# <div class="nav-item__title-container">
# <span class="nav-item__title nav-item__dropdown-trigger--title">Me</span>
# <li-icon aria-hidden="true" class="nav-item__dropdown-trigger--icon" size="small" type="caret-filled-down-icon"><svg data-supported-dps="16x16" fill="currentColor" focusable="false" height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
# <path d="M8.8 10.66L14 5.12a.07.07 0 00-.07-.12H2.07a.07.07 0 00-.07.12l5.2 5.54a1.1 1.1 0 001.6 0z"></path>
# </svg></li-icon>
# </div>
# <!-- --></button><div aria-hidden="true" class="nav-settings__dropdown-options artdeco-dropdown__content artdeco-dropdown--is-dropdown-element artdeco-dropdown__content--justification-right artdeco-dropdown__content--placement-bottom ember-view" id="ember25" tabindex="-1"><div class="artdeco-dropdown__content-inner">
# <ul class="nav-settings__dropdown-options container-with-shadow">
# <li class="nav-settings__topcard nav-settings__no-hover">
# <a class="nav-settings__dropdown-item-link nav-settings__view-profile-link block clearfix ember-view" data-control-name="nav.settings_view_profile" href="/in/mike-patel-6684691a4/" id="ember26"> <div class="nav-settings__member nav-settings__block">
# <div class="nav-settings__member-photo-container">
# <img alt="mike patel" class="nav-settings__member-photo EntityPhoto-circle-4 ghost-person ember-view" height="70" id="ember27" src="..." width="70"/>
# </div>
# <div class="nav-settings__member-info-container">
# <!-- --> <h3 class="nav-settings__member-name t-16 t-black t-bold">
#                 mike patel
#               </h3>
# <h4 class="nav-settings__member-occupation t-14 t-black--light t-normal">
#                 Student at University of Windsor
#               </h4>
# </div>
# </div>
# <div class="nav-settings__linkcard nav-settings__block">
# <span class="artdeco-button artdeco-button--tertiary artdeco-button--fluid">
#               View profile
#             </span>
# </div>
# </a> </li>
# <!-- -->
# <li class="nav-settings__dropdown-options--account nav-settings__dropdown-options nav-settings__no-hover">
# <h5 class="nav-dropdown__title nav-settings__dropdown-title t-14 t-black t-bold">Account</h5>
# <ul class="nav-settings__dropdown-items">
# <li class="nav-dropdown__item nav-settings__dropdown-item t-14">
# <a class="nav-settings__dropdown-item-link block t-black--light t-bold ember-view" data-control-name="nav.settings_account_manage_account" href="https://www.linkedin.com/psettings/" id="ember29" rel="noopener noreferrer" tabindex="0" target="_blank">                    Settings &amp; Privacy
# </a> </li>
# <li class="nav-dropdown__item nav-settings__dropdown-item t-14">
# <button class="nav-settings__dropdown-item-link nav-settings__dropdown-button-link t-14 t-black--light t-bold block" data-control-name="quick-help-action-button" data-ember-action="" data-ember-action-31="31" type="button">
#                     Help
#                   </button>
# </li>
# <li class="nav-dropdown__item nav-settings__dropdown-item t-14">
# <a class="nav-settings__dropdown-item-link block t-black--light t-bold ember-view" data-control-name="nav.settings_account_language" href="https://www.linkedin.com/psettings/select-language" id="ember33" rel="noopener noreferrer" tabindex="0" target="_blank">                    Language
# </a> </li>
# </ul>
# </li>
# <li class="nav-settings__dropdown-options--manage nav-settings__no-hover">
# <h5 class="nav-dropdown__title nav-settings__dropdown-title t-14 t-black t-bold">Manage</h5>
# <ul class="nav-settings__dropdown-items">
# <li class="nav-dropdown__item nav-settings__dropdown-item t-14">
# <a class="nav-settings__dropdown-item-link nav-settings__manage-link nav-settings__view-activity-link block t-black--light t-bold ember-view" data-control-name="recent_activity_nav_all" href="/in/mike-patel-6684691a4/detail/recent-activity/" id="ember34">                  Posts &amp; Activity
# </a> </li>
# <li class="nav-dropdown__item nav-settings__dropdown-item t-14">
# <a class="nav-settings__dropdown-item-link block nav-settings__manage-link t-black--light t-bold ember-view" data-control-name="nav.settings_manage_job_posting_account" href="https://www.linkedin.com/job/consumer/manageConsumer?trk=nav_app_launcher_manage_job_post_nept" id="ember36" rel="noopener noreferrer" tabindex="0" target="_blank">                      Job posting account
# </a> </li>
# </ul>
# </li>
# <!-- -->
# <li class="nav-settings__dropdown-options--actions nav-settings__no-hover">
# <ul class="nav-settings__dropdown-items">
# <li class="nav-dropdown__item nav-settings__dropdown-item nav-dropdown__action t-14 t-bold">
# <a class="nav-settings__dropdown-item-link block t-black--light t-bold ember-view" data-control-name="nav.settings_signout" href="/m/logout/" id="ember38">                Sign out
# </a> </li>
# </ul>
# </li>
# </ul>
# </div>
# </div></div>
# </div>
# </li><li class="nav-item nav-item--app-launcher" id="app-launcher-nav-item"> <div class="nav-item__content">
# <div class="ember-view" id="ember19"><button class="nav-item__link nav-panel__trigger " data-control-name="nav.launcher" data-ember-action="" data-ember-action-20="20" type="button">
# <li-icon aria-label="Work icon" class="nav-item__icon" role="img" type="grid-icon"><svg data-supported-dps="24x24" fill="currentColor" focusable="false" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M10 10h4v4h-4v-4zm0 11h4v-4h-4v4zm-7-7h4v-4H3v4zm0 7h4v-4H3v4zM3 7h4V3H3v4zm14 7h4v-4h-4v4zm0-11v4h4V3h-4zm-7 4h4V3h-4v4zm7 14h4v-4h-4v4z"></path>
# </svg></li-icon>
# <div class="nav-item__title-container">
# <span class="nav-item__title nav-item__dropdown-trigger--title">Work</span>
# <li-icon aria-hidden="true" class="nav-item__dropdown-trigger--icon" size="small" type="caret-filled-down-icon"><svg data-supported-dps="16x16" fill="currentColor" focusable="false" height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
# <path d="M8.8 10.66L14 5.12a.07.07 0 00-.07-.12H2.07a.07.07 0 00-.07.12l5.2 5.54a1.1 1.1 0 001.6 0z"></path>
# </svg></li-icon>
# </div>
# </button>
# <div class="ember-view" id="ember21"><!-- --></div></div> </div>
# </li><li class="nav-item nav-item--spotlight-one nav-item__spotlight" id="spotlight-one-nav-item"> <div class="nav-item__wormhole">
# <div class="nav-item__content t-14 t-black t-normal premium-upsell-link ember-view" id="ember8">
# <a class="link-without-visited-state nav-item__spotlight-upsell premium-upsell-link--long ember-view" data-control-name="premium_nav_upsell_text_click" href="/premium/products/?destRedirectURL=https%3A%2F%2Fwww.linkedin.com%2Fin%2Fcharan-nadendla-858a17120%2F%3FshowPremiumWelcomeBanner%3Dtrue&amp;upsellOrderOrigin=premium_nav_upsell_text" id="ember9">        Try Premium Free for 1 Month
# <!-- --></a></div>
# </div>
# </li></ul></nav></div></header>
# <!-- EMBER_CLI_FASTBOOT_BODY -->
# <script src="https://static-exp1.licdn.com/sc/h/br/d0a0lb0tiq5qpenxgc4ps5hbz"></script>
# <script nomodule="" src="https://static-exp1.licdn.com/sc/h/br/1id8ixboa6ibb8do33ac7j0l4"></script>
# <script src="https://static-exp1.licdn.com/sc/h/br/44lpm3xommt4uaobb0rsjjk0w"></script>
# <div class="app-boot-bg-skeleton" id="app-boot-bg-loader">
# <div class="top-bar"></div>
# <div class="content">
# <div class="initial-load-animation fade-load">
# <div class="linkedin-image">
# ...
#     Sponsored •
#   </span>
#   Global Online MBA in Canada
# </span>
# </p>
# </div>
# </div>
# <div class="msg-conversation-card__conversation-status fr pl2 align-items-center flex-grow-1">
# <!-- --> <mark class="msg-conversation-card__unread-count">
# <abbr title="1 unread message">
#                 1
#               </abbr>
# </mark>
# </div>
# </div>
# </div>
# </div></div>
# <div class="msg-overlay-list-bubble__convo-item--hoverable msg-overlay-list-bubble__convo-item ember-view" data-control-name="overlay.view_message" id="ember370" role="button" tabindex="0"><div class="msg-conversation-listitem__link msg-overlay-list-bubble__convo-item-link">
# <div class="msg-conversation-card msg-overlay-list-bubble__convo-card">
# <div class="msg-facepile-grid msg-facepile-grid--no-facepile msg-facepile-grid--small ember-view" id="ember372"> <img alt="LinkedIn Member" class="lazy-image msg-facepile-grid__img msg-facepile-grid__img--person ember-view" id="ember374" loading="lazy" src="https://media-exp1.licdn.com/dms/image/C560CAQHyRqDKV1P_ZQ/spinmail-customsender-displayphoto-shrink_100_100/0?e=1590087600&amp;v=beta&amp;t=JK3d8rBNXqArtElhBe_6xLRZn9OSdSPHIBFLUhLo9Co"/>
# </div>
# <div class="msg-overlay-list-bubble__convo-card-content overflow-hidden">
# <div class="msg-overlay-list-bubble__convo-card-content-wrapper fl msg-overlay-list-bubble__convo-card-content-wrapper--narrow">
# <!-- --> <div class="msg-conversation-card__row">
# <h4 class="msg-conversation-listitem__participant-names msg-conversation-card__participant-names truncate t-14 t-black t-bold">
#               Jen &amp; the Sales Navigator Team
#           </h4>
# </div>
# <div class="msg-conversation-card__row">
# <p class="msg-overlay-list-bubble__message-snippet msg-overlay-participant-headline m0 truncate t-12 t-black t-bold">
# <span class="ember-view" id="ember375">
# <span class="msg-conversation-card__pill t-14 t-black t-bold pr1">
#     LinkedIn Offer •
#   </span>
#   Thanks for being an active LinkedIn member
# </span>
# </p>
# </div>
# </div>
# <div class="msg-conversation-card__conversation-status fr pl2 align-items-center flex-grow-1">
# <!-- --> <mark class="msg-conversation-card__unread-count">
# <abbr title="1 unread message">
#                 1
#               </abbr>
# </mark>
# </div>
# </div>
# </div>
# </div></div>
# <div class="msg-overlay-list-bubble__convo-item--hoverable msg-overlay-list-bubble__convo-item ember-view" data-control-name="overlay.view_message" id="ember377" role="button" tabindex="0"><div class="msg-conversation-listitem__link msg-overlay-list-bubble__convo-item-link">
# <div class="msg-conversation-card msg-overlay-list-bubble__convo-card">
# <div class="msg-facepile-grid msg-facepile-grid--no-facepile msg-facepile-grid--small ember-view" id="ember379"> <img alt="LinkedIn Member" class="lazy-image msg-facepile-grid__img msg-facepile-grid__img--person ghost-person ember-view" id="ember381" loading="lazy" src="..."/>
# </div>
# <div class="msg-overlay-list-bubble__convo-card-content overflow-hidden">
# <div class="msg-overlay-list-bubble__convo-card-content-wrapper fl ">
# <!-- --> <div class="msg-conversation-card__row">
# <h4 class="msg-conversation-listitem__participant-names msg-conversation-card__participant-names truncate t-14 t-black t-normal">
#               LinkedIn Member
#           </h4>
# </div>
# <div class="msg-conversation-card__row">
# <p class="msg-overlay-list-bubble__message-snippet msg-overlay-participant-headline m0 truncate t-12 t-black t-normal">
# <span class="ember-view" id="ember382">
# <span class="msg-conversation-card__pill t-14 t-black t-bold pr1">
#     Sponsored •
#   </span>
# </span>
# </p>
# </div>
# </div>
# <div class="msg-conversation-card__conversation-status fr pl2 align-items-center flex-grow-1">
# <!-- --><!-- --> </div>
# </div>
# </div>
# </div></div>
# </div>
# <!-- --> <div class="msg-overlay-list-bubble__loader hidden">
# <div class="artdeco-loader artdeco-loader--small ember-view" id="ember383"><!-- -->
# <span class="artdeco-loader__bars"></span>
# <span class="artdeco-loader__bars"></span>
# <span class="artdeco-loader__bars"></span>
# <span class="artdeco-loader__bars"></span>
# <span class="artdeco-loader__bars"></span>
# <span class="artdeco-loader__bars"></span>
# <span class="artdeco-loader__bars"></span>
# <span class="artdeco-loader__bars"></span>
# <span class="artdeco-loader__bars"></span>
# <span class="artdeco-loader__bars"></span>
# <span class="artdeco-loader__bars"></span>
# <span class="artdeco-loader__bars"></span>
# </div>
# </div>
# </div>
# </section>
# <!-- --></div>
# <!-- --></aside>
# <img class="third-party-tracking-pixel hidden ember-view" id="ember133" src="https://c.bing.com/c.gif?Red3=MSLI_pd&amp;LIID=ATjMmFgqKAn-1lpUfbd65Vk6n1b8&amp;_t=1589998032662"/>
# <img class="third-party-tracking-pixel hidden ember-view" id="ember134" src="https://secure.adnxs.com/setuid?entity=373&amp;code=ARE7m1jV2x6MEHqV3aDbx-oKiP8-&amp;_t=1589998032665"/>
# <img class="third-party-tracking-pixel hidden ember-view" id="ember135" src="https://eb2.3lift.com/xuid?mid=6250&amp;xuid=isLIMember&amp;dongle=2b63&amp;rdir=https%3A%2F%2Fpx.ads.linkedin.com%2Fsetuid%3Fpartner%3Dtriplelift%26tlUid%3D%24UID&amp;_t=1589998032669"/>
# <img class="third-party-tracking-pixel hidden ember-view" id="ember136" src="https://sync.teads.tv/um?eid=161&amp;uid=&amp;fb=https%3A%2F%2Fpx.ads.linkedin.com%2Fsetuid%3Fpartner%3Dteads%26exuid%3D%5BVID%5D&amp;_t=1589998032671"/>
# <img class="third-party-tracking-pixel hidden ember-view" id="ember137" src="https://px.ads.linkedin.com/collect/?pid=6883&amp;fmt=gif&amp;_t=1589998032673"/>
# </div>
# <div id="li-modal-container"></div>
# <div id="artdeco-hoverable-outlet"></div>
# <div class="entity-hovercard-container hidden ember-view" id="ember12"><div class="entity-hovercard p4" role="tooltip" tabindex="-1">
# <section class="entity-hovercard__loading-state">
#       Loading…
#     </section>
# </div>
# </div>
# <!-- -->
# <!-- -->
# <div class="type-ahead type-ahead-wormhole" id="type-ahead-wormhole">
# </div>
# <div class="toast-wormhole" id="toast-wormhole">
# </div>
# <!-- -->
# <div><!-- --></div>
# <code id="bpr-guid-1292999" style="display: none">
#   {"data":{"entityUrn":"urn:li:collectionResponse:p+vB2JbcvuVz+hHXtwIkcCMn8CjTiaoJjvncQ26cyBc=","paging":{"count":10,"start":0,"links":[]},"*elements":["urn:li:fsd_profile:ACoAAB4M_QQBfm81WIkWLiT988PmyhWfdiEi5Qc"],"$type":"com.linkedin.restli.common.CollectionResponse"},"meta":{"microSchema":{"version":"2","types":{"com.linkedin.voyager.dash.deco.common.IntegerRange":{"fields":{"start":{"type":"int"},"end":{"type":"int"}},"baseType":"com.linkedin.common.IntegerRange"},"com.linkedin.voyager.dash.deco.identity.profile.EmploymentType":{"fields":{"name":{"type":"string"},"entityUrn":{"type":"string"},"companyNameRequired":{"type":"boolean"}},"baseType":"com.linkedin.voyager.dash.identity.profile.EmploymentType"},"com.linkedin.voyager.dash.deco.identity.profile.LinkableMiniCompany":{"fields":{"name":{"type":"string"},"logo":{"type":{"union":{"url":"string","vectorImage":"com.linkedin.voyager.dash.deco.identity.profile.linkableminicompany.Anon0"}}},"universalName":{"type":"string"},"entityUrn":{"type":"string"},"url":{"type":"string"}},"baseType":"com.linkedin.voyager.dash.organization.Company"},"com.linkedin.voyager.dash.deco.identity.profile.CountryGeo":{"fields":{"entityUrn":{"type":"string"},"defaultLocalizedName":{"type":"string"}},"baseType":"com.linkedin.voyager.dash.common.Geo"},"com.linkedin.voyager.dash.deco.identity.profile.FullProfilePublication":{"fields":{"entityUrn":{"type":"string"},"multiLocaleName":{"type":{"map":"string"}},"name":{"type":"string"},"description":{"type":"string"},"publishedOn":{"type":"com.linkedin.common.Date"},"publisher":{"type":"string"},"multiLocaleDescription":{"type":{"map":"string"}},"multiLocalePublisher":{"type":{"map":"string"}},"url":{"type":"string"},"authors":{"type":{"array":{"union":{"nonStandardizedContributor":"com.linkedin.voyager.dash.deco.identity.profile.FullNonStandardizedContributor","standardizedContributor":"com.linkedin.voyager.dash.deco.identity.profile.StandardizedContributor"}}}}},"baseType":"com.linkedin.voyager.dash.identity.profile.Publication"},"com.linkedin.voyager.dash.deco.organization.VectorImage":{"fields":{"attribution":{"type":"string"},"artifacts":{"type":{"array":"com.linkedin.common.VectorArtifact"}},"rootUrl":{"type":"string"}},"baseType":"com.linkedin.common.VectorImage"},"com.linkedin.voyager.dash.deco.identity.profile.FullProfileHonorsInjection":{"fields":{"paging":{"type":"com.linkedin.voyager.dash.deco.common.FullPaging"},"elements":{"type":{"array":"com.linkedin.voyager.dash.deco.identity.profile.FullProfileHonor"}}},"baseType":"com.linkedin.restli.common.CollectionResponse"},"com.linkedin.voyager.dash.deco.identity.profile.FullProfileLanguagesInjection":{"fields":{"paging":{"type":"com.linkedin.voyager.dash.deco.common.FullPaging"},"elements":{"type":{"array":"com.linkedin.voyager.dash.deco.identity.profile.FullProfileLanguage"}}},"baseType":"com.linkedin.restli.common.CollectionResponse"},"com.linkedin.voyager.dash.deco.identity.profile.FullProfileTreasuryMedia":{"fields":{"mediaDescription":{"type":"string"},"multiLocaleTitle":{"type":{"map":"string"}},"data":{"type":{"union":{"VectorImage":"com.linkedin.voyager.dash.deco.identity.profile.fullprofiletreasurymedia.Anon0","ImageUrl":"com.linkedin.voyager.dash.deco.identity.profile.ImageUrl","Document":"com.linkedin.voyager.dash.deco.identity.profile.EmbeddableMedia","NativeDocument":"com.linkedin.voyager.dash.deco.identity.profile.Document","Url":"string","Video":"com.linkedin.voyager.dash.deco.identity.profile.EmbeddableMedia"}}},"description":{"type":"string"},"title":{"type":"string"},"previewImages":{"type":{"array":"com.linkedin.voyager.dash.deco.identity.profile.ImageUrl"}},"mediaTitle":{"type":"string"},"entityUrn":{"type":"string"},"multiLocaleMediaDescription":{"type":{"map":"string"}},"width":{"type":"int"},"multiLocaleDescription":{"type":{"map":"string"}},"providerName":{"type":"string"},"previewImage":{"type":"com.linkedin.voyager.dash.deco.common.image.ImageViewModel"},"height":{"typ ...
# </code>
# <code id="datalet-bpr-guid-1292999" style="display: none">
#   {"request":"/voyager/api/identity/dash/profiles?q\u003DmemberIdentity\u0026memberIdentity\u003Dcharan-nadendla-858a17120\u0026decorationId\u003Dcom.linkedin.voyager.dash.deco.identity.profile.FullProfileWithEntities-45","status":200,"body":"bpr-guid-1292999","method":"GET"}
# </code>
# <img class="datalet-bpr-guid-1292999" src="..." style="display: none"/><code id="bpr-guid-1293004" style="display: none">
#   {"data":{"primaryExternalAction":null,"primaryAction":{"action":{"$type":"com.linkedin.voyager.identity.profile.actions.Connect"},"$type":"com.linkedin.voyager.identity.profile.actions.ProfileAction"},"entityUrn":"urn:li:fs_profileactions:ACoAAB4M_QQBfm81WIkWLiT988PmyhWfdiEi5Qc","secondaryAction":{"action":{"composeOption":{"icon":{"attributes":[{"sourceType":"ART_DECO_ICON","artDecoIcon":"IC_LOCK_24DP","$type":"com.linkedin.voyager.common.ImageAttribute"}],"accessibilityTextAttributes":[],"$type":"com.linkedin.voyager.common.ImageViewModel"},"displayText":{"textDirection":"USER_LOCALE","attributes":[],"text":"Message","$type":"com.linkedin.voyager.common.TextViewModel"},"composeOptionType":"UPSELL","textStartIcon":{"attributes":[{"sourceType":"ART_DECO_ICON","artDecoIcon":"IC_LOCK_24DP","$type":"com.linkedin.voyager.common.ImageAttribute"}],"accessibilityTextAttributes":[],"$type":"com.linkedin.voyager.common.ImageViewModel"},"targetUrl":"https://www.linkedin.com/premium/upsell?upsellOrderOrigin=PREMIUM_INMAIL_PROFILE_UPSELL_MODAL&amp;contextUrn=urn%3Ali%3Afs_profile%3A%28ACoAAB4M_QQBfm81WIkWLiT988PmyhWfdiEi5Qc%2Cen_US%29&amp;channel=INMAIL","$type":"com.linkedin.voyager.messaging.compose.ComposeOption"},"profileActionType":"COMPOSE_MESSAGE","$type":"com.linkedin.voyager.identity.profile.actions.GenericProfileAction"},"$type":"com.linkedin.voyager.identity.profile.actions.ProfileAction"},"overflowActions":[{"action":{"requestUrl":"https://www.linkedin.com/profile/pdf?id=ACoAAB4M_QQBfm81WIkWLiT988PmyhWfdiEi5Qc&amp;locale=en_US&amp;authType=name&amp;authToken=kMb6&amp;disablePdfCompression=true&amp;trk=pdf_pro_full","$type":"com.linkedin.voyager.identity.profile.actions.SaveToPdf"},"$type":"com.linkedin.voyager.identity.profile.actions.ProfileAction"},{"action":{"$type":"com.linkedin.voyager.identity.profile.actions.Follow"},"$type":"com.linkedin.voyager.identity.profile.actions.ProfileAction"},{"action":{"$type":"com.linkedin.voyager.identity.profile.actions.Report"},"$type":"com.linkedin.voyager.identity.profile.actions.ProfileAction"}],"actions":[],"$type":"com.linkedin.voyager.identity.profile.actions.ProfileActions"},"included":[]}
# </code>
# <code id="datalet-bpr-guid-1293004" style="display: none">
#   {"request":"/voyager/api/identity/profiles/charan-nadendla-858a17120/profileActions?contextType\u003DNON_SELF_PROFILE_VIEW\u0026profileActionTypes\u003DList(ACCEPT,BLOCK,BUILD_RESUME,CONNECT,DISCONNECT,FOLLOW,IGNORE,INVITATION_PENDING,PERSONALIZED_CONNECT,RECOMMEND,REPORT,REQUEST_RECOMMENDATION,SAVE_TO_PDF,SIGNUP,UNFOLLOW,VIEW_PROFILE_IN_RECRUITER,VIEW_PROFILE_IN_SALES_NAVIGATOR,APPRECIATE,COMPOSE_MESSAGE,ADD_TEAMMATE)","status":200,"body":"bpr-guid-1293004","method":"GET"}
# </code>
# <img class="datalet-bpr-guid-1293004" src="..." style="display: none"/><code id="bpr-guid-1293006" style="display: none">
#   {"data":{"firstName":"Charan","lastName":"Nadendla","occupation":"FPGA Emulation Engineer at Microchip Technology Inc.","objectUrn":"urn:li:member:504167684","entityUrn":"urn:li:fs_miniProfile:ACoAAB4M_QQBfm81WIkWLiT988PmyhWfdiEi5Qc","backgroundImage":null,"publicIdentifier":"charan-nadendla-858a17120","picture":{"artifacts":[{"width":100,"fileIdentifyingUrlPathSegment":"100_100/0?e=1595462400&amp;v=beta&amp;t=YSNQ8CURaadF3ynfLONKQZG9TyLuw6pWKzoV93rviKs","expiresAt":1595462400000,"height":100,"$type":"com.linkedin.common.VectorArtifact"},{"width":200,"fileIdentifyingUrlPathSegment":"200_200/0?e=1595462400&amp;v=beta&amp;t=Q0ZLwomUaAQq7FjqotqBbZiNfj2GQcawbfqL0nT7FKc","expiresAt":1595462400000,"height":200,"$type":"com.linkedin.common.VectorArtifact"},{"width":400,"fileIdentifyingUrlPathSegment":"400_400/0?e=1595462400&amp;v=beta&amp;t=04xAxdAS3lsXCBRaoMSjxTZOJIyzY-097bZow1LQKDo","expiresAt":1595462400000,"height":400,"$type":"com.linkedin.common.VectorArtifact"},{"width":800,"fileIdentifyingUrlPathSegment":"800_800/0?e=1595462400&amp;v=beta&amp;t=Z3b0a__e7G-1pRkD2hA0WziylXefU2dAZ5JgGKMSr2w","expiresAt":1595462400000,"height":800,"$type":"com.linkedin.common.VectorArtifact"}],"rootUrl":"https://media-exp1.licdn.com/dms/image/C5603AQFXCn7t7QGCgg/profile-displayphoto-shrink_","$type":"com.linkedin.common.VectorImage"},"trackingId":"h840/AeUTHCu/8aZdM+0TA==","$type":"com.linkedin.voyager.identity.shared.MiniProfile"},"included":[]}
# </code>
# <code id="datalet-bpr-guid-1293006" style="display: none">
#   {"request":"/voyager/api/identity/miniprofiles/ACoAAB4M_QQBfm81WIkWLiT988PmyhWfdiEi5Qc","status":200,"body":"bpr-guid-1293006","method":"GET"}
# </code>
# <img class="datalet-bpr-guid-1293006" src="..." style="display: none"/><code id="bpr-guid-1293010" style="display: none">
#   {"data":{"entityUrn":"urn:li:collectionResponse:l4USwGeBYmrZkJ2HJ79zLJBHw+jFM6jme188Se9w8Hw=","elements":[],"paging":{"count":10,"start":0,"links":[]},"$type":"com.linkedin.restli.common.CollectionResponse"},"included":[]}
# </code>
# <code id="datalet-bpr-guid-1293010" style="display: none">
#   {"request":"/voyager/api/identity/profiles/charan-nadendla-858a17120/opportunityCards?q\u003Dgoals","status":200,"body":"bpr-guid-1293010","method":"GET"}
# </code>
# <img class="datalet-bpr-guid-1293010" src="..." style="display: none"/><code id="clientPageInstance" style="display: none">
#   urn:li:page:d_flagship3_profile_view_base;OsvNqKFETBKnaesdgCe7nw==
# </code>
# <img class="terminatorlet" src="..." style="display: none"/>
# <div aria-live="polite" class="visually-hidden" id="a11y-notification" role="region"></div>
# </body></html>

# %%
name_div = soup.find('div', {'class': 'flex-1 mr5'})
name_div
# Out:
# <div class="flex-1 mr5">
# <ul class="pv-top-card--list inline-flex align-items-center">
# <li class="inline t-24 t-black t-normal break-words">
#             Charan Nadendla
#           </li>
# <li class="pv-top-card__distance-badge inline-block v-align-text-bottom t-16 t-black--light t-normal"><span class="distance-badge separator">
# <span class="visually-hidden">3rd degree connection</span><span aria-hidden="true" class="dist-value">3rd</span>
# </span></li>
# <!-- --> <li class="inline-flex ml2">
# <span class="pv-member-badge--for-top-card inline-flex pv-member-badge ember-view" id="ember89" style="display: none;"><!-- -->
# <!-- -->
# <span class="visually-hidden">
#   Charan has a  account
# </span>
# <!-- --></span>
# </li>
# </ul>
# <h2 class="mt1 t-18 t-black t-normal break-words">
#             FPGA Emulation Engineer  at Microchip Technology Inc.
#           </h2>
# <ul class="pv-top-card--list pv-top-card--list-bullet mt1">
# <li class="t-16 t-black t-normal inline-block">
#               Bengaluru, Karnataka, India
#             </li>
# <!-- -->
# <li class="inline-block">
# <span class="t-16 t-black t-normal">
#                   500+ connections
#                 </span>
# </li>
# <li class="inline-block">
# <a class="ember-view" data-control-name="contact_see_more" href="/in/charan-nadendla-858a17120/detail/contact-info/" id="ember90"> <span class="t-16 t-bold">
#                 Contact info
#               </span>
# </a> </li>
# </ul>
# </div>

# %%
name_loc = name_div.find_all('ul')
name = name_loc[0].find('li').get_text().strip()
name
# Out:
# 'Charan Nadendla'

# %%
loc = name_loc[1].find('li').get_text().strip()
loc
# Out:
# 'Bengaluru, Karnataka, India'

# %%
profile_title = name_div.find('h2').get_text().strip()
profile_title
# Out:
# 'FPGA Emulation Engineer  at Microchip Technology Inc.'

# %%
connection = name_loc[1].find_all('li')
connection = connection[1].get_text().strip()
connection
# Out:
# '500+ connections'

# %%
info = []
info.append(link)
info.append(name)
info.append(profile_title)
info.append(loc)
info.append(connection)
info
# Out:
# ['https://www.linkedin.com/in/charan-nadendla-858a17120/',
#  'Charan Nadendla',
#  'FPGA Emulation Engineer  at Microchip Technology Inc.',
#  'Bengaluru, Karnataka, India',
#  '500+ connections']

# %% [markdown]
# ### Experience

# %%
exp_section = soup.find('section', {'id': 'experience-section'})
#exp_section

# %%
exp_section = exp_section.find('ul')
#exp_section

# %%
new_data=soup.find_all('h3',{'class':'t-16 t-black t-bold'})
new_data
# Out:
# [<h3 class="t-16 t-black t-bold">FPGA Emulation Engineer </h3>,
#  <h3 class="t-16 t-black t-bold">FPGA Design and Verification Engineer</h3>]

# %%
li_tags = exp_section.find('div')
a_tags = li_tags.find('a')
#a_tags

# %%
#a_tags

# %%
job_title = a_tags.find('h3').get_text().strip()
job_title
# Out:
# 'FPGA Emulation Engineer'

# %%
company_name = a_tags.find_all('p')[1].get_text().strip()
company_name
# Out:
# 'Microchip Technology Inc.\n        Full-time'

# %%
joining_date = a_tags.find_all('h4')[0].find_all('span')[1].get_text().strip()
joining_date
# Out:
# 'Nov 2019 – Present'

# %%
exp = a_tags.find_all('h4')[1].find_all('span')[1].get_text().strip()
exp
# Out:
# '7 mos'

# %%
info
# Out:
# ['https://www.linkedin.com/in/charan-nadendla-858a17120/',
#  'Charan Nadendla',
#  'FPGA Emulation Engineer  at Microchip Technology Inc.',
#  'Bengaluru, Karnataka, India',
#  '500+ connections']

# %%
info.append(company_name)
info.append(job_title)
info.append(joining_date)
info.append(exp)

# %%
info
# Out:
# ['https://www.linkedin.com/in/charan-nadendla-858a17120/',
#  'Charan Nadendla',
#  'FPGA Emulation Engineer  at Microchip Technology Inc.',
#  'Bengaluru, Karnataka, India',
#  '500+ connections',
#  'Microchip Technology Inc.\n        Full-time',
#  'FPGA Emulation Engineer',
#  'Nov 2019 – Present',
#  '7 mos']

# %% [markdown]
# ### Education

# %%
edu_section = soup.find('section', {'id': 'education-section'}).find('ul')
edu_section
# Out:
# <ul class="pv-profile-section__section-info section-info pv-profile-section__section-info--has-no-more">
# <li class="pv-profile-section__list-item pv-education-entity pv-profile-section__card-item ember-view" id="339128774"><div class="display-flex justify-space-between full-width">
# <div class="display-flex flex-column full-width">
# <a class="ember-view" data-control-name="background_details_school" href="/school/220513/?legacySchoolId=220513" id="ember167"> <div class="pv-entity__logo">
# <img alt="Madanapalli Institute of Technology &amp; Science, Madanapalli" class="pv-entity__logo-img pv-entity__logo-img EntityPhoto-square-4 lazy-image ghost-school ember-view" id="ember169" loading="lazy" src="..."/>
# </div>
# <div class="pv-entity__summary-info pv-entity__summary-info--background-section">
# <div class="pv-entity__degree-info">
# <h3 class="pv-entity__school-name t-16 t-black t-bold">Madanapalli Institute of Technology &amp; Science, Madanapalli</h3>
# <p class="pv-entity__secondary-title pv-entity__degree-name t-14 t-black t-normal">
# <span class="visually-hidden">Degree Name</span>
# <span class="pv-entity__comma-item">Bachelor’s Degree</span>
# </p>
# <p class="pv-entity__secondary-title pv-entity__fos t-14 t-black t-normal">
# <span class="visually-hidden">Field Of Study</span>
# <span class="pv-entity__comma-item">ELECTRONICS AND COMMUNICATION ENGINEERING</span>
# </p>
# <p class="pv-entity__secondary-title pv-entity__grade t-14 t-black t-normal">
# <span class="visually-hidden">Grade</span>
# <span class="pv-entity__comma-item">A</span>
# </p>
# </div>
# <p class="pv-entity__dates t-14 t-black--light t-normal">
# <span class="visually-hidden">Dates attended or expected graduation</span>
# <span>
# <time>2013</time> – <time>2017</time>
# </span>
# </p>
# <!-- --></div>
# </a>
# <!-- --> </div>
# <!-- --></div>
# </li>
# </ul>

# %%
college_name = edu_section.find('h3').get_text().strip()
college_name
# Out:
# 'Madanapalli Institute of Technology & Science, Madanapalli'

# %%
degree_name = edu_section.find('p', {'class': 'pv-entity__secondary-title pv-entity__degree-name t-14 t-black t-normal'}).find_all('span')[1].get_text().strip()
degree_name
# Out:
# 'Bachelor’s Degree'

# %%
stream = edu_section.find('p', {'class': 'pv-entity__secondary-title pv-entity__fos t-14 t-black t-normal'}).find_all('span')[1].get_text().strip()
stream
# Out:
# 'ELECTRONICS AND COMMUNICATION ENGINEERING'

# %%
degree_year = edu_section.find('p', {'class': 'pv-entity__dates t-14 t-black--light t-normal'}).find_all('span')[1].get_text().strip()
degree_year
# Out:
# '2013 – 2017'

# %%
info
# Out:
# ['https://www.linkedin.com/in/charan-nadendla-858a17120/',
#  'Charan Nadendla',
#  'FPGA Emulation Engineer  at Microchip Technology Inc.',
#  'Bengaluru, Karnataka, India',
#  '500+ connections',
#  'Microchip Technology Inc.\n        Full-time',
#  'FPGA Emulation Engineer',
#  'Nov 2019 – Present',
#  '7 mos']

# %%
info.append(college_name)
info.append(degree_name)
#info.append(stream)
#info.append(degree_year)

# %%
info
# Out:
# ['https://www.linkedin.com/in/charan-nadendla-858a17120/',
#  'Charan Nadendla',
#  'FPGA Emulation Engineer  at Microchip Technology Inc.',
#  'Bengaluru, Karnataka, India',
#  '500+ connections',
#  'Microchip Technology Inc.\n        Full-time',
#  'FPGA Emulation Engineer',
#  'Nov 2019 – Present',
#  '7 mos',
#  'Madanapalli Institute of Technology & Science, Madanapalli',
#  'Bachelor’s Degree']
