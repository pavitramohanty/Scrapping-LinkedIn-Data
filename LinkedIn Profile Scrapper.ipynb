# %%
import requests, time, random
from bs4 import BeautifulSoup
from selenium import webdriver
import pandas as pd
import time

# %%
df = pd.read_csv("C:/Users/Admin/Desktop/linkedin_name.csv") 
print(df[['Lname','Fname']])

#https://www.linkedin.com/search/results/people/?facetSchool=%5B%2210880%22%5D&keywords=patel%20Jaimin&origin=FACETED_SEARCH
# Out:
#      Lname      Fname
# 0    Patel       Meet
# 1  Kukreja     Smarth
# 2    Singh  karmanjot
# 3  Agarwal     Saurav
# 4     Lean    Prakort
# 5    Patel    Nishtha
# 6    Patel        Het
# 7    Mehta      Ankit

# %%
lname=df.iloc[0][0]
fname=df.iloc[0][1]
link="https://www.linkedin.com/search/results/people/?facetSchool=%5B%2210880%22%5D&keywords="+lname+"%20"+fname+"&origin=FACETED_SEARCH"
print(link)
# Out:
# https://www.linkedin.com/search/results/people/?facetSchool=%5B%2210880%22%5D&keywords=Patel%20Meet&origin=FACETED_SEARCH

# %%
for i in range(0,8):
    link="https://www.linkedin.com/search/results/people/?facetSchool=%5B%2210880%22%5D&keywords="+df.iloc[i][0]+"%20"+df.iloc[i][1]+"&origin=FACETED_SEARCH"
    print(link)
# Out:
# https://www.linkedin.com/search/results/people/?facetSchool=%5B%2210880%22%5D&keywords=Patel%20Meet&origin=FACETED_SEARCH
# https://www.linkedin.com/search/results/people/?facetSchool=%5B%2210880%22%5D&keywords=Kukreja%20Smarth&origin=FACETED_SEARCH
# https://www.linkedin.com/search/results/people/?facetSchool=%5B%2210880%22%5D&keywords=Singh%20karmanjot&origin=FACETED_SEARCH
# https://www.linkedin.com/search/results/people/?facetSchool=%5B%2210880%22%5D&keywords=Agarwal%20Saurav&origin=FACETED_SEARCH
# https://www.linkedin.com/search/results/people/?facetSchool=%5B%2210880%22%5D&keywords=Lean%20Prakort&origin=FACETED_SEARCH
# https://www.linkedin.com/search/results/people/?facetSchool=%5B%2210880%22%5D&keywords=Patel%20Nishtha&origin=FACETED_SEARCH
# https://www.linkedin.com/search/results/people/?facetSchool=%5B%2210880%22%5D&keywords=Patel%20Het&origin=FACETED_SEARCH
# https://www.linkedin.com/search/results/people/?facetSchool=%5B%2210880%22%5D&keywords=Mehta%20Ankit&origin=FACETED_SEARCH

# %%
browser = webdriver.Chrome('C:/Users/Admin/Desktop/LinkedIn-Profile-Scrapper-in-Python-master/chromedriver.exe')
browser.get('https://www.linkedin.com/uas/login')
file = open('config.txt')
lines = file.readlines()
username = lines[0]
password = lines[1]


elementID = browser.find_element_by_id('username')
elementID.send_keys(username)

elementID = browser.find_element_by_id('password')
elementID.send_keys(password)

elementID.submit()

# %%
df = pd.read_csv("C:/Users/Admin/Desktop/linkedin_name.csv") 
#print(df[['Lname','Fname']])
URL=[]
for i in range(0,len(df)):
    link="https://www.linkedin.com/search/results/people/?facetSchool=%5B%2210880%22%5D&keywords="+df.iloc[i][0]+"%20"+df.iloc[i][1]+"&origin=FACETED_SEARCH"
    URL.append(link)
#    print(URL)
print(URL)
for link in URL:
#URL="https://www.linkedin.com/search/results/people/?facetSchool=%5B%2210880%22%5D&keywords=Patel%20Het&origin=FACETED_SEARCH"
    browser.get(link)
    src = browser.page_source
    soup = BeautifulSoup(src, 'lxml')
    id=soup.find_all('div',{'class':'search-result__info pt3 pb4 ph0'})
    list_url=[]
    for a in id:
        url="https://www.linkedin.com"+a.find('a')['href']
        list_url.append(url)
        print("Found the URL:"+ url )
    Profile_link=list_url
    result=pd.DataFrame(columns="Link",data=Profile_link) 
    #result = result[result.Link != 0]
    result.to_csv("C:/Users/Admin/Desktop/output.csv",mode='a')
    time.sleep(2)
# Out:
# ['https://www.linkedin.com/search/results/people/?facetSchool=%5B%2210880%22%5D&keywords=Patel%20Meet&origin=FACETED_SEARCH', 'https://www.linkedin.com/search/results/people/?facetSchool=%5B%2210880%22%5D&keywords=Kukreja%20Smarth&origin=FACETED_SEARCH', 'https://www.linkedin.com/search/results/people/?facetSchool=%5B%2210880%22%5D&keywords=Singh%20karmanjot&origin=FACETED_SEARCH', 'https://www.linkedin.com/search/results/people/?facetSchool=%5B%2210880%22%5D&keywords=Agarwal%20Saurav&origin=FACETED_SEARCH', 'https://www.linkedin.com/search/results/people/?facetSchool=%5B%2210880%22%5D&keywords=Lean%20Prakort&origin=FACETED_SEARCH', 'https://www.linkedin.com/search/results/people/?facetSchool=%5B%2210880%22%5D&keywords=Patel%20Nishtha&origin=FACETED_SEARCH', 'https://www.linkedin.com/search/results/people/?facetSchool=%5B%2210880%22%5D&keywords=Patel%20Het&origin=FACETED_SEARCH', 'https://www.linkedin.com/search/results/people/?facetSchool=%5B%2210880%22%5D&keywords=Mehta%20Ankit&origin=FACETED_SEARCH']
# Found the URL:https://www.linkedin.com/in/meet-patel-0001b51a2/
# Found the URL:https://www.linkedin.com/in/meet329/
# Found the URL:https://www.linkedin.com/in/m-patel/
# Found the URL:https://www.linkedin.com/in/meet-patel-8844a9a3/
# Found the URL:https://www.linkedin.com/in/meet-patel-26948113b/
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-2d97cfdede15> in <module>
#      19         print("Found the URL:"+ url )
#      20     Profile_link=list_url
# ---> 21     result=pd.DataFrame(columns="Link",data=Profile_link)
#      22     #result = result[result.Link != 0]
#      23     result.to_csv("C:/Users/Admin/Desktop/output.csv",mode='a')
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     401                 else:
#     402                     mgr = self._init_ndarray(data, index, columns, dtype=dtype,
# --> 403                                              copy=copy)
#     404             else:
#     405                 mgr = self._init_dict({}, index, columns, dtype=dtype)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _init_ndarray(self, values, index, columns, dtype, copy)
#     525                     raise_with_traceback(e)
#     526
# --> 527         index, columns = _get_axes(*values.shape)
#     528         values = values.T
#     529
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _get_axes(N, K, index, columns)
#     487                 columns = com._default_index(K)
#     488             else:
# --> 489                 columns = _ensure_index(columns)
#     490             return index, columns
#     491
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in _ensure_index(index_like, copy)
#    4972             index_like = copy(index_like)
#    4973
# -> 4974     return Index(index_like)
#    4975
#    4976
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in __new__(cls, data, dtype, copy, name, fastpath, tupleize_cols, **kwargs)
#     435                          **kwargs)
#     436         elif data is None or is_scalar(data):
# --> 437             cls._scalar_data_error(data)
#     438         else:
#     439             if tupleize_cols and is_list_like(data):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in _scalar_data_error(cls, data)
#     895         raise TypeError('{0}(...) must be called with a collection of some '
#     896                         'kind, {1} was passed'.format(cls.__name__,
# --> 897                                                       repr(data)))
#     898
#     899     @classmethod
#
# TypeError: Index(...) must be called with a collection of some kind, 'Link' was passed

# %%
df1 = pd.read_csv("C:/Users/Admin/Desktop/output.csv") 
df1.sort_values("Link", inplace = True)
df1=df1.drop_duplicates(subset=['Link'],keep='first')
print(df1)

# %%
URL="https://www.linkedin.com/search/results/people/?facetSchool=%5B%2210880%22%5D&keywords=Patel%20Het&origin=FACETED_SEARCH"
browser.get(URL)
src = browser.page_source
soup = BeautifulSoup(src, 'lxml')

id=soup.find_all('div',{'class':'search-result__info pt3 pb4 ph0'})
list_url=[]
for a in id:
    url="https://www.linkedin.com"+a.find('a')['href']
    list_url.append(url)
    print("Found the URL:"+ url )
# Out:
# Found the URL:https://www.linkedin.com/in/patel1ik/
# Found the URL:https://www.linkedin.com/in/het-patel-8518a599/
# Found the URL:https://www.linkedin.com/in/het-patel-7629b519a/

# %%
Profile_link=list_url
result=pd.DataFrame(data=Profile_link) 
result.to_csv("C:/Users/Admin/Desktop/output.csv",mode='a')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-6218acc30111> in <module>
# ----> 1 Profile_link=list_url
#       2 result=pd.DataFrame(data=Profile_link)
#       3 result.to_csv("C:/Users/Admin/Desktop/output.csv",mode='a')
#
# NameError: name 'list_url' is not defined

# %%
browser = webdriver.Chrome('C:/Users/Admin/Desktop/LinkedIn-Profile-Scrapper-in-Python-master/chromedriver.exe')
browser.get('https://www.linkedin.com/uas/login')
file = open('config.txt')
lines = file.readlines()
username = lines[0]
password = lines[1]


elementID = browser.find_element_by_id('username')
elementID.send_keys(username)

elementID = browser.find_element_by_id('password')
elementID.send_keys(password)

elementID.submit()

# %%
#link='https://www.linkedin.com/in/pavitrakumar-m-089b51105/'
#link = 'https://www.linkedin.com/in/rishabh-singh-61b706114/'
#link = 'https://www.linkedin.com/in/simran-gandhi-024593128/'
#link = 'https://www.linkedin.com/in/smriti-handa-0636045/'
#link = 'https://www.linkedin.com/in/charan-nadendla-858a17120/'
link = 'https://www.linkedin.com/in/mayank-agrawal-1a5883148/'
browser.get(link)

# %%
SCROLL_PAUSE_TIME = 5

# Get scroll height
last_height = browser.execute_script("return document.body.scrollHeight")

for i in range(3):
    # Scroll down to bottom
    browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = browser.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

# %%
src = browser.page_source
soup = BeautifulSoup(src, 'lxml')
soup
# Out:
# <html class="artdeco windows" lang="en"><head>
# <script async="" src="https://platform.linkedin.com/js/analytics.js"></script><script type="application/javascript">!function(i,n){void 0!==i.addEventListener&&void 0!==i.hidden&&(n.liVisibilityChangeListener=function(){i.hidden&&(n.liHasWindowHidden=!0)},i.addEventListener("visibilitychange",n.liVisibilityChangeListener))}(document,window);</script>
# <title>(7) Mayank Agrawal | LinkedIn</title>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="" name="description"/>
# <meta content="notranslate" name="google"/>
# <meta content="false" name="is-http2"/>
# <meta content="voyager-web" name="service"/>
# <meta content="#0077B5" name="theme-color"/>
# <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0" name="viewport"/>
# <link href="/voyager/manifest.json" rel="manifest"/>
# <link href="https://static-exp1.licdn.com/sc/h/br/92nkhrbn7au12oxnxrta931u4" rel="stylesheet"/>
# <meta content="%7B%22modulePrefix%22%3A%22extended%22%2C%22environment%22%3A%22production%22%2C%22ember-a11y-testing%22%3A%7B%22componentOptions%22%3A%7B%22turnAuditOff%22%3Atrue%2C%22excludeAxeCore%22%3Atrue%2C%22axeOptions%22%3A%7B%22iframes%22%3Afalse%2C%22reporter%22%3A%22v2%22%2C%22resultTypes%22%3A%5B%22violations%22%5D%2C%22rules%22%3A%7B%22duplicate-id%22%3A%7B%22enabled%22%3Afalse%7D%2C%22duplicate-id-active%22%3A%7B%22enabled%22%3Afalse%7D%2C%22duplicate-id-aria%22%3A%7B%22enabled%22%3Afalse%7D%7D%7D%7D%7D%2C%22ember-media-player%22%3A%7B%22lazyLoad%22%3Atrue%7D%2C%22ember-pem%22%3A%7B%22trackingTerminationLixKey%22%3A%22pem.degradation-tracking-kill-switch.voyager-web%22%7D%2C%22rootURL%22%3A%22%2F%22%2C%22routerRootURL%22%3A%22%2F%22%2C%22deviceFormFactor%22%3A%22DESKTOP%22%2C%22emberStrictResolver%22%3Afalse%2C%22locationType%22%3A%22voyager-location%22%2C%22namespace%22%3A%22voyager%2Fapi%22%2C%22EmberENV%22%3A%7B%22FEATURES%22%3A%7B%7D%2C%22_JQUERY_INTEGRATION%22%3Afalse%2C%22_TEMPLATE_ONLY_GLIMMER_COMPONENTS%22%3Afalse%7D%2C%22APP%22%3A%7B%22locale%22%3A%22en_US%22%2C%22rumConfig%22%3A%7B%22pageKeyPrefix%22%3A%22d_%22%2C%22beacon-service%22%3A%22tracking%22%2C%22beacon-url%22%3A%22%2Fli%2Ftrack%22%2C%22event-name%22%3A%22RealUserMonitoringEvent%22%2C%22enable-cdn-tracking%22%3Atrue%2C%22enable-pop-tracking%22%3Atrue%2C%22user-timing-mark-enabled%22%3Atrue%7D%2C%22name%22%3A%22extended%22%2C%22version%22%3A%22voyager-web_1.6.3394%2B64aff349%22%7D%2C%22contentSecurityPolicy%22%3A%7B%22default-src%22%3A%22%5C%22none%5C%22%20*.licdn.com%20*.licdn-ei.com%22%2C%22script-src%22%3A%22%5C%22self%5C%22%20%5C%22unsafe-inline%5C%22%20*.licdn.com%20*.licdn-ei.com%20*.linkedin.com%22%2C%22font-src%22%3A%22%5C%22self%5C%22%20*.licdn.com%20*.licdn-ei.com%20*.slidesharecdn.com%22%2C%22frame-src%22%3A%22*.youtube.com%20*.slideshare.net%22%2C%22connect-src%22%3A%22%5C%22self%5C%22%20localhost%3A*%20*.linkedin.com%22%2C%22img-src%22%3A%22%5C%22self%5C%22%20*.slidesharecdn.com%20*.licdn.com%20*.licdn-ei.com%20spdy.linkedin.com%20spdy.linkedin-ei.com%20*.youtube.com%22%2C%22style-src%22%3A%22%5C%22self%5C%22%20%5C%22unsafe-inline%5C%22%20*.licdn.com%20*.licdn-ei.com%22%2C%22media-src%22%3A%22%5C%22self%5C%22%20*.slidesharecdn.com%20*.licdn.com%20*.licdn-ei.com%22%7D%2C%22tracking%22%3A%7B%22validation%22%3A%7B%22throwOnError%22%3Afalse%7D%2C%22appId%22%3A%22com.linkedin.flagship3.d_web%22%2C%22pageKeyPrefix%22%3A%22d_%22%2C%22pveTrackingInfo%22%3A%7B%22osName%22%3A%22phone_web%22%7D%2C%22impression%22%3A%7B%22timeThreshold%22%3A300%2C%22percentageThreshold%22%3A50%2C%22viewportOffset%22%3A%7B%22top%22%3A52%2C%22bottom%22%3A0%2C%22left%22%3A0%2C%22right%22%3A0%7D%7D%2C%22comScore%22%3A%7B%22enabled%22%3Atrue%7D%7D%2C%22skeleton%22%3A%7B%22data%22%3A%7B%7D%2C%22template%22%3A%22.%2Fskeleton%2Floader.hbs%22%7D%2C%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets%2Fimg%2Fchina-icp-filing.png%22%2C%22assets%2Fimg%2Forganization%2Fdesktop-screenshot.png%22%2C%22assets%2Fimg%2Forganization%2Fmobile-screenshot.png%22%2C%22assets%2Fimg%2Fprofile%2Fdesktop-photo-upload-add-photo.png%22%2C%22assets%2Fhighcharts%2Fhighcharts.js%22%2C%22assets%2Fhighcharts%2Fmodules%2Fmap.js%22%2C%22assets%2Fhighcharts%2Fmodules%2Faccessibility.js%22%2C%22assets%2FcloudSDK%2FOneDriveSDK.js%22%2C%22assets%2FcloudSDK%2FDropboxSDK.js%22%2C%22assets%2Fproj4.js%22%2C%22assets%2Fspectroscopy-worker.js%22%2C%22assets%2Fworld.js%22%2C%22assets%2Fsrc%2Fchartbeat.js%22%2C%22assets%2Fpowerpoint-coach%2FCoachPackage.js%22%2C%22assets%2Ffavicon.ico%22%2C%22assets%2Ffavicon-notification.ico%22%2C%22assets%2Fimg%2Fhiring%2Fonboarding%2Fnew-poster-desktop-modal-image%402x.png%22%2C%22assets%2Fimg%2Fpremium%2Fproducts%2Fslides%2Fjob_seeker_featured_applicant_650x468_v1.png%22%2C%22assets%2Fimg%2Fpremium%2Fproducts%2Fslides%2Fjob_seeker_inmail_650x468_v1.png%22%2C%22assets%2Fimg%2Fpremium%2Fproducts%2Fslides%2Fjob_seeker_job_insights_650x468_v1.png%22%2C%22assets%2Fi ...
# <!-- EMBER_CLI_FASTBOOT_TITLE --><!-- EMBER_CLI_FASTBOOT_HEAD -->
# <meta content="en_US" name="i18nDefaultLocale"/>
# <meta content="en_US" name="i18nLocale"/>
# <meta content="https://static-exp1.licdn.com/sc/h/br/aanly5o5blk5l977rvjksluux" name="i18nIntlPolyfillUrl"/>
# <meta content="ca" name="requestIpCountryCode"/>
# <meta content="urn:li:page:bpr;wC3Wi44yRPG9+ybU+4lfvw==" name="bprPageInstance"/>
# <meta content='{"applicationUrn": "urn:li:application:(voyager-web,voyager-web)", "version": "1.6.3394", "trackingId": [65, 30, 111, 67, -49, 45, 69, 106, -106, -44, -37, -113, 45, -126, 123, 117]}' name="applicationInstance"/>
# <meta content="eOEaY4fmRvm/PH9Tkbe4OQ==" name="clientPageInstanceId"/>
# <meta content="voyager-web" name="service"/>
# <meta content="i001" name="serviceInstance"/>
# <meta content="1.6.3394" name="serviceVersion"/>
# <link href="https://static-exp1.licdn.com/sc/h/1bt1uwq5akv756knzdj4l6cdc" id="favicon-ico" rel="shortcut icon"/>
# <link href="https://static-exp1.licdn.com/sc/h/2if24wp7oqlodqdlgei1n1520" rel="apple-touch-icon"/>
# <link href="https://static-exp1.licdn.com/sc/h/eahiplrwoq61f4uan012ia17i" rel="apple-touch-icon-precomposed"/>
# <link href="https://static-exp1.licdn.com/sc/h/2if24wp7oqlodqdlgei1n1520" rel="apple-touch-icon-precomposed" sizes="57x57"/>
# <link href="https://static-exp1.licdn.com/sc/h/eahiplrwoq61f4uan012ia17i" rel="apple-touch-icon-precomposed" sizes="144x144"/>
# <link href="https://static-exp1.licdn.com/sc/h/br/14vz2btbo9e9uigtfjestnzb3" rel="stylesheet"/>
# <link href="https://static-exp1.licdn.com/sc/h/br/tcybthu5johy0maognhzskez" rel="stylesheet"/>
# <meta content='{"assets/img/china-icp-filing.png":"https://static-exp1.licdn.com/sc/h/cbn91jpp9vuid7olk3y6qmbpj","assets/img/organization/desktop-screenshot.png":"https://static-exp1.licdn.com/sc/h/ev2ewp91pnvtl0gcyt4xht0b5","assets/img/organization/mobile-screenshot.png":"https://static-exp1.licdn.com/sc/h/3v3wzhnr3kapuzwpk1zt6r1jt","assets/img/profile/desktop-photo-upload-add-photo.png":"https://static-exp1.licdn.com/sc/h/c5ybm82ti04zuasz2a0ubx7bu","assets/highcharts/highcharts.js":"https://static-exp1.licdn.com/sc/h/br/3gz6uyw7tnqpbhl8fe277swbp","assets/highcharts/modules/map.js":"https://static-exp1.licdn.com/sc/h/br/emp4qn95u3dapai0gby9efjak","assets/highcharts/modules/accessibility.js":"https://static-exp1.licdn.com/sc/h/br/7j8d68spn8mp00zhl3vmqcka3","assets/cloudSDK/OneDriveSDK.js":"https://static-exp1.licdn.com/sc/h/br/45bhd02gokyndidefhx1ptdvt","assets/cloudSDK/DropboxSDK.js":"https://static-exp1.licdn.com/sc/h/br/874gdyhk2zgt1hdrm1rvxih7g","assets/proj4.js":"https://static-exp1.licdn.com/sc/h/br/a52rm6mz15bfb6b25ex2fl8mr","assets/spectroscopy-worker.js":"https://static-exp1.licdn.com/sc/h/br/69miyr75u4gp5utz4wgun9dya","assets/world.js":"https://static-exp1.licdn.com/sc/h/br/2s51vhg4vrr7k24sjaop3o56b","assets/src/chartbeat.js":"https://static-exp1.licdn.com/sc/h/br/dudi1lzgkt9xq5lg3f0j1c66p","assets/powerpoint-coach/CoachPackage.js":"https://static-exp1.licdn.com/sc/h/br/5bgqmlfah2j3phsfvchqusuiv","assets/favicon.ico":"https://static-exp1.licdn.com/sc/h/al2o9zrvru7aqj8e1x2rzsrca","assets/favicon-notification.ico":"https://static-exp1.licdn.com/sc/h/1bt1uwq5akv756knzdj4l6cdc","assets/img/hiring/onboarding/new-poster-desktop-modal-image@2x.png":"https://static-exp1.licdn.com/sc/h/ewdoimk3v63x2o3nsi6rharus","assets/img/premium/products/slides/job_seeker_featured_applicant_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/6gl4ufmcgffyhuu4lti3us9mr","assets/img/premium/products/slides/job_seeker_inmail_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/194ufzr1ibusivbechyc149ox","assets/img/premium/products/slides/job_seeker_job_insights_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/b9qvh5p1l68rq61pvb6f3dpin","assets/img/premium/products/slides/job_seeker_professional_learning_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/75zb38b8070xlgfvx5ta8ksg5","assets/img/premium/products/slides/job_seeker_professional_wvmp_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/85swj4u5h27rp1gv0gtu5568","assets/img/premium/products/slides/job_seeker_resume_builder_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/b7ybzpxcq6ma06b6jrssqcu5v","assets/img/premium/products/slides/job_seeker_interview_prep_648x468_v1.png":"https://static-exp1.licdn.com/sc/h/dxj16dv0q0dlpveh17ftnocke","assets/img/premium/products/slides/learning_certificates_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/583fidw259ymymoncldari2wo","assets/img/premium/products/slides/learning_experts_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/c6188n1g55fuxv51sx0ldfc9a","assets/img/premium/products/slides/learning_practice_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/cu8z4dheitoo3j58t2hzsnriu","assets/img/premium/products/slides/learning_recommendations_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/czbqzystj2cf6vcdikti5qpxl","assets/img/premium/products/slides/learning_time_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/f13ctg6tjp7cnaf9orkc9m1lz","assets/img/premium/products/slides/learning_topics_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/eazvcix8vc8qb5vead285sqcq","assets/img/premium/products/slides/learning_unlimited_access_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/ctrkfni1bhv3uyokx49xwtr3o","assets/img/premium/products/slides/professional_browse_profiles_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/1ehgbakjab9ljkoavygzhtoa3","assets/img/premium/products/slides/professional_company_research_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/2wxmom0vvkzhp4tfdd0cpa4ib","assets/img/premium/products/slides ...
# <meta content="none" name="liamOrLisa"/>
# <meta content='{"lix":{"voyager.client.engage-flash-dynamic-text-size":{"testKey":"voyager.client.engage-flash-dynamic-text-size","treatment":"control","trackingInfo":{"segmentIndex":2,"experimentId":2951206,"treatmentIndex":0,"urn":"urn:li:member:801379952"}},"voyager.web.mbc.organization-people-card":{"testKey":"voyager.web.mbc.organization-people-card","treatment":"control","trackingInfo":{"segmentIndex":1,"experimentId":2967303,"treatmentIndex":0,"urn":"urn:li:member:801379952"}},"voyager.web.feed.text-view-model-migration-sponsored":{"testKey":"voyager.web.feed.text-view-model-migration-sponsored","treatment":"control","trackingInfo":null},"voyager.web.jobs-in-feed-link-opens-tab":{"testKey":"voyager.web.jobs-in-feed-link-opens-tab","treatment":"control","trackingInfo":{"segmentIndex":1,"experimentId":2918225,"treatmentIndex":0,"urn":"urn:li:member:801379952"}},"voyager.web.nav.job-posting-jobs-led-entry-points":{"testKey":"voyager.web.nav.job-posting-jobs-led-entry-points","treatment":"control","trackingInfo":null},"voyager.web.premium-welcome-flow-opt-in-card":{"testKey":"voyager.web.premium-welcome-flow-opt-in-card","treatment":"control","trackingInfo":{"segmentIndex":2,"experimentId":2974706,"treatmentIndex":0,"urn":"urn:li:member:801379952"}},"voyager.web.jobs-home-post-free-job":{"testKey":"voyager.web.jobs-home-post-free-job","treatment":"control","trackingInfo":null},"voyager.jobs.web.post-apply.check-skill-assessments-with-lego":{"testKey":"voyager.jobs.web.post-apply.check-skill-assessments-with-lego","treatment":"enabled","trackingInfo":null},"voyager.iac.web.import-communities":{"testKey":"voyager.iac.web.import-communities","treatment":"control","trackingInfo":null},"voyager.web.premium-upsell-card-reactivate-compliance":{"testKey":"voyager.web.premium-upsell-card-reactivate-compliance","treatment":"control","trackingInfo":null},"voyager.web.infraux-mercado-theme":{"testKey":"voyager.web.infraux-mercado-theme","treatment":"control","trackingInfo":null},"voyager.web.groups-metadata":{"testKey":"voyager.web.groups-metadata","treatment":"enabled","trackingInfo":null},"voyager.web.organization-company-jobs-disable-job-alert":{"testKey":"voyager.web.organization-company-jobs-disable-job-alert","treatment":"enabled","trackingInfo":null},"voyager.client.engage-omakase-minimum-refresh-interval":{"testKey":"voyager.client.engage-omakase-minimum-refresh-interval","treatment":"control","trackingInfo":{"segmentIndex":1,"experimentId":2967348,"treatmentIndex":0,"urn":"urn:li:member:801379952"}},"voyager.web.jobs-search-jymbii":{"testKey":"voyager.web.jobs-search-jymbii","treatment":"enabled","trackingInfo":{"segmentIndex":1,"experimentId":2926241,"treatmentIndex":1,"urn":"urn:li:member:801379952"}},"voyager.video.web.settings-modal":{"testKey":"voyager.video.web.settings-modal","treatment":"thumbnail_captions","trackingInfo":null},"voyager.web.search-jobs-pill-to-jymbii":{"testKey":"voyager.web.search-jobs-pill-to-jymbii","treatment":"control","trackingInfo":{"segmentIndex":1,"experimentId":2943759,"treatmentIndex":0,"urn":"urn:li:member:801379952"}},"voyager.web.premium.sales-nav-for-professionals-nav-identity-upsell":{"testKey":"voyager.web.premium.sales-nav-for-professionals-nav-identity-upsell","treatment":"control","trackingInfo":null},"voyager.web.search-enable-events-vertical":{"testKey":"voyager.web.search-enable-events-vertical","treatment":"control","trackingInfo":null},"voyager.web.jobs-search-get-salary-data":{"testKey":"voyager.web.jobs-search-get-salary-data","treatment":"control","trackingInfo":null},"voyager.client.engage-revenue-sponsored-commentary-line-count":{"testKey":"voyager.client.engage-revenue-sponsored-commentary-line-count","treatment":"enabled","trackingInfo":{"segmentIndex":2,"experimentId":2828600,"treatmentIndex":1,"urn":"urn:li:member:801379952"}},"voyager.messaging.web.valhalla-send-message-requests":{"testKey":"voyager.messaging.web.valhalla-send-message-requests","treatment":"enabled"," ...
# <meta content="false" name="isGuest"/>
# <meta data-mode="BIGPIPE" name="renderingMode"/>
# <meta content="12000" name="bigpipeResponseTimeout"/>
# <meta content="false" name="bigpipeJetRethrowError"/>
# <meta content='["static\\.licdn\\.com","media\\.licdn\\.com","voyager/api/typeahead/hits"]' name="bigpipeBlacklistUrls"/>
# <meta content="false" name="isQueryTunnelRequestSupported"/>
# <script src="https://static-exp1.licdn.com/sc/h/br/35ggkijo61ertszeggzb888kt"></script>
# <meta content="qTwBnaaABhZAPY8eISsAAA==" name="treeID"/>
# <meta content="%7B%7D" name="abi/config/environment"/>
# <meta content="%7B%7D" name="article-reader/config/environment"/>
# <meta content="%7B%7D" name="career-services/config/environment"/>
# <meta content="%7B%7D" name="colleagues/config/environment"/>
# <meta content="%7B%7D" name="company-creation/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="events/config/environment"/>
# <meta content="%7B%7D" name="feed/config/environment"/>
# <meta content="%7B%7D" name="feed-detail/config/environment"/>
# <meta content="%7B%7D" name="feed-shared/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="groups/config/environment"/>
# <meta content="%7B%7D" name="hiring/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="inshare/config/environment"/>
# <meta content="%7B%7D" name="interview-prep/config/environment"/>
# <meta content="%7B%7D" name="jobs/config/environment"/>
# <meta content="%7B%22googleAnalytics%22%3A%7B%22trackingId%22%3A%22UA-62256447-1%22%7D%7D" name="jobs-search/config/environment"/>
# <meta content="%7B%7D" name="lead-capture/config/environment"/>
# <meta content="%7B%7D" name="me/config/environment"/>
# <meta content="%7B%7D" name="me-ca/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="messaging/config/environment"/>
# <meta content="%7B%7D" name="msg-conversation-ui/config/environment"/>
# <meta content="%7B%7D" name="msg-mentions/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="msg-overlay/config/environment"/>
# <meta content="%7B%7D" name="msg-referrals/config/environment"/>
# <meta content="%7B%7D" name="msg-rich-media/config/environment"/>
# <meta content="%7B%7D" name="msg-shared-modals/config/environment"/>
# <meta content="%7B%7D" name="msg-spinmail/config/environment"/>
# <meta content="%7B%7D" name="msg-ui-base/config/environment"/>
# <meta content="%7B%7D" name="mynetwork/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="news/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="notifications/config/environment"/>
# <meta content="%7B%7D" name="onboarding/config/environment"/>
# <meta content="%7B%7D" name="opportunities/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="organization/config/environment"/>
# <meta content="%7B%7D" name="organization-about/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="organization-admin/config/environment"/>
# <meta content="%7B%7D" name="organization-content-suggestions/config/environment"/>
# <meta content="%7B%7D" name="organization-employee-experience/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="organization-events/config/environment"/>
# <meta content="%7B%7D" name="organization-insights/config/environment"/>
# <meta content="%7B%7D" name="organization-jobs/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="organization-life/config/environment"/>
# <meta content="%7B%7D" name="organization-people/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="organization-videos/config/environment"/>
# <meta content="%7B%7D" name="participate-text-editor/config/environment"/>
# <meta content="%7B%7D" name="premium/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="products/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="profile/config/environment"/>
# <meta content="%7B%22environment%22%3A%22production%22%2C%22ember-a11y-testing%22%3A%7B%22componentOptions%22%3A%7B%22turnAuditOff%22%3Atrue%2C%22excludeAxeCore%22%3Atrue%2C%22axeOptions%22%3A%7B%22iframes%22%3Afalse%2C%22reporter%22%3A%22v2%22%2C%22resultTypes%22%3A%5B%22violations%22%5D%2C%22rules%22%3A%7B%22duplicate-id%22%3A%7B%22enabled%22%3Afalse%7D%2C%22duplicate-id-active%22%3A%7B%22enabled%22%3Afalse%7D%2C%22duplicate-id-aria%22%3A%7B%22enabled%22%3Afalse%7D%7D%7D%7D%7D%7D" name="profile-edit/config/environment"/>
# <meta content="%7B%7D" name="profile-ge/config/environment"/>
# <meta content="%7B%7D" name="profile-opportunities/config/environment"/>
# <meta content="%7B%7D" name="profile-search-analytics/config/environment"/>
# <meta content="%7B%7D" name="profile-skill-assessments/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="profile-subroutes/config/environment"/>
# <meta content="%7B%7D" name="profile-tetris/config/environment"/>
# <meta content="%7B%7D" name="publishing/config/environment"/>
# <meta content="%7B%7D" name="publishing-entity/config/environment"/>
# <meta content="%7B%7D" name="resume-builder/config/environment"/>
# <meta content="%7B%7D" name="salary/config/environment"/>
# <meta content="%7B%7D" name="search/config/environment"/>
# <meta content="%7B%7D" name="service-marketplace/config/environment"/>
# <meta content="%7B%7D" name="sharing-v2/config/environment"/>
# <meta content="%7B%7D" name="slideshare-migration/config/environment"/>
# <meta content="%7B%7D" name="tenor-gif/config/environment"/>
# <meta content="%7B%7D" name="unemployment/config/environment"/>
# <meta content="%7B%7D" name="video-engine/config/environment"/>
# <meta content="%7B%7D" name="workflow/config/environment"/>
# <meta content="https://static-exp1.licdn.com/sc/h/5jh8oqp921no2o6ymoa6uy1wl" id="artdeco-icons/static/images/icons.svg" name="asset-url"/>
# <meta content='{"bundles":{"abi":{"assets":[{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/3q0w9tbx515dearscy7jftne"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/50saacujiio3i69qg3vaxjtqt"},{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/3nbx0xk6px3u9pmm9bynqbydb"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/dm7e089oqm10qv3h63lax5w1k"}],"dependencies":[]},"article-reader":{"assets":[{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/e7l2vmhkwkuxm30f310vp3j4k"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/2clj3b8s29kpue2iy2opeucf9"},{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/65m15w0wlbondwx4w6fou5dtn"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/24067md6xf93mgu4wtnkhlq68"}],"dependencies":["feed-shared"]},"career-services":{"assets":[{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/6dp2puqu86tn7qazpfs36rigg"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/9k5wr2d913rxn3xs5sazw59b1"},{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/e3bfq4h859mdaani0lxsssofr"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/dn34fxhhlkxqikt1vi3j3nrl1"}],"dependencies":[]},"colleagues":{"assets":[{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/5tpzwych5xmgobz2n3x50h1ny"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/6ap9b689uafoejsrhb4w2jcip"},{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/4xbukgju3k92xkzx3kl3an6dy"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/dvmlfp8mn2xyci667p1kzhdoa"}],"dependencies":[]},"company-creation":{"assets":[{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/41zyp5odbew50h6c3kszpdgry"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/9zniq8y48vg9oyvqak9mblwgb"},{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/2bysimtcg7bkmmwyoir2m5wj6"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/abk3zqeqqsqh9i0f016hplmgt"}],"dependencies":[]},"content-analytics":{"assets":[],"dependencies":null},"events":{"assets":[{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/b816paq87g1jodd01zo44axgf"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/r9duvom6gx93fxw1ggqiqv04"},{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/dyimpn84emvp4ephoxs8gl53u"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/ahb5s3nkmgac91fbct6opgkrx"},{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/curlhe9tst2wdbcrjovvrkr2w"}],"dependencies":["feed-shared"]},"feed-detail":{"assets":[{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/ce3aqd20vffmjcn38pt0rdtzs"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/e7f52rqyt98e4p6k7dxcneewi"},{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/41fyc78qeut4he7puvsmftuso"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/5fz44udcxg84ear3340ek7lkf"},{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/curlhe9tst2wdbcrjovvrkr2w"}],"dependencies":["feed","feed-shared"]},"feed-shared":{"assets":[{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/ajpuitk8kggz4r4w3bseb5b8z"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/bbu1kvl38dm1n4xjq9qe644rq"},{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/ikfork6yg5ye4wuzg00mxigy"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/6wictemcdvjd1s6f9wgfgre4j"}],"dependencies":null},"feed":{"assets":[{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/bhncv6ypybigkdvddw65qlo9m"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/bj70t6yo8634h83587phd6beb"},{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/dvk55113s1h9qxby5p8vtduxc"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/r9lncke78n34lddplz5dz0ee"},{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/curlhe9tst2wdbcrjovvrkr2w"}],"dependencies":["feed-shared"]},"groups":{"assets":[{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/2lt74tvrr679gybi ...
# <link href="https://static-exp1.licdn.com/sc/h/br/1kv9ly1fzl3szylfshrrpzi2s" rel="stylesheet"/><link href="https://static-exp1.licdn.com/sc/h/br/f0gvekzmdx352zw3ialhxr7e6" rel="stylesheet"/><link href="https://static-exp1.licdn.com/sc/h/br/bbu1kvl38dm1n4xjq9qe644rq" rel="stylesheet"/><link href="https://static-exp1.licdn.com/sc/h/br/6wictemcdvjd1s6f9wgfgre4j" rel="stylesheet"/>
# <link class="lazy-css" href="https://static-exp1.licdn.com/sc/h/br/cgwh2iw7inro80jzlw9qhdd4t" rel="stylesheet"/>
# <style>%INLINE_CRITICAL_STYLES%</style>
# <meta content="app-id=288429040, affiliate-data=ct=campaign_vw_smart_app_banner&amp;pt=10746, app-argument=voyager://in/mayank-agrawal-1a5883148/?trk=vw_smart_app_banner" name="apple-itunes-app"/>
# <script src="https://static-exp1.licdn.com/sc/h/br/148p4n13ta5whecszis6vx9q7"></script><script src="https://static-exp1.licdn.com/sc/h/br/62oy72vi67uwqdhgh9vbvzbh6"></script><link href="https://static-exp1.licdn.com/sc/h/br/276j42m0zb0mckgzcnyna2r3q" rel="stylesheet"/><script src="https://static-exp1.licdn.com/sc/h/br/3hjb904darxvr8j0cious78jz"></script><link href="https://static-exp1.licdn.com/sc/h/br/cl2oax4c9690ge81vh4a5yh1v" rel="stylesheet"/><script src="https://static-exp1.licdn.com/sc/h/br/babao4w2jizjyg6os404ggn0j"></script><link href="https://static-exp1.licdn.com/sc/h/br/6cqnsafi8nupqnco5h0xogb6x" rel="stylesheet"/><script src="https://static-exp1.licdn.com/sc/h/br/coa7f3ykpl4n59lxspa6n42h5"></script><script src="https://static-exp1.licdn.com/sc/h/br/a3xx8n4xh6vflvngqxxd05c61"></script><link href="https://static-exp1.licdn.com/sc/h/br/7qshs74coqub3x1n0q18oxicc" rel="stylesheet"/><script src="https://static-exp1.licdn.com/sc/h/br/axg8p67lhh8kebmml5ohld06n"></script><link href="https://static-exp1.licdn.com/sc/h/br/dwidosgxj6iugdot4ko86c32h" rel="stylesheet"/><script src="https://static-exp1.licdn.com/sc/h/br/a1nmzey2yx7vi2dqmdv2x7aeq"></script><link href="https://static-exp1.licdn.com/sc/h/br/5l7z99xtkg7e5qmah3faq7ni5" rel="stylesheet"/><script src="https://static-exp1.licdn.com/sc/h/br/56qlxptzvuv1fgp2uzt6536ns"></script><link href="https://static-exp1.licdn.com/sc/h/br/44oq6lv8jxhx0pkr2sfzwztvf" rel="stylesheet"/><script src="https://static-exp1.licdn.com/sc/h/br/en18rzzofxe5l132z19tcoy1r"></script><link href="https://static-exp1.licdn.com/sc/h/br/d06ba1clihzhc86z8w8zi86ji" rel="stylesheet"/></head>
# <body class="render-mode-BIGPIPE nav-v2 theme theme--classic ember-application boot-complete icons-loaded" data-t-link-to-event-attached="true" dir="ltr">
# <!-- HUED-11420 -->
# <div id="artdeco-toasts__wormhole"> <section class="artdeco-toasts" id="artdeco-toasts">
# <header class="artdeco-toasts__header">
# <h2 class="artdeco-toasts__title">
#         0 notifications total
#       </h2>
# </header>
# <!-- -->
# <ul aria-atomic="true" aria-live="assertive" class="artdeco-toasts_toasts">
# <!-- --> </ul>
# </section>
# </div>
# <div id="a11y-menu"> <div class="a11y-menu-container ember-view" id="ember16"><button class="mr4 artdeco-button artdeco-button--muted artdeco-button--2 artdeco-button--secondary ember-view" id="ember17"><!-- -->
# <span class="artdeco-button__text">
#     Skip to search
# </span></button>
# <a class="artdeco-button artdeco-button--muted artdeco-button--secondary" data-ember-action="" data-ember-action-18="18" href="#skip-link">
#   Skip to main content
# </a>
# <button class="a11y-menu__close artdeco-button artdeco-button--circle artdeco-button--muted artdeco-button--2 artdeco-button--tertiary ember-view" id="ember19"> <li-icon aria-hidden="true" class="artdeco-button__icon" type="cancel-icon"><svg data-supported-dps="24x24" fill="currentColor" focusable="false" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M20 5.32L13.32 12 20 18.68 18.66 20 12 13.33 5.34 20 4 18.68 10.68 12 4 5.32 5.32 4 12 10.69 18.68 4z"></path>
# </svg></li-icon>
# <span class="artdeco-button__text">
#     Close jump menu
# </span></button>
# </div>
# </div><header class="extended-nav nav-main-container global-alert-offset-top is-loading-nav" data-test-main-nav="" id="extended-nav" role="banner" style="display: block;" tabindex="-1"><div class="nav-main__content full-height display-flex align-items-center"><div class="nav-main__inbug-container"><div class="nav-item--inbug" id="inbug-nav-item" lang="en"><a class="nav-item__link js-nav-item-link" data-alias="" data-control-name="" data-link-to="feed" data-resource="feed/badge" href="/feed/"><span class="nav-item__icon nav-item__icon--inbug" lang="en" role="presentation"><li-icon aria-hidden="true" color="brand" size="34dp" type="linkedin-bug"><svg focusable="false" preserveaspectratio="xMinYMin meet" xmlns="http://www.w3.org/2000/svg"><g class="scaling-icon" style="fill-opacity: 1"><defs></defs><g class="bug-14dp" fill="none" fill-rule="evenodd" stroke="none" stroke-width="1"><g class="dp-1"><path class="bug-text-color" d="M14,1.25 L14,12.75 C14,13.44 13.44,14 12.75,14 L1.25,14 C0.56,14 0,13.44 0,12.75 L0,1.25 C0,0.56 0.56,0 1.25,0 L12.75,0 C13.44,0 14,0.56 14,1.25" fill="#FFFFFF"></path><path class="background" d="M14,1.25 L14,12.75 C14,13.44 13.44,14 12.75,14 L1.25,14 C0.56,14 0,13.44 0,12.75 L0,1.25 C0,0.56 0.56,0 1.25,0 L12.75,0 C13.44,0 14,0.56 14,1.25 Z M5,5 L6.85,5 L6.85,6.016 L6.893,6.016 C7.259,5.541 8.018,4.938 9.25,4.938 C11.125,4.938 12,5.808 12,8 L12,12 L10,12 L10,8.75 C10,7.313 9.672,6.875 8.632,6.875 C7.5,6.875 7,7.75 7,9 L7,12 L5,12 L5,5 Z M2,12 L4,12 L4,5 L2,5 L2,12 Z M4.335,3 C4.335,3.737 3.737,4.335 3,4.335 C2.263,4.335 1.665,3.737 1.665,3 C1.665,2.263 2.263,1.665 3,1.665 C3.737,1.665 4.335,2.263 4.335,3 Z" fill="#0073B2"></path></g><g class="dpi-gt1" transform="scale(0.2917)"><rect class="bug-text-color" fill="#FFFFFF" height="46" rx="4" width="46" x="1" y="1"></rect><path class="background" d="M0,4.00989318 C0,1.79529033 1.79405245,0 4.00989318,0 L43.9901068,0 C46.2047097,0 48,1.79405245 48,4.00989318 L48,43.9901068 C48,46.2047097 46.2059475,48 43.9901068,48 L4.00989318,48 C1.79529033,48 0,46.2059475 0,43.9901068 L0,4.00989318 Z M19,18.3 L25.5,18.3 L25.5,21.566 C26.437,19.688 28.838,18 32.445,18 C39.359,18 41,21.738 41,28.597 L41,41.3 L34,41.3 L34,30.159 C34,26.253 33.063,24.05 30.68,24.05 C27.375,24.05 26,26.425 26,30.159 L26,41.3 L19,41.3 L19,18.3 Z M7,41 L14,41 L14,18 L7,18 L7,41 Z M15,10.5 C15,12.985 12.985,15 10.5,15 C8.015,15 6,12.985 6,10.5 C6,8.015 8.015,6 10.5,6 C12.985,6 15,8.015 15,10.5 Z" fill="#0077B5"></path></g></g><g class="bug-21dp" fill="none" fill-rule="evenodd" stroke="none" stroke-width="1"><g class="dp-1"><path class="bug-text-color" d="M19.479,0 L1.583,0 C0.728,0 0,0.677 0,1.511 L0,19.488 C0,20.323 0.478,21 1.333,21 L19.229,21 C20.086,21 21,20.323 21,19.488 L21,1.511 C21,0.677 20.336,0 19.479,0" fill="#FFFFFF"></path><path class="background" d="M19.479,0 L1.583,0 C0.728,0 0,0.677 0,1.511 L0,19.488 C0,20.323 0.478,21 1.333,21 L19.229,21 C20.086,21 21,20.323 21,19.488 L21,1.511 C21,0.677 20.336,0 19.479,0 Z M8,8 L10.827,8 L10.827,9.441 L10.858,9.441 C11.289,8.664 12.562,7.875 14.136,7.875 C17.157,7.875 18,9.479 18,12.45 L18,18 L15,18 L15,12.997 C15,11.667 14.469,10.5 13.227,10.5 C11.719,10.5 11,11.521 11,13.197 L11,18 L8,18 L8,8 Z M3,18 L6,18 L6,8 L3,8 L3,18 Z M6.375,4.5 C6.375,5.536 5.536,6.375 4.5,6.375 C3.464,6.375 2.625,5.536 2.625,4.5 C2.625,3.464 3.464,2.625 4.5,2.625 C5.536,2.625 6.375,3.464 6.375,4.5 Z" fill="#0077B5"></path></g><g class="dpi-gt1" transform="scale(0.4375)"><rect class="bug-text-color" fill="#FFFFFF" height="46" rx="4" width="46" x="1" y="1"></rect><path class="background" d="M0,4.00989318 C0,1.79529033 1.79405245,0 4.00989318,0 L43.9901068,0 C46.2047097,0 48,1.79405245 48,4.00989318 L48,43.9901068 C48,46.2047097 46.2059475,48 43.9901068,48 L4.00989318,48 C1.79529033,48 0,46.2059475 0,43.9901068 L0,4.00989318 Z M19,18.3 L25.5,18.3 L25.5,21.566 C26.437,19.688 28.838,18 32.445,18 C39.359,18 41,21.738 41,28.597 L41,41.3 L34,41.3 L34,30.159 C34,26.253 33.063,24.05  ...
# <div class="search-global-typeahead ember-view" id="ember42"><div class="search-typeahead-v2 search-global-typeahead__typeahead ember-view" id="global-nav-typeahead"> <div class="ember-view" id="ember44"><input aria-activedescendant="" aria-autocomplete="list" aria-expanded="false" aria-label="Search" aria-owns="" class="search-global-typeahead__input always-show-placeholder" placeholder="Search" role="combobox" type="text"/></div>
# <!-- -->
# </div><div class="search-global-typeahead__controls">
# <button class="search-global-typeahead__button" data-control-name="nav.search_button" data-ember-action="" data-ember-action-45="45" tabindex="-1" type="button">
# <li-icon aria-label="i18n_search_button" class="search-global-typeahead__icon" role="img" size="medium" type="search-icon"><svg data-supported-dps="24x24" fill="currentColor" focusable="false" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M21 19.67l-5.44-5.44a7 7 0 10-1.33 1.33L19.67 21zm-11-4.54A5.13 5.13 0 1115.13 10 5.13 5.13 0 0110 15.13z"></path>
# </svg></li-icon>
# </button>
# </div>
# <div class="ember-view" id="ember46"><!-- --></div>
# </div>
# </div>
# </div></div></form><nav aria-label="Primary" class="display-flex full-height" data-nav="main"><ul class="nav-main nav-container display-flex full-height"><li class="nav-item nav-item--feed" id="feed-nav-item" lang="en"><a class="nav-item__link nav-item__link--underline js-nav-item-link" data-alias="" data-control-name="" data-link-to="feed" data-resource="feed/badge" href="/feed/"><span class="nav-item__badge nav-item__badge--doughnut"><span aria-hidden="true" class="nav-item__badge-count">3</span><span class="visually-hidden">3</span></span><span class="nav-item__icon" id="feed-tab-icon" lang="en" role="presentation"><li-icon aria-hidden="true" color="true" type="nav-small-home-icon"><svg class="nav-icon" focusable="false" height="24px" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" xmlns="http://www.w3.org/2000/svg" y="0"><path class="active-item" d="M22,8.45L12.85,2.26a1.5,1.5,0,0,0-1.69,0L2,8.45,3.06,10,4,9.37V19a1,1,0,0,0,1,1h5V15h4v5h5a1,1,0,0,0,1-1V9.37L20.94,10Z" style="fill-opacity: 1"></path><path class="inactive-item" d="M22,9.45L12.85,3.26a1.5,1.5,0,0,0-1.69,0L2,9.45,3.06,11,4,10.37V20a1,1,0,0,0,1,1h6V16h2v5h6a1,1,0,0,0,1-1V10.37L20.94,11ZM18,19H15V15a1,1,0,0,0-1-1H10a1,1,0,0,0-1,1v4H6V8.89l6-4,6,4V19Z" style="fill: currentColor"></path></svg></li-icon></span><span class="nav-item__title">Home</span></a></li><li class="nav-item nav-item--mynetwork" id="mynetwork-nav-item" lang="en"><a class="nav-item__link nav-item__link--underline js-nav-item-link" data-alias="relationships" data-control-name="" data-link-to="mynetwork" data-resource="voyagerCommunicationsTabBadges" href="/mynetwork/"><span class="nav-item__badge"><span aria-hidden="true" class="nav-item__badge-count">1</span><span class="visually-hidden">1 new network update.</span></span><span class="nav-item__icon" id="mynetwork-tab-icon" lang="en" role="presentation"><li-icon aria-hidden="true" color="true" type="nav-small-people-icon"><svg class="nav-icon" focusable="false" height="24px" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" xmlns="http://www.w3.org/2000/svg" y="0"><path class="active-item" d="M16,17.85V20a1,1,0,0,1-1,1H1a1,1,0,0,1-1-1V17.85a4,4,0,0,1,2.55-3.73l2.95-1.2V11.71l-0.73-1.3A6,6,0,0,1,4,7.47V6a4,4,0,0,1,4.39-4A4.12,4.12,0,0,1,12,6.21V7.47a6,6,0,0,1-.77,2.94l-0.73,1.3v1.21l2.95,1.2A4,4,0,0,1,16,17.85Zm4.75-3.65L19,13.53v-1a6,6,0,0,0,1-3.31V9a3,3,0,0,0-6,0V9.18a6,6,0,0,0,.61,2.58A3.61,3.61,0,0,0,16,13a3.62,3.62,0,0,1,2,3.24V21h4a1,1,0,0,0,1-1V17.47A3.5,3.5,0,0,0,20.75,14.2Z" style="fill-opacity: 1"></path><path class="inactive-item" d="M20.74,14.2L19,13.54V12.86l0.25-.41A5,5,0,0,0,20,9.82V9a3,3,0,0,0-6,0V9.82a5,5,0,0,0,.75,2.63L15,12.86v0.68l-1,.37a4,4,0,0,0-.58-0.28l-2.45-1V10.83A8,8,0,0,0,12,7V6A4,4,0,0,0,4,6V7a8,8,0,0,0,1,3.86v1.84l-2.45,1A4,4,0,0,0,0,17.35V20a1,1,0,0,0,1,1H22a1,1,0,0,0,1-1V17.47A3.5,3.5,0,0,0,20.74,14.2ZM16,8.75a1,1,0,0,1,2,0v1.44a3,3,0,0,1-.38,1.46l-0.33.6a0.25,0.25,0,0,1-.22.13H16.93a0.25,0.25,0,0,1-.22-0.13l-0.33-.6A3,3,0,0,1,16,10.19V8.75ZM6,5.85a2,2,0,0,1,4,0V7.28a6,6,0,0,1-.71,2.83L9,10.72a1,1,0,0,1-.88.53H7.92A1,1,0,0,1,7,10.72l-0.33-.61A6,6,0,0,1,6,7.28V5.85ZM14,19H2V17.25a2,2,0,0,1,1.26-1.86L7,13.92v-1a3,3,0,0,0,1,.18H8a3,3,0,0,0,1-.18v1l3.72,1.42A2,2,0,0,1,14,17.21V19Zm7,0H16V17.35a4,4,0,0,0-.55-2l1.05-.4V14.07a2,2,0,0,0,.4.05h0.2a2,2,0,0,0,.4-0.05v0.88l2.53,1a1.5,1.5,0,0,1,1,1.4V19Z" style="fill: currentColor"></path></svg></li-icon></span><span class="nav-item__title">My Network</span></a></li><li class="nav-item nav-item--jobs" id="jobs-nav-item" lang="en"><a class="nav-item__link nav-item__link--underline js-nav-item-link" data-alias="" data-control-name="" data-link-to="jobs" data-resource="" href="/jobs/"><span class="nav-item__icon" id="jobs-tab-icon" lang="en" role="presentation"><li-icon aria-hidden="true" color="true" type="nav-small-jobs-icon"><svg class="nav-icon" focusable="false" height="24px" preserveaspectratio="xMinYMin meet" viewbox="0 0  ...
# <artdeco-dropdown class="nav-item__dropdown ember-view" id="nav-settings__dropdown"><artdeco-dropdown-trigger aria-expanded="false" class="nav-item__link nav-item__dropdown-trigger t-14 t-black--light t-bold ember-view" data-control-name="nav.settings" id="ember26" placement="bottom" role="button" tabindex="0"> <img alt="mike patel" class="nav-item__profile-member-photo nav-item__icon ghost-person ember-view" height="24" id="ember27" src="..." width="24"/>
# <div class="nav-item__title-container">
# <span class="nav-item__title nav-item__dropdown-trigger--title">Me</span>
# <li-icon aria-hidden="true" class="nav-item__dropdown-trigger--icon" size="small" type="caret-filled-down-icon"><svg data-supported-dps="16x16" fill="currentColor" focusable="false" height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
# <path d="M8.8 10.66L14 5.12a.07.07 0 00-.07-.12H2.07a.07.07 0 00-.07.12l5.2 5.54a1.1 1.1 0 001.6 0z"></path>
# </svg></li-icon>
# </div>
# <!-- --></artdeco-dropdown-trigger><artdeco-dropdown-content aria-hidden="true" class="nav-settings__dropdown-options ember-view" data-dropdown="" id="ember28" justification="right" placement="bottom" tabindex="-1"><div class="artdeco-dropdown__content-inner">
# <ul class="nav-settings__dropdown-options container-with-shadow">
# <li class="nav-settings__topcard nav-settings__no-hover">
# <a class="nav-settings__dropdown-item-link nav-settings__view-profile-link block clearfix ember-view" data-control-name="nav.settings_view_profile" href="/in/mike-patel-6684691a4/" id="ember29"> <div class="nav-settings__member nav-settings__block">
# <div class="nav-settings__member-photo-container">
# <img alt="mike patel" class="nav-settings__member-photo EntityPhoto-circle-4 ghost-person ember-view" height="70" id="ember30" src="..." width="70"/>
# </div>
# <div class="nav-settings__member-info-container">
# <!-- --> <h3 class="nav-settings__member-name t-16 t-black t-bold">
#                 mike patel
#               </h3>
# <h4 class="nav-settings__member-occupation t-14 t-black--light t-normal">
#                 Student at University of Windsor
#               </h4>
# </div>
# </div>
# <div class="nav-settings__linkcard nav-settings__block">
# <span class="artdeco-button artdeco-button--tertiary artdeco-button--fluid">
#               View profile
#             </span>
# </div>
# </a> </li>
# <!-- -->
# <li class="nav-settings__dropdown-options--account nav-settings__dropdown-options nav-settings__no-hover">
# <h5 class="nav-dropdown__title nav-settings__dropdown-title t-14 t-black t-bold">Account</h5>
# <ul class="nav-settings__dropdown-items">
# <li class="nav-dropdown__item nav-settings__dropdown-item t-14">
# <a class="nav-settings__dropdown-item-link block t-black--light t-bold ember-view" data-control-name="nav.settings_account_manage_account" href="https://www.linkedin.com/psettings/" id="ember32" rel="noopener noreferrer" tabindex="0" target="_blank">                    Settings &amp; Privacy
# </a> </li>
# <li class="nav-dropdown__item nav-settings__dropdown-item t-14">
# <button class="nav-settings__dropdown-item-link nav-settings__dropdown-button-link t-14 t-black--light t-bold block" data-control-name="quick-help-action-button" data-ember-action="" data-ember-action-34="34" type="button">
#                     Help
#                   </button>
# </li>
# <li class="nav-dropdown__item nav-settings__dropdown-item t-14">
# <a class="nav-settings__dropdown-item-link block t-black--light t-bold ember-view" data-control-name="nav.settings_account_language" href="https://www.linkedin.com/psettings/select-language" id="ember36" rel="noopener noreferrer" tabindex="0" target="_blank">                    Language
# </a> </li>
# </ul>
# </li>
# <li class="nav-settings__dropdown-options--manage nav-settings__no-hover">
# <h5 class="nav-dropdown__title nav-settings__dropdown-title t-14 t-black t-bold">Manage</h5>
# <ul class="nav-settings__dropdown-items">
# <li class="nav-dropdown__item nav-settings__dropdown-item t-14">
# <a class="nav-settings__dropdown-item-link nav-settings__manage-link nav-settings__view-activity-link block t-black--light t-bold ember-view" data-control-name="recent_activity_nav_all" href="/in/mike-patel-6684691a4/detail/recent-activity/" id="ember37">                  Posts &amp; Activity
# </a> </li>
# <li class="nav-dropdown__item nav-settings__dropdown-item t-14">
# <a class="nav-settings__dropdown-item-link block nav-settings__manage-link t-black--light t-bold ember-view" data-control-name="nav.settings_manage_job_posting_account" href="https://www.linkedin.com/job/consumer/manageConsumer?trk=nav_app_launcher_manage_job_post_nept" id="ember39" rel="noopener noreferrer" tabindex="0" target="_blank">                      Job posting account
# </a> </li>
# </ul>
# </li>
# <!-- -->
# <li class="nav-settings__dropdown-options--actions nav-settings__no-hover">
# <ul class="nav-settings__dropdown-items">
# <li class="nav-dropdown__item nav-settings__dropdown-item nav-dropdown__action t-14 t-bold">
# <a class="nav-settings__dropdown-item-link block t-black--light t-bold ember-view" data-control-name="nav.settings_signout" href="/m/logout/" id="ember41">                Sign out
# </a> </li>
# </ul>
# </li>
# </ul>
# </div>
# </artdeco-dropdown-content></artdeco-dropdown>
# </div>
# </li><li class="nav-item nav-item--app-launcher" id="app-launcher-nav-item"> <div class="nav-item__content">
# <div class="ember-view" id="ember22"><button class="nav-item__link nav-panel__trigger " data-control-name="nav.launcher" data-ember-action="" data-ember-action-23="23">
# <li-icon aria-label="Work icon" class="nav-item__icon" role="img" type="grid-icon"><svg data-supported-dps="24x24" fill="currentColor" focusable="false" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M10 10h4v4h-4v-4zm0 11h4v-4h-4v4zm-7-7h4v-4H3v4zm0 7h4v-4H3v4zM3 7h4V3H3v4zm14 7h4v-4h-4v4zm0-11v4h4V3h-4zm-7 4h4V3h-4v4zm7 14h4v-4h-4v4z"></path>
# </svg></li-icon>
# <div class="nav-item__title-container">
# <span class="nav-item__title nav-item__dropdown-trigger--title">Work</span>
# <li-icon aria-hidden="true" class="nav-item__dropdown-trigger--icon" size="small" type="caret-filled-down-icon"><svg data-supported-dps="16x16" fill="currentColor" focusable="false" height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
# <path d="M8.8 10.66L14 5.12a.07.07 0 00-.07-.12H2.07a.07.07 0 00-.07.12l5.2 5.54a1.1 1.1 0 001.6 0z"></path>
# </svg></li-icon>
# </div>
# </button>
# <div class="ember-view" id="ember24"><!-- --></div></div> </div>
# </li><li class="nav-item nav-item--spotlight-one nav-item__spotlight" id="spotlight-one-nav-item"> <div class="nav-item__wormhole">
# <div class="nav-item__content t-14 t-black t-normal premium-upsell-link ember-view" id="ember20">
# <a class="link-without-visited-state nav-item__spotlight-upsell premium-upsell-link--long ember-view" data-control-name="premium_nav_upsell_text_click" href="/premium/products/?destRedirectURL=https%3A%2F%2Fwww.linkedin.com%2Fin%2Fmayank-agrawal-1a5883148%2F%3FshowPremiumWelcomeBanner%3Dtrue&amp;upsellOrderOrigin=premium_nav_upsell_text" id="ember21">        Try Premium Free for 1 Month
# <!-- --></a></div>
# </div>
# </li></ul></nav></div></header>
# <!-- EMBER_CLI_FASTBOOT_BODY -->
# <script src="https://static-exp1.licdn.com/sc/h/br/d0a0lb0tiq5qpenxgc4ps5hbz"></script>
# <script nomodule="" src="https://static-exp1.licdn.com/sc/h/br/1id8ixboa6ibb8do33ac7j0l4"></script>
# <script src="https://static-exp1.licdn.com/sc/h/br/44lpm3xommt4uaobb0rsjjk0w"></script>
# <div class="app-boot-bg-skeleton" id="app-boot-bg-loader">
# <div class="top-bar"></div>
# <div class="content">
# <div class="initial-load-animation fade-load">
# <div class="linkedin-image">
# ...
# </a>
# <p class="global-footer__label t-12">Go to your Settings.</p>
# </span>
# </li>
# </ul>
# <div class="grid__col grid__col--6">
# <label class="global-footer__label t-12 t-normal mb1 mt0" for="globalfooter-select_language">
#             Select Language
#           </label>
# <div class="ember-view" id="ember326"><select class="global-footer__language-selection-dropdown t-12 t-black--light t-bold" id="globalfooter-select_language">
# <option lang="in-ID" value="in_ID">Bahasa Indonesia (Bahasa Indonesia)</option>
# <option lang="ms-MY" value="ms_MY">Bahasa Malaysia (Malay)</option>
# <option lang="cs-CZ" value="cs_CZ">Čeština (Czech)</option>
# <option lang="da-DK" value="da_DK">Dansk (Danish)</option>
# <option lang="de-DE" value="de_DE">Deutsch (German)</option>
# <option lang="en-US" value="en_US">English (English)</option>
# <option lang="es-ES" value="es_ES">Español (Spanish)</option>
# <option lang="zh-TW" value="zh_TW">正體中文 (Chinese (Traditional))</option>
# <option lang="fr-FR" value="fr_FR">Français (French)</option>
# <option lang="ko-KR" value="ko_KR">한국어 (Korean)</option>
# <option lang="it-IT" value="it_IT">Italiano (Italian)</option>
# <option lang="zh-CN" value="zh_CN">简体中文 (Chinese (Simplified))</option>
# <option lang="nl-NL" value="nl_NL">Nederlands (Dutch)</option>
# <option lang="ja-JP" value="ja_JP">日本語 (Japanese)</option>
# <option lang="no-NO" value="no_NO">Norsk (Norwegian)</option>
# <option lang="pl-PL" value="pl_PL">Polski (Polish)</option>
# <option lang="pt-BR" value="pt_BR">Português (Portuguese)</option>
# <option lang="ro-RO" value="ro_RO">Română (Romanian)</option>
# <option lang="ru-RU" value="ru_RU">Русский (Russian)</option>
# <option lang="sv-SE" value="sv_SE">Svenska (Swedish)</option>
# <option lang="tl-PH" value="tl_PH">Tagalog (Tagalog)</option>
# <option lang="th-TH" value="th_TH">ภาษาไทย (Thai)</option>
# <option lang="tr-TR" value="tr_TR">Türkçe (Turkish)</option>
# <option lang="ar-AE" value="ar_AE">العربية (Arabic)</option>
# </select>
# </div>
# </div>
# </div>
# <p class="t-12 t-black--light t-normal text-align-left clear-both" id="globalfooter-copyright">
#         LinkedIn Corporation © 2020
#       </p>
# </div>
# </div></footer>
# </div>
# </div>
# <!-- -->
# <!-- -->
# </div>
# </div>
# </div>
# </div>
# <aside class="msg-overlay-container ember-view" id="msg-overlay"><!-- -->
# <div class="mh4 msg-overlay-list-bubble ember-view" id="ember139" tabindex="-1"><header class="msg-overlay-bubble-header msg-overlay-bubble-header--inverse msg-overlay-bubble-header--is-badged" data-control-name="overlay.minimize_connection_list_bar" data-ember-action="" data-ember-action-140="140">
# <div class="ember-view" id="ember141"><!-- --></div>
# <section class="msg-overlay-bubble-header__details flex-row align-items-center">
# <div class="presence-entity presence-entity--size-1 ember-view" id="ember142"><img alt="mike patel" class=" presence-entity__image EntityPhoto-circle-1 lazy-image ghost-person loaded ember-view" id="ember143" loading="lazy" src="..." title="mike patel"/>
# <div class=" presence-entity__indicator presence-entity__indicator--size-1 presence-indicator presence-indicator--is-online presence-indicator--size-1 ember-view" id="ember144">
# <span class="visually-hidden">
#     Status is online
# </span></div></div>
# <button class="msg-overlay-bubble-header__button truncate ml2">
# <h4 class="truncate t-14 t-bold t-white">
# <span aria-hidden="true">
#           Messaging
#         </span>
# <span class="visually-hidden">
#           You are on the messaging overlay. Press enter to minimize it.
#         </span>
# </h4>
# </button>
# <mark aria-hidden="true" class="msg-overlay-bubble-header__unread-count">
# <abbr title="You have 1 unseen message">
#           1
#         </abbr>
# </mark>
# <!-- --> </section>
# <section class="msg-overlay-bubble-header__controls display-flex">
# <button class="msg-overlay-bubble-header__control msg-overlay-bubble-header__control--new-convo-btn artdeco-button artdeco-button--circle artdeco-button--inverse artdeco-button--1 artdeco-button--tertiary ember-view" data-control-name="overlay.compose_message" id="ember145"> <li-icon aria-hidden="true" class="artdeco-button__icon" size="small" type="compose-icon"><svg data-supported-dps="16x16" fill="currentColor" focusable="false" height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
# <path d="M11 8.75l2-2V13a1 1 0 01-1 1H3a1 1 0 01-1-1V4a1 1 0 011-1h6.25l-2 2H4v7h7V8.75zm-5-.16L5 11l2.41-1 5.49-5.48-1.42-1.42zm8.85-6.73l-.71-.71a.5.5 0 00-.71 0l-1.18 1.19 1.41 1.41 1.19-1.19a.5.5 0 000-.71z"></path>
# </svg></li-icon>
# <span class="artdeco-button__text">
#     Compose message
# </span></button>
# <artdeco-dropdown class="ember-view" id="ember146">
# <artdeco-dropdown-trigger aria-expanded="false" class="artdeco-button artdeco-button--1 artdeco-button--circle artdeco-button--tertiary artdeco-button--inverse ember-view" data-control-name="overlay.dropdown_menu" id="ember147" placement="bottom" role="button" tabindex="0">
# <li-icon aria-label="Open messenger dropdown menu" color="true" role="img" size="small" type="ellipsis-horizontal-icon"><svg data-supported-dps="16x16" fill="currentColor" focusable="false" height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
# <path d="M2 7h2v2H2V7zm5 2h2V7H7v2zm5-2v2h2V7h-2z"></path>
# </svg></li-icon>
# <!-- --></artdeco-dropdown-trigger>
# <div class="msg-overlay-bubble-header__dropdown-container">
# <artdeco-dropdown-content aria-hidden="true" arrow-dir="right" class="artdeco-dropdown-with-arrow ember-view" data-dropdown="" id="ember148" justification="right" placement="bottom" tabindex="-1"><div class="artdeco-dropdown__content-inner">
# <ul class="white-space-nowrap">
# <!-- --> <artdeco-dropdown-item class="ember-view" data-control-name="overlay.compose_group" data-dropdown="" id="ember149" tabindex="0"><!-- -->
#               New group conversation
#             </artdeco-dropdown-item>
# <!-- --> <artdeco-dropdown-item class="ember-view" data-control-name="overlay.connection_list_settings_from_dropdown" data-dropdown="" id="ember150" tabindex="0"><!-- -->
#               Messaging settings
#             </artdeco-dropdown-item>
# <artdeco-dropdown-item class="ember-view" data-dropdown="" id="ember151" tabindex="0"><!-- -->
#                 Message request inbox
#               </artdeco-dropdown-item>
# <!-- --> </ul>
# </div>
# </artdeco-dropdown-content>
# </div>
# </artdeco-dropdown>
# </section>
# </header>
# <div class="msg-overlay-list-bubble-search ember-view" id="ember155"><div class="msg-overlay-list-bubble-search__input-container">
# <label class="a11y-text" for="msg-overlay-list-bubble-search__search-typeahead-input">
#     Type to search for connections and conversations.
#   </label>
# <li-icon aria-hidden="true" class="msg-overlay-list-search__search-icon" size="small" type="search-icon"><svg data-supported-dps="16x16" fill="currentColor" focusable="false" height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
# <path d="M14 12.67L11.13 9.8a5 5 0 10-1.33 1.33L12.67 14zM3.88 7A3.13 3.13 0 117 10.13 3.13 3.13 0 013.88 7z"></path>
# </svg></li-icon>
# <input autocomplete="off" class="msg-overlay-list-bubble-search__search-typeahead-input ember-text-field ember-view" id="msg-overlay-list-bubble-search__search-typeahead-input" placeholder="Search messages" type="text"/>
# <artdeco-dropdown class="msg-overlay-list-bubble__filters-dropdown ember-view" id="ember157">
# <artdeco-dropdown-trigger aria-expanded="false" class="msg-overlay-list-bubble__filters-btn ember-view" id="ember158" placement="bottom" role="button" tabindex="0">
# <li-icon aria-label="Filter messages by" role="img" size="small" type="filter-icon"><svg data-supported-dps="16x16" fill="currentColor" focusable="false" height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
# <path d="M15 2v2H6.72a2 2 0 01-3.44 0H1V2h2.28a2 2 0 013.44 0H15zm-4 4a2 2 0 00-1.72 1H1v2h8.28a2 2 0 003.45 0H15V7h-2.28A2 2 0 0011 6zm-6 5a2 2 0 00-1.72 1H1v2h2.28a2 2 0 003.45 0H15v-2H6.72A2 2 0 005 11z"></path>
# </svg></li-icon>
# <!-- --></artdeco-dropdown-trigger>
# <artdeco-dropdown-content aria-hidden="true" arrow-dir="right" class="msg-overlay-list-bubble__filters-dropdown-content artdeco-dropdown-with-arrow ember-view" data-dropdown="" id="ember159" justification="right" placement="bottom" tabindex="-1"><div class="artdeco-dropdown__content-inner">
# <ul>
# <li class="msg-overlay-list-bubble__filters-dropdown-content-list-item">
# <artdeco-dropdown-item class="artdeco-selected ember-view" data-dropdown="" id="ember160" tabindex="0"> <span class="artdeco-sr-only">Selected</span>
#
#             All Messages
#           </artdeco-dropdown-item>
# </li>
# <li class="msg-overlay-list-bubble__filters-dropdown-content-list-item">
# <artdeco-dropdown-item class="ember-view" data-dropdown="" id="ember161" tabindex="0"><!-- -->
#             Archived
#           </artdeco-dropdown-item>
# </li>
# <li class="msg-overlay-list-bubble__filters-dropdown-content-list-item">
# <artdeco-dropdown-item class="ember-view" data-dropdown="" id="ember162" tabindex="0"><!-- -->
#             My Connections
#           </artdeco-dropdown-item>
# </li>
# <li class="msg-overlay-list-bubble__filters-dropdown-content-list-item">
# <artdeco-dropdown-item class="ember-view" data-dropdown="" id="ember163" tabindex="0"><!-- -->
#             Unread
#           </artdeco-dropdown-item>
# </li>
# <li class="msg-overlay-list-bubble__filters-dropdown-content-list-item">
# <artdeco-dropdown-item class="ember-view" data-dropdown="" id="ember164" tabindex="0"><!-- -->
#             InMail
#           </artdeco-dropdown-item>
# </li>
# <li class="msg-overlay-list-bubble__filters-dropdown-content-list-item">
# <artdeco-dropdown-item class="ember-view" data-dropdown="" id="ember165" tabindex="0"><!-- -->
#             Spam
#           </artdeco-dropdown-item>
# </li>
# </ul>
# </div>
# </artdeco-dropdown-content>
# </artdeco-dropdown>
# <!-- --><!-- --><!-- --></div>
# <div class="msg-overlay-list-bubble-search-content hidden">
# <div class="msg-overlay-list-bubble-search__history-placeholder-container text-align-center">
# <div class="msg-overlay-list-bubble-search__history-placeholder-illustration"></div>
# <p class="t-12 t-black--light t-normal ph2">
#             Search your messages by recipient, content, or conversation name
#           </p>
# </div>
# </div></div>
# <section class="msg-overlay-list-bubble__content msg-overlay-list-bubble__content--scrollable">
# <div class="msg-overlay-list-bubble-default-conversation-container">
# <!-- --> <span class="visually-hidden">
#               Attention screen reader users, messaging items continuously update. Please use the tab and shift + tab keys instead of your up and down arrow keys to navigate between messaging items.
#             </span>
# <!-- --><!-- --> <div class="msg-conversations-container__conversations-list msg-overlay-list-bubble__conversations-list">
# <div class="msg-overlay-list-bubble__convo-item--hoverable msg-overlay-list-bubble__convo-item ember-view" data-control-name="overlay.view_message" id="ember233" role="button" tabindex="0"><div class="msg-conversation-listitem__link msg-overlay-list-bubble__convo-item-link">
# <div class="msg-conversation-card msg-overlay-list-bubble__convo-card">
# <div class="msg-facepile-grid msg-facepile-grid--no-facepile msg-facepile-grid--small ember-view" id="ember235"> <img alt="LinkedIn Member" class="lazy-image msg-facepile-grid__img msg-facepile-grid__img--person loaded ember-view" id="ember237" loading="lazy" src="https://media-exp1.licdn.com/dms/image/C560CAQHyRqDKV1P_ZQ/spinmail-customsender-displayphoto-shrink_100_100/0?e=1587186000&amp;v=beta&amp;t=gssquYVP1sKeoAVNIH44iKSxWHLCzJ-QiW4S6DZOuSQ"/>
# </div>
# <div class="msg-overlay-list-bubble__convo-card-content overflow-hidden">
# <div class="msg-overlay-list-bubble__convo-card-content-wrapper fl msg-overlay-list-bubble__convo-card-content-wrapper--narrow">
# <!-- --> <div class="msg-conversation-card__row">
# <h4 class="msg-conversation-listitem__participant-names msg-conversation-card__participant-names truncate t-14 t-black t-bold">
#               Jen &amp; the Sales Navigator Team
#           </h4>
# </div>
# <div class="msg-conversation-card__row">
# <p class="msg-overlay-list-bubble__message-snippet msg-overlay-participant-headline m0 truncate t-12 t-black t-bold">
# <span class="ember-view" id="ember238">
# <span class="msg-conversation-card__pill t-14 t-black t-bold pr1">
#     LinkedIn Offer •
#   </span>
#   Thanks for being an active LinkedIn member
# </span>
# </p>
# </div>
# </div>
# <div class="msg-conversation-card__conversation-status fr pl2 align-items-center flex-grow-1">
# <!-- --> <mark class="msg-conversation-card__unread-count">
# <abbr title="1 unread message">
#                 1
#               </abbr>
# </mark>
# </div>
# </div>
# </div>
# </div></div>
# <div class="msg-overlay-list-bubble__convo-item--hoverable msg-overlay-list-bubble__convo-item ember-view" data-control-name="overlay.view_message" id="ember240" role="button" tabindex="0"><div class="msg-conversation-listitem__link msg-overlay-list-bubble__convo-item-link">
# <div class="msg-conversation-card msg-overlay-list-bubble__convo-card">
# <div class="msg-facepile-grid msg-facepile-grid--no-facepile msg-facepile-grid--small ember-view" id="ember242"> <img alt="{:actorName}" class="lazy-image msg-facepile-grid__img msg-facepile-grid__img--company loaded ember-view" id="ember244" loading="lazy" src="https://media-exp1.licdn.com/dms/image/C560BAQFZ55VnGlGUrw/company-logo_100_100/0?e=1595462400&amp;v=beta&amp;t=A3LHU-HMtRRdzrnzpPwgu0YNCuLmMp0AiWN2chleUm8"/>
# </div>
# <div class="msg-overlay-list-bubble__convo-card-content overflow-hidden">
# <div class="msg-overlay-list-bubble__convo-card-content-wrapper fl ">
# <!-- --> <div class="msg-conversation-card__row">
# <h4 class="msg-conversation-listitem__participant-names msg-conversation-card__participant-names truncate t-14 t-black t-normal">
#               Australian Institute of Business
#           </h4>
# </div>
# <div class="msg-conversation-card__row">
# <p class="msg-overlay-list-bubble__message-snippet msg-overlay-participant-headline m0 truncate t-12 t-black t-normal">
# <span class="ember-view" id="ember245">
# <span class="msg-conversation-card__pill t-14 t-black t-bold pr1">
#     Sponsored •
#   </span>
#   The Australian MBA program for Canadians
# </span>
# </p>
# </div>
# </div>
# <div class="msg-conversation-card__conversation-status fr pl2 align-items-center flex-grow-1">
# <!-- --><!-- --> </div>
# </div>
# </div>
# </div></div>
# </div>
# <!-- --> <div class="msg-overlay-list-bubble__loader hidden">
# <artdeco-loader class="artdeco-loader ember-view" id="ember246" size="small"><!-- --><span class="artdeco-spinner--bars"></span>
# <span class="artdeco-spinner--bars"></span>
# <span class="artdeco-spinner--bars"></span>
# <span class="artdeco-spinner--bars"></span>
# <span class="artdeco-spinner--bars"></span>
# <span class="artdeco-spinner--bars"></span>
# <span class="artdeco-spinner--bars"></span>
# <span class="artdeco-spinner--bars"></span>
# <span class="artdeco-spinner--bars"></span>
# <span class="artdeco-spinner--bars"></span>
# <span class="artdeco-spinner--bars"></span>
# <span class="artdeco-spinner--bars"></span></artdeco-loader>
# </div>
# </div>
# </section>
# <!-- --></div>
# <!-- --></aside>
# <img class="third-party-tracking-pixel hidden ember-view" id="ember152" src="https://px.ads.linkedin.com/collect/?pid=6883&amp;fmt=gif&amp;_t=1587097374478"/>
# </div>
# <div id="li-modal-container"></div>
# <div id="artdeco-hoverable-outlet"></div>
# <div class="entity-hovercard-container hidden ember-view" id="ember13"><div class="entity-hovercard p4" role="tooltip" tabindex="-1">
# <section class="entity-hovercard__loading-state">
#       Loading…
#     </section>
# </div>
# </div>
# <!-- -->
# <!-- -->
# <div class="type-ahead type-ahead-wormhole" id="type-ahead-wormhole">
# </div>
# <div class="toast-wormhole" id="toast-wormhole">
# </div>
# <!-- -->
# <div class="ember-view" id="ember14"><!-- --></div>
# </div></body></html>

# %%
name_div = soup.find('div', {'class': 'flex-1 mr5'})
name_div
# Out:
# <div class="flex-1 mr5">
# <ul class="pv-top-card--list inline-flex align-items-center">
# <li class="inline t-24 t-black t-normal break-words">
#             Mayank Agrawal
#           </li>
# <li class="pv-top-card__distance-badge inline-block v-align-text-bottom t-16 t-black--light t-normal"><span class="distance-badge separator">
# <span class="visually-hidden">3rd degree connection</span><span aria-hidden="true" class="dist-value">3rd</span>
# </span></li>
# <li class="inline-flex ml2">
# <span class="pv-member-badge--for-top-card inline-flex pv-member-badge ember-view" id="ember93" style="display: none;"><!-- -->
# <!-- -->
# <span class="visually-hidden">
#   Mayank has a  account
# </span>
# <!-- --></span>
# </li>
# </ul>
# <h2 class="mt1 t-18 t-black t-normal">
#             Competitive Coder
#           </h2>
# <ul class="pv-top-card--list pv-top-card--list-bullet mt1">
# <li class="t-16 t-black t-normal inline-block">
#               West Midnapore, West Bengal, India
#             </li>
# <!-- -->
# <li class="inline-block">
# <span class="t-16 t-black t-normal">
#                   500+ connections
#                 </span>
# </li>
# <li class="inline-block">
# <a class="ember-view" data-control-name="contact_see_more" href="/in/mayank-agrawal-1a5883148/detail/contact-info/" id="ember94"> <span class="t-16 t-bold">
#                 Contact info
#               </span>
# </a> </li>
# </ul>
# </div>

# %%
name_loc = name_div.find_all('ul')
name = name_loc[0].find('li').get_text().strip()
name
# Out:
# 'Mayank Agrawal'

# %%
loc = name_loc[1].find('li').get_text().strip()
loc
# Out:
# 'West Midnapore, West Bengal, India'

# %%
profile_title = name_div.find('h2').get_text().strip()
profile_title
# Out:
# 'Competitive Coder'

# %%
connection = name_loc[1].find_all('li')
connection = connection[1].get_text().strip()
connection
# Out:
# '500+ connections'

# %%
info = []
info.append(link)
info.append(name)
info.append(profile_title)
info.append(loc)
info.append(connection)
info
# Out:
# ['https://www.linkedin.com/in/mayank-agrawal-1a5883148/',
#  'Mayank Agrawal',
#  'Competitive Coder',
#  'West Midnapore, West Bengal, India',
#  '500+ connections']

# %% [markdown]
# ### Experience

# %%
exp_section = soup.find('section', {'id': 'experience-section'})
#exp_section

# %%
exp_section = exp_section.find('ul')
#exp_section

# %%
new_data=soup.find_all('h3',{'class':'t-16 t-black t-bold'})
new_data
# Out:
# [<h3 class="t-16 t-black t-bold">Secretary Indoor Games</h3>]

# %%
li_tags = exp_section.find('div')
a_tags = li_tags.find('a')
#a_tags

# %%
#a_tags

# %%
job_title = a_tags.find('h3').get_text().strip()
job_title
# Out:
# 'Secretary Indoor Games'

# %%
company_name = a_tags.find_all('p')[1].get_text().strip()
company_name
# Out:
# 'Rajendra Prasad Hall of Residence'

# %%
joining_date = a_tags.find_all('h4')[0].find_all('span')[1].get_text().strip()
joining_date
# Out:
# 'Jul 2018 – Apr 2019'

# %%
exp = a_tags.find_all('h4')[1].find_all('span')[1].get_text().strip()
exp
# Out:
# '10 mos'

# %%
info
# Out:
# ['https://www.linkedin.com/in/mayank-agrawal-1a5883148/',
#  'Mayank Agrawal',
#  'Competitive Coder',
#  'West Midnapore, West Bengal, India',
#  '500+ connections']

# %%
info.append(company_name)
info.append(job_title)
info.append(joining_date)
info.append(exp)

# %%
info
# Out:
# ['https://www.linkedin.com/in/mayank-agrawal-1a5883148/',
#  'Mayank Agrawal',
#  'Competitive Coder',
#  'West Midnapore, West Bengal, India',
#  '500+ connections',
#  'Rajendra Prasad Hall of Residence',
#  'Secretary Indoor Games',
#  'Jul 2018 – Apr 2019',
#  '10 mos']

# %% [markdown]
# ### Education

# %%
edu_section = soup.find('section', {'id': 'education-section'}).find('ul')
edu_section
# Out:
# <ul class="pv-profile-section__section-info section-info pv-profile-section__section-info--has-no-more">
# <li class="pv-profile-section__list-item pv-education-entity pv-profile-section__card-item ember-view" id="441026069"><div class="display-flex justify-space-between full-width">
# <div class="display-flex flex-column full-width">
# <a class="ember-view" data-control-name="background_details_school" href="/school/13500/?legacySchoolId=13500" id="ember265"> <div class="pv-entity__logo">
# <img alt="Indian Institute of Technology, Kharagpur" class="pv-entity__logo-img pv-entity__logo-img EntityPhoto-square-4 lazy-image loaded ember-view" id="ember267" loading="lazy" src="https://media-exp1.licdn.com/dms/image/C4E0BAQHbYxMF7lBoDg/company-logo_100_100/0?e=1595462400&amp;v=beta&amp;t=5qpzYnPae6JxnOOsF1ovgt3AMt70Boixq2tmZyJ9d1c"/>
# </div>
# <div class="pv-entity__summary-info pv-entity__summary-info--background-section">
# <div class="pv-entity__degree-info">
# <h3 class="pv-entity__school-name t-16 t-black t-bold">Indian Institute of Technology, Kharagpur</h3>
# <p class="pv-entity__secondary-title pv-entity__degree-name t-14 t-black t-normal">
# <span class="visually-hidden">Degree Name</span>
# <span class="pv-entity__comma-item">Btech in Mechanical Engineering &amp; MTech in Financial Engineering</span>
# </p>
# <!-- --> <p class="pv-entity__secondary-title pv-entity__grade t-14 t-black t-normal">
# <span class="visually-hidden">Grade</span>
# <span class="pv-entity__comma-item">9.07</span>
# </p>
# </div>
# <p class="pv-entity__dates t-14 t-black--light t-normal">
# <span class="visually-hidden">Dates attended or expected graduation</span>
# <span>
# <time>2017</time> – <time>2022</time>
# </span>
# </p>
# <!-- --></div>
# </a>
# <!-- --> </div>
# <!-- --></div>
# </li>
# </ul>

# %%
college_name = edu_section.find('h3').get_text().strip()
college_name
# Out:
# 'Indian Institute of Technology, Kharagpur'

# %%
degree_name = edu_section.find('p', {'class': 'pv-entity__secondary-title pv-entity__degree-name t-14 t-black t-normal'}).find_all('span')[1].get_text().strip()
degree_name
# Out:
# 'Btech in Mechanical Engineering & MTech in Financial Engineering'

# %%
stream = edu_section.find('p', {'class': 'pv-entity__secondary-title pv-entity__fos t-14 t-black t-normal'}).find_all('span')[1].get_text().strip()
stream
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-d337ab31eede> in <module>
# ----> 1 stream = edu_section.find('p', {'class': 'pv-entity__secondary-title pv-entity__fos t-14 t-black t-normal'}).find_all('span')[1].get_text().strip()
#       2 stream
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
degree_year = edu_section.find('p', {'class': 'pv-entity__dates t-14 t-black--light t-normal'}).find_all('span')[1].get_text().strip()
degree_year

# %%
info
# Out:
# ['https://www.linkedin.com/in/mayank-agrawal-1a5883148/',
#  'Mayank Agrawal',
#  'Competitive Coder',
#  'West Midnapore, West Bengal, India',
#  '500+ connections',
#  'Rajendra Prasad Hall of Residence',
#  'Secretary Indoor Games',
#  'Jul 2018 – Apr 2019',
#  '10 mos']

# %%
info.append(college_name)
info.append(degree_name)
#info.append(stream)
#info.append(degree_year)

# %%
info
# Out:
# ['https://www.linkedin.com/in/mayank-agrawal-1a5883148/',
#  'Mayank Agrawal',
#  'Competitive Coder',
#  'West Midnapore, West Bengal, India',
#  '500+ connections',
#  'Rajendra Prasad Hall of Residence',
#  'Secretary Indoor Games',
#  'Jul 2018 – Apr 2019',
#  '10 mos',
#  'Indian Institute of Technology, Kharagpur',
#  'Btech in Mechanical Engineering & MTech in Financial Engineering',
#  'Indian Institute of Technology, Kharagpur',
#  'Btech in Mechanical Engineering & MTech in Financial Engineering',
#  'Indian Institute of Technology, Kharagpur',
#  'Btech in Mechanical Engineering & MTech in Financial Engineering']
