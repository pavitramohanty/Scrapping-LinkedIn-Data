# %%
import requests, time, random
from bs4 import BeautifulSoup
from selenium import webdriver

# %%
browser = webdriver.Chrome('C:/Users/Admin/Desktop/LinkedIn-Profile-Scrapper-in-Python-master/chromedriver.exe')
browser.get('https://www.linkedin.com/uas/login')
file = open('config.txt')
lines = file.readlines()
username = lines[0]
password = lines[1]


elementID = browser.find_element_by_id('username')
elementID.send_keys(username)

elementID = browser.find_element_by_id('password')
elementID.send_keys(password)

elementID.submit()

# %%
#link='https://www.linkedin.com/in/pavitrakumar-m-089b51105/'
#link = 'https://www.linkedin.com/in/rishabh-singh-61b706114/'
link = 'https://www.linkedin.com/in/simran-gandhi-024593128/'
#link = 'https://www.linkedin.com/in/smriti-handa-0636045/'
#link = 'https://www.linkedin.com/in/charan-nadendla-858a17120/'
#link = 'https://www.linkedin.com/in/mayank-agrawal-1a5883148/'
browser.get(link)

# %%
SCROLL_PAUSE_TIME = 5

# Get scroll height
last_height = browser.execute_script("return document.body.scrollHeight")

for i in range(3):
    # Scroll down to bottom
    browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = browser.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

# %%
src = browser.page_source
soup = BeautifulSoup(src, 'lxml')
soup
# Out:
# <html class="artdeco windows" lang="en"><head>
# <script async="" src="https://platform.linkedin.com/js/analytics.js"></script><script type="application/javascript">!function(i,n){void 0!==i.addEventListener&&void 0!==i.hidden&&(n.liVisibilityChangeListener=function(){i.hidden&&(n.liHasWindowHidden=!0)},i.addEventListener("visibilitychange",n.liVisibilityChangeListener))}(document,window);</script>
# <meta charset="utf-8"/>
# <meta content="voyager-web" name="service"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>(6) Simran Gandhi | LinkedIn</title>
# <meta content="" name="description"/>
# <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0" name="viewport"/>
# <meta content="#0077B5" name="theme-color"/>
# <meta content="true" name="is-http2"/>
# <meta content="notranslate" name="google"/>
# <link href="/voyager/manifest.json" rel="manifest"/>
# <link href="https://static-exp1.licdn.com/sc/h/br/ezz12qztjwpfdu4ofj3thea0u" rel="stylesheet"/>
# <meta content="%7B%22modulePrefix%22%3A%22extended%22%2C%22environment%22%3A%22production%22%2C%22ember-a11y-testing%22%3A%7B%22componentOptions%22%3A%7B%22turnAuditOff%22%3Atrue%2C%22excludeAxeCore%22%3Atrue%2C%22axeOptions%22%3A%7B%22iframes%22%3Afalse%2C%22reporter%22%3A%22v2%22%2C%22resultTypes%22%3A%5B%22violations%22%5D%2C%22rules%22%3A%7B%22duplicate-id%22%3A%7B%22enabled%22%3Afalse%7D%2C%22duplicate-id-active%22%3A%7B%22enabled%22%3Afalse%7D%2C%22duplicate-id-aria%22%3A%7B%22enabled%22%3Afalse%7D%7D%7D%7D%7D%2C%22ember-media-player%22%3A%7B%22lazyLoad%22%3Atrue%7D%2C%22ember-pem%22%3A%7B%22trackingTerminationLixKey%22%3A%22pem.degradation-tracking-kill-switch.voyager-web%22%7D%2C%22rootURL%22%3A%22%2F%22%2C%22routerRootURL%22%3A%22%2F%22%2C%22deviceFormFactor%22%3A%22DESKTOP%22%2C%22locationType%22%3A%22voyager-location%22%2C%22namespace%22%3A%22voyager%2Fapi%22%2C%22EmberENV%22%3A%7B%22FEATURES%22%3A%7B%7D%2C%22_JQUERY_INTEGRATION%22%3Afalse%2C%22_TEMPLATE_ONLY_GLIMMER_COMPONENTS%22%3Atrue%7D%2C%22APP%22%3A%7B%22locale%22%3A%22en_US%22%2C%22rumConfig%22%3A%7B%22pageKeyPrefix%22%3A%22d_%22%2C%22beacon-service%22%3A%22tracking%22%2C%22beacon-url%22%3A%22%2Fli%2Ftrack%22%2C%22event-name%22%3A%22RealUserMonitoringEvent%22%2C%22enable-cdn-tracking%22%3Atrue%2C%22enable-pop-tracking%22%3Atrue%2C%22user-timing-mark-enabled%22%3Atrue%7D%2C%22name%22%3A%22extended%22%2C%22version%22%3A%22voyager-web_1.6.76%2B59a42f39%22%7D%2C%22contentSecurityPolicy%22%3A%7B%22default-src%22%3A%22%5C%22none%5C%22%20*.licdn.com%20*.licdn-ei.com%22%2C%22script-src%22%3A%22%5C%22self%5C%22%20%5C%22unsafe-inline%5C%22%20*.licdn.com%20*.licdn-ei.com%20*.linkedin.com%22%2C%22font-src%22%3A%22%5C%22self%5C%22%20*.licdn.com%20*.licdn-ei.com%20*.slidesharecdn.com%22%2C%22frame-src%22%3A%22*.youtube.com%20*.slideshare.net%22%2C%22connect-src%22%3A%22%5C%22self%5C%22%20localhost%3A*%20*.linkedin.com%22%2C%22img-src%22%3A%22%5C%22self%5C%22%20*.slidesharecdn.com%20*.licdn.com%20*.licdn-ei.com%20spdy.linkedin.com%20spdy.linkedin-ei.com%20*.youtube.com%22%2C%22style-src%22%3A%22%5C%22self%5C%22%20%5C%22unsafe-inline%5C%22%20*.licdn.com%20*.licdn-ei.com%22%2C%22media-src%22%3A%22%5C%22self%5C%22%20*.slidesharecdn.com%20*.licdn.com%20*.licdn-ei.com%22%7D%2C%22tracking%22%3A%7B%22appId%22%3A%22com.linkedin.flagship3.d_web%22%2C%22pageKeyPrefix%22%3A%22d_%22%2C%22pveTrackingInfo%22%3A%7B%22osName%22%3A%22phone_web%22%7D%2C%22impression%22%3A%7B%22timeThreshold%22%3A300%2C%22percentageThreshold%22%3A50%2C%22viewportOffset%22%3A%7B%22top%22%3A52%2C%22bottom%22%3A0%2C%22left%22%3A0%2C%22right%22%3A0%7D%7D%2C%22comScore%22%3A%7B%22enabled%22%3Atrue%7D%7D%2C%22skeleton%22%3A%7B%22data%22%3A%7B%7D%2C%22template%22%3A%22.%2Fskeleton%2Floader.hbs%22%7D%2C%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets%2Fimg%2Fchina-icp-filing.png%22%2C%22assets%2Fimg%2Forganization%2Fdesktop-screenshot.png%22%2C%22assets%2Fimg%2Forganization%2Fmobile-screenshot.png%22%2C%22assets%2Fimg%2Fprofile%2Fdesktop-photo-upload-add-photo.png%22%2C%22assets%2Fhighcharts%2Fhighcharts.js%22%2C%22assets%2Fhighcharts%2Fmodules%2Fmap.js%22%2C%22assets%2Fhighcharts%2Fmodules%2Faccessibility.js%22%2C%22assets%2Fmedia-player%2Fmedia-player.amd.js%22%2C%22assets%2FcloudSDK%2FOneDriveSDK.js%22%2C%22assets%2FcloudSDK%2FDropboxSDK.js%22%2C%22assets%2Fproj4.js%22%2C%22assets%2Fspectroscopy-worker.js%22%2C%22assets%2Fworld.js%22%2C%22assets%2Fsrc%2Fchartbeat.js%22%2C%22assets%2Ffavicon.ico%22%2C%22assets%2Ffavicon-notification.ico%22%2C%22assets%2Fimg%2Fpremium%2Fproducts%2Fslides%2Fjob_seeker_featured_applicant_650x468_v1.png%22%2C%22assets%2Fimg%2Fpremium%2Fproducts%2Fslides%2Fjob_seeker_inmail_650x468_v1.png%22%2C%22assets%2Fimg%2Fpremium%2Fproducts%2Fslides%2Fjob_seeker_job_insights_650x468_v1.png%22%2C%22assets%2Fimg%2Fpremium%2Fproducts%2Fslides%2Fjob_seeker_professional_learning_650x468_v1.png%22%2C%22assets%2Fimg%2Fpremium%2Fproducts%2Fslides%2Fjob_seeker_professional_wvmp_650x468_v1.pn ...
# <!-- EMBER_CLI_FASTBOOT_TITLE --><!-- EMBER_CLI_FASTBOOT_HEAD -->
# <meta content="en_US" name="i18nDefaultLocale"/>
# <meta content="en_US" name="i18nLocale"/>
# <meta content="https://static-exp1.licdn.com/sc/h/br/aanly5o5blk5l977rvjksluux" name="i18nIntlPolyfillUrl"/>
# <meta content="ca" name="requestIpCountryCode"/>
# <meta content="urn:li:page:bpr;Ke0Z1nc9T06uziCV5TM6nA==" name="bprPageInstance"/>
# <meta content='{"applicationUrn": "urn:li:application:(voyager-web,voyager-web)", "version": "1.6.76", "trackingId": [112, 119, 102, 109, -95, -128, 64, -73, -72, 42, 7, -8, 91, 74, -99, 86]}' name="applicationInstance"/>
# <meta content="9BMTiTGiRc6IC8M5E2UgEA==" name="clientPageInstanceId"/>
# <meta content="voyager-web" name="service"/>
# <meta content="i001" name="serviceInstance"/>
# <meta content="1.6.76" name="serviceVersion"/>
# <link href="https://static-exp1.licdn.com/sc/h/1bt1uwq5akv756knzdj4l6cdc" id="favicon-ico" rel="shortcut icon"/>
# <link href="https://static-exp1.licdn.com/sc/h/2if24wp7oqlodqdlgei1n1520" rel="apple-touch-icon"/>
# <link href="https://static-exp1.licdn.com/sc/h/eahiplrwoq61f4uan012ia17i" rel="apple-touch-icon-precomposed"/>
# <link href="https://static-exp1.licdn.com/sc/h/2if24wp7oqlodqdlgei1n1520" rel="apple-touch-icon-precomposed" sizes="57x57"/>
# <link href="https://static-exp1.licdn.com/sc/h/eahiplrwoq61f4uan012ia17i" rel="apple-touch-icon-precomposed" sizes="144x144"/>
# <link href="https://static-exp1.licdn.com/sc/h/br/7jq8qpi30ei0hom7i0gwgy75n" rel="stylesheet"/>
# <link href="https://static-exp1.licdn.com/sc/h/br/dp5f9i4i2a7w20uj817c0gqo2" rel="stylesheet"/>
# <meta content='{"assets/img/china-icp-filing.png":"https://static-exp1.licdn.com/sc/h/cbn91jpp9vuid7olk3y6qmbpj","assets/img/organization/desktop-screenshot.png":"https://static-exp1.licdn.com/sc/h/ev2ewp91pnvtl0gcyt4xht0b5","assets/img/organization/mobile-screenshot.png":"https://static-exp1.licdn.com/sc/h/3v3wzhnr3kapuzwpk1zt6r1jt","assets/img/profile/desktop-photo-upload-add-photo.png":"https://static-exp1.licdn.com/sc/h/c5ybm82ti04zuasz2a0ubx7bu","assets/highcharts/highcharts.js":"https://static-exp1.licdn.com/sc/h/br/jbevef2eshsf90hs9udzeno3","assets/highcharts/modules/map.js":"https://static-exp1.licdn.com/sc/h/br/f0tjc5q9eq9sc2me2wuptv5ab","assets/highcharts/modules/accessibility.js":"https://static-exp1.licdn.com/sc/h/br/8gq9abeur2x3h4h1h0v7j79r7","assets/media-player/media-player.amd.js":"https://static-exp1.licdn.com/sc/h/br/334keakz3r1t5hi6rqvuigh4m","assets/cloudSDK/OneDriveSDK.js":"https://static-exp1.licdn.com/sc/h/br/45bhd02gokyndidefhx1ptdvt","assets/cloudSDK/DropboxSDK.js":"https://static-exp1.licdn.com/sc/h/br/874gdyhk2zgt1hdrm1rvxih7g","assets/proj4.js":"https://static-exp1.licdn.com/sc/h/br/a52rm6mz15bfb6b25ex2fl8mr","assets/spectroscopy-worker.js":"https://static-exp1.licdn.com/sc/h/br/69miyr75u4gp5utz4wgun9dya","assets/world.js":"https://static-exp1.licdn.com/sc/h/br/2s51vhg4vrr7k24sjaop3o56b","assets/src/chartbeat.js":"https://static-exp1.licdn.com/sc/h/br/dudi1lzgkt9xq5lg3f0j1c66p","assets/favicon.ico":"https://static-exp1.licdn.com/sc/h/al2o9zrvru7aqj8e1x2rzsrca","assets/favicon-notification.ico":"https://static-exp1.licdn.com/sc/h/1bt1uwq5akv756knzdj4l6cdc","assets/img/premium/products/slides/job_seeker_featured_applicant_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/6gl4ufmcgffyhuu4lti3us9mr","assets/img/premium/products/slides/job_seeker_inmail_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/194ufzr1ibusivbechyc149ox","assets/img/premium/products/slides/job_seeker_job_insights_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/b9qvh5p1l68rq61pvb6f3dpin","assets/img/premium/products/slides/job_seeker_professional_learning_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/75zb38b8070xlgfvx5ta8ksg5","assets/img/premium/products/slides/job_seeker_professional_wvmp_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/85swj4u5h27rp1gv0gtu5568","assets/img/premium/products/slides/job_seeker_resume_builder_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/b7ybzpxcq6ma06b6jrssqcu5v","assets/img/premium/products/slides/job_seeker_interview_prep_648x468_v1.png":"https://static-exp1.licdn.com/sc/h/dxj16dv0q0dlpveh17ftnocke","assets/img/premium/products/slides/professional_browse_profiles_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/1ehgbakjab9ljkoavygzhtoa3","assets/img/premium/products/slides/professional_company_research_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/2wxmom0vvkzhp4tfdd0cpa4ib","assets/img/premium/products/slides/professional_company_research_650x468_v2.png":"https://static-exp1.licdn.com/sc/h/5tigosoe1c6tonlu9psklh2f3","assets/img/premium/products/slides/professional_inmail_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/cwcgp1ebxedyejqr826bkpu8v","assets/img/premium/products/slides/recruiter_inmail_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/esjaplzg7oohpjabyq2xeelmi","assets/img/premium/products/slides/recruiter_manage_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/4odo71qtgrq2x8wcg0a99nv4y","assets/img/premium/products/slides/recruiter_recruiter_lite_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/6ivpnp1oew7noisonnlotdqyp","assets/img/premium/products/slides/recruiter_smart_search_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/aujac8303i9wxgcnnnv0jyxz4","assets/img/premium/products/slides/recruiter_stay_up_to_date_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/4yadosfw4e29dxz75juxmbupc","assets/img/premium/products/slides/recruiter_talent_pool_650x468_v1.png":"https://static-exp1.licdn.com/sc/h/5ahb8y31p2e05sym1y0fuwcn2","assets/img ...
# <meta content="none" name="liamOrLisa"/>
# <meta content='{"lix":{"voyager.web.jobs-search-continuum-phase1":{"testKey":"voyager.web.jobs-search-continuum-phase1","trackingInfo":null,"treatment":"enabled"},"voyager.web.feed.text-view-model-migration-sponsored":{"testKey":"voyager.web.feed.text-view-model-migration-sponsored","trackingInfo":null,"treatment":"control"},"voyager.web.nav.job-posting-jobs-led-entry-points":{"testKey":"voyager.web.nav.job-posting-jobs-led-entry-points","trackingInfo":null,"treatment":"control"},"voyager.search.web.right-rail-news-module":{"testKey":"voyager.search.web.right-rail-news-module","trackingInfo":null,"treatment":"enabled"},"voyager.web.premium-welcome-flow-opt-in-card":{"testKey":"voyager.web.premium-welcome-flow-opt-in-card","trackingInfo":null,"treatment":"control"},"voyager.iac.web.import-communities":{"testKey":"voyager.iac.web.import-communities","trackingInfo":null,"treatment":"control"},"voyager.web.groups-metadata":{"testKey":"voyager.web.groups-metadata","trackingInfo":null,"treatment":"control"},"voyager.web.organization-company-jobs-disable-job-alert":{"testKey":"voyager.web.organization-company-jobs-disable-job-alert","trackingInfo":null,"treatment":"control"},"voyager.web.profile-optimize-route-api":{"testKey":"voyager.web.profile-optimize-route-api","trackingInfo":null,"treatment":"enabled"},"voyager.web.mynetwork-client-sensor":{"testKey":"voyager.web.mynetwork-client-sensor","trackingInfo":null,"treatment":"enable"},"voyager.video.web.use-ember-media-player":{"testKey":"voyager.video.web.use-ember-media-player","trackingInfo":null,"treatment":"enabled"},"publishing.web.filtered-image-history":{"testKey":"publishing.web.filtered-image-history","trackingInfo":null,"treatment":"control"},"voyager.client.engage-omakase-minimum-refresh-interval":{"testKey":"voyager.client.engage-omakase-minimum-refresh-interval","trackingInfo":null,"treatment":"control"},"voyager.iac.web.group-abi-results":{"testKey":"voyager.iac.web.group-abi-results","trackingInfo":null,"treatment":"control"},"voyager.web.jobs-search-jymbii":{"testKey":"voyager.web.jobs-search-jymbii","trackingInfo":{"experimentId":2802817,"segmentIndex":1,"treatmentIndex":1,"urn":"urn:li:member:447754281"},"treatment":"enabled"},"voyager.video.web.settings-modal":{"testKey":"voyager.video.web.settings-modal","trackingInfo":null,"treatment":"captions"},"voyager.client.engage-revenue-palette-chevron":{"testKey":"voyager.client.engage-revenue-palette-chevron","trackingInfo":null,"treatment":"CHEVRON"},"voyager.web.premium.sales-nav-for-professionals-nav-identity-upsell":{"testKey":"voyager.web.premium.sales-nav-for-professionals-nav-identity-upsell","trackingInfo":null,"treatment":"control"},"voyager.client.engege-following-info-tracking-urn":{"testKey":"voyager.client.engege-following-info-tracking-urn","trackingInfo":null,"treatment":"enabled"},"voyager.web.search-enable-events-vertical":{"testKey":"voyager.web.search-enable-events-vertical","trackingInfo":null,"treatment":"control"},"voyager.web.jobs-search-get-salary-data":{"testKey":"voyager.web.jobs-search-get-salary-data","trackingInfo":null,"treatment":"control"},"voyager.client.engage-revenue-sponsored-commentary-line-count":{"testKey":"voyager.client.engage-revenue-sponsored-commentary-line-count","trackingInfo":{"experimentId":2802024,"segmentIndex":2,"treatmentIndex":1,"urn":"urn:li:member:447754281"},"treatment":"enabled"},"voyager.messaging.web.valhalla-send-message-requests":{"testKey":"voyager.messaging.web.valhalla-send-message-requests","trackingInfo":null,"treatment":"control"},"voyager.web.organization-admin-analytics-updates-table-filter":{"testKey":"voyager.web.organization-admin-analytics-updates-table-filter","trackingInfo":null,"treatment":"control"},"voyager.web.groups-promotions-experience":{"testKey":"voyager.web.groups-promotions-experience","trackingInfo":null,"treatment":"control"},"voyager.web.engage-use-update-token-expiry":{"testKey":"voyager.web.engage-use-update-token-expiry","trackin ...
# <meta content="false" name="isGuest"/>
# <meta data-mode="BIGPIPE" name="renderingMode"/>
# <meta content="12000" name="bigpipeResponseTimeout"/>
# <meta content="false" name="bigpipeJetRethrowError"/>
# <meta content='["static\\.licdn\\.com","media\\.licdn\\.com","voyager/api/typeahead/hits"]' name="bigpipeBlacklistUrls"/>
# <script src="https://static-exp1.licdn.com/sc/h/br/35ggkijo61ertszeggzb888kt"></script>
# <meta content="0ydxO/Kx9xXgJNjicCsAAA==" name="treeID"/>
# <meta content="%7B%7D" name="abi/config/environment"/>
# <meta content="%7B%7D" name="article-reader/config/environment"/>
# <meta content="%7B%7D" name="career-services/config/environment"/>
# <meta content="%7B%7D" name="colleagues/config/environment"/>
# <meta content="%7B%7D" name="company-creation/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="events/config/environment"/>
# <meta content="%7B%7D" name="feed/config/environment"/>
# <meta content="%7B%7D" name="feed-detail/config/environment"/>
# <meta content="%7B%7D" name="feed-shared/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="groups/config/environment"/>
# <meta content="%7B%7D" name="hiring/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="inshare/config/environment"/>
# <meta content="%7B%7D" name="interview-prep/config/environment"/>
# <meta content="%7B%7D" name="jobs/config/environment"/>
# <meta content="%7B%22googleAnalytics%22%3A%7B%22trackingId%22%3A%22UA-62256447-1%22%7D%7D" name="jobs-search/config/environment"/>
# <meta content="%7B%7D" name="lead-capture/config/environment"/>
# <meta content="%7B%7D" name="me/config/environment"/>
# <meta content="%7B%7D" name="me-ca/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="messaging/config/environment"/>
# <meta content="%7B%7D" name="msg-conversation-ui/config/environment"/>
# <meta content="%7B%7D" name="msg-mentions/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="msg-overlay/config/environment"/>
# <meta content="%7B%7D" name="msg-referrals/config/environment"/>
# <meta content="%7B%7D" name="msg-rich-media/config/environment"/>
# <meta content="%7B%7D" name="msg-shared-modals/config/environment"/>
# <meta content="%7B%7D" name="msg-spinmail/config/environment"/>
# <meta content="%7B%7D" name="msg-ui-base/config/environment"/>
# <meta content="%7B%7D" name="mynetwork/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="news/config/environment"/>
# <meta content="%7B%7D" name="notifications/config/environment"/>
# <meta content="%7B%7D" name="onboarding/config/environment"/>
# <meta content="%7B%7D" name="opportunities/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="organization/config/environment"/>
# <meta content="%7B%7D" name="organization-about/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="organization-admin/config/environment"/>
# <meta content="%7B%7D" name="organization-content-suggestions/config/environment"/>
# <meta content="%7B%7D" name="organization-employee-experience/config/environment"/>
# <meta content="%7B%7D" name="organization-insights/config/environment"/>
# <meta content="%7B%7D" name="organization-jobs/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="organization-life/config/environment"/>
# <meta content="%7B%7D" name="organization-people/config/environment"/>
# <meta content="%7B%7D" name="organization-salary/config/environment"/>
# <meta content="%7B%7D" name="participate-text-editor/config/environment"/>
# <meta content="%7B%7D" name="premium/config/environment"/>
# <meta content="%7B%7D" name="products/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="profile/config/environment"/>
# <meta content="%7B%22environment%22%3A%22production%22%2C%22ember-a11y-testing%22%3A%7B%22componentOptions%22%3A%7B%22turnAuditOff%22%3Atrue%2C%22excludeAxeCore%22%3Atrue%2C%22axeOptions%22%3A%7B%22iframes%22%3Afalse%2C%22reporter%22%3A%22v2%22%2C%22resultTypes%22%3A%5B%22violations%22%5D%2C%22rules%22%3A%7B%22duplicate-id%22%3A%7B%22enabled%22%3Afalse%7D%2C%22duplicate-id-active%22%3A%7B%22enabled%22%3Afalse%7D%2C%22duplicate-id-aria%22%3A%7B%22enabled%22%3Afalse%7D%7D%7D%7D%7D%7D" name="profile-edit/config/environment"/>
# <meta content="%7B%7D" name="profile-ge/config/environment"/>
# <meta content="%7B%7D" name="profile-opportunities/config/environment"/>
# <meta content="%7B%7D" name="profile-search-analytics/config/environment"/>
# <meta content="%7B%7D" name="profile-skill-assessments/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name="profile-subroutes/config/environment"/>
# <meta content="%7B%7D" name="publishing/config/environment"/>
# <meta content="%7B%7D" name="publishing-entity/config/environment"/>
# <meta content="%7B%7D" name="resume-builder/config/environment"/>
# <meta content="%7B%7D" name="salary/config/environment"/>
# <meta content="%7B%7D" name="search/config/environment"/>
# <meta content="%7B%7D" name="service-marketplace/config/environment"/>
# <meta content="%7B%7D" name="slideshare-migration/config/environment"/>
# <meta content="%7B%7D" name="tenor-gif/config/environment"/>
# <meta content="%7B%7D" name="unemployment/config/environment"/>
# <meta content="%7B%7D" name="video-engine/config/environment"/>
# <meta content="%7B%7D" name="workflow/config/environment"/>
# <meta content="https://static-exp1.licdn.com/sc/h/bnxja8vmi4065df2frq7k1f93" id="artdeco-icons/static/images/icons.svg" name="asset-url"/>
# <meta content='{"bundles":{"abi":{"assets":[{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/ajnk0kwt03rz4lrbc878rx48l"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/50saacujiio3i69qg3vaxjtqt"},{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/dclioxsxar82sn7f3j50obmqm"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/8c1g80pnofxue6ukzw1qu013a"}],"dependencies":[]},"article-reader":{"assets":[{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/zizf5pw7izv7u7uedjjzhkfu"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/d0eu3mq88f0wnpzq25qk7kyc2"},{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/6qcej9j6jvibqnz361vfb2yrq"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/f3ls67wb9vyg8aw9e4duywus3"}],"dependencies":["feed-shared"]},"career-services":{"assets":[{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/5vehy7clw0a7dfz3kr31o71xm"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/c4v2m3ithcyroi4ac3s3d0bz7"},{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/doh8ipytltb80ceg967ta4gr6"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/eo0bxgwk1e50ue8lulyigtzi4"}],"dependencies":[]},"colleagues":{"assets":[{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/6vergvdtpw8lk90glo9leelo0"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/6ap9b689uafoejsrhb4w2jcip"},{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/2eu5i4b5a96lak4mopcze5nzh"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/d9sv0z8a17v9dreyccx1got3o"}],"dependencies":[]},"company-creation":{"assets":[{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/9na4shtn1j1fkht940hb0c3lc"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/d46hs0whgnyopuxnip5nw69q6"},{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/5o9cwkhsv9k6mjqiulgs77w7k"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/4jtkxg49eac4cvpncoyum8ylc"}],"dependencies":[]},"content-analytics":{"assets":[],"dependencies":null},"events":{"assets":[{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/30u8r8q927m9ww1y1x1me5a4l"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/2n7y3jbtez8c4lfqxkla67bwv"},{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/ey1p4hso7dbkf3jyua1z5fi9f"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/c0vnzm7rrn79nbrsi87fj2kt8"},{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/2f19oce63tg0w0f22qye8gl6j"}],"dependencies":["feed-shared"]},"feed-detail":{"assets":[{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/4yvlrpwfhj8w6z8sac6wbpd4m"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/6yb5k5mqffluqk3gmfjx4cn3r"},{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/bkxxjel11717esclqllr62dvc"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/5fz44udcxg84ear3340ek7lkf"},{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/2f19oce63tg0w0f22qye8gl6j"}],"dependencies":["feed","feed-shared"]},"feed-shared":{"assets":[{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/fxkpwnmj3zcb7v1gnlgjupph"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/7f569hugwki0135foprbpxryt"},{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/7li028o0desv4foa4w26bxm3n"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/53flspyr2ml65dq3740iv5qvl"}],"dependencies":null},"feed":{"assets":[{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/2xul5qb4edogtel3v67498pgp"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/3mmysteg79pqps0ddrj4ywe5d"},{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/bpo2g0yquq5id700fibf1djen"},{"type":"css","uri":"https://static-exp1.licdn.com/sc/h/br/72bdj3nmbdyf4uxzypo7teg8m"},{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/2f19oce63tg0w0f22qye8gl6j"}],"dependencies":["feed-shared"]},"groups":{"assets":[{"type":"js","uri":"https://static-exp1.licdn.com/sc/h/br/qwf4iu1y386gzd ...
# <link href="https://static-exp1.licdn.com/sc/h/br/1mdizo9am7h6ycsosjpdz0t7d" rel="stylesheet"/><link href="https://static-exp1.licdn.com/sc/h/br/1lovmkc22luyzmcgu1d1gh6xn" rel="stylesheet"/><link href="https://static-exp1.licdn.com/sc/h/br/7f569hugwki0135foprbpxryt" rel="stylesheet"/><link href="https://static-exp1.licdn.com/sc/h/br/53flspyr2ml65dq3740iv5qvl" rel="stylesheet"/>
# <link class="lazy-css" href="https://static-exp1.licdn.com/sc/h/br/1pt13tts9vmrkijlchoxm2xwj" rel="stylesheet"/>
# <style></style>
# <meta content="app-id=288429040, affiliate-data=ct=campaign_vw_smart_app_banner&amp;pt=10746, app-argument=voyager://in/simran-gandhi-024593128/?trk=vw_smart_app_banner" name="apple-itunes-app"/>
# <script src="https://static-exp1.licdn.com/sc/h/br/eu4crmnigvud15fn1r2fumfg"></script><script src="https://static-exp1.licdn.com/sc/h/br/1p493ii4hg6u184qyskg0byph"></script><link href="https://static-exp1.licdn.com/sc/h/br/accx9ws6tuirfk68lf55ww5gy" rel="stylesheet"/><script src="https://static-exp1.licdn.com/sc/h/br/aexkyd94as4s53fidjk1hamm0"></script><link href="https://static-exp1.licdn.com/sc/h/br/4qdwr48a3lfs2wa9lfx4g0hpl" rel="stylesheet"/><script src="https://static-exp1.licdn.com/sc/h/br/7rqaem1ikrljrrapx3iy42546"></script><link href="https://static-exp1.licdn.com/sc/h/br/7uigw279w4h43vinrhbg17yvm" rel="stylesheet"/><script src="https://static-exp1.licdn.com/sc/h/br/coa7f3ykpl4n59lxspa6n42h5"></script><script src="https://static-exp1.licdn.com/sc/h/br/5fnrbz1ptw468s80bderimm7q"></script><link href="https://static-exp1.licdn.com/sc/h/br/776jkxo7nn0221j4smg14bag0" rel="stylesheet"/><script src="https://static-exp1.licdn.com/sc/h/br/6bk0douwgjr98f3yay49kpvq4"></script><link href="https://static-exp1.licdn.com/sc/h/br/oisemurpd12bcf2tn5q8ccms" rel="stylesheet"/><script src="https://static-exp1.licdn.com/sc/h/br/2a5fbk2wn2k05c0v2gn4mbans"></script><link href="https://static-exp1.licdn.com/sc/h/br/5qyvfidnyzpvux6kwlrng2jwh" rel="stylesheet"/><script src="https://static-exp1.licdn.com/sc/h/br/w35p6m7dgz0w31puf8g2811r"></script><link href="https://static-exp1.licdn.com/sc/h/br/6nzwg56buzd2sf2i9r16e1afa" rel="stylesheet"/><script src="https://static-exp1.licdn.com/sc/h/br/4ctrb4hx7ktqo13i9j9sci1cr"></script><link href="https://static-exp1.licdn.com/sc/h/br/2qcsvsrarcx20jnjnguliqn0d" rel="stylesheet"/></head>
# <body class="render-mode-BIGPIPE nav-v2 ember-application boot-complete icons-loaded" data-t-link-to-event-attached="true" dir="ltr">
# <!-- HUED-11420 -->
# <div id="artdeco-toasts__wormhole"> <section class="artdeco-toasts" id="artdeco-toasts">
# <header class="artdeco-toasts__header">
# <h2 class="artdeco-toasts__title">
#         0 notifications total
#       </h2>
# </header>
# <!-- -->
# <ul aria-atomic="true" aria-live="assertive" class="artdeco-toasts_toasts">
# <!-- --> </ul>
# </section>
# </div>
# <div id="a11y-menu"> <div>
# <div class="a11y-menu-container ember-view" id="ember12"><button class="mr4 artdeco-button artdeco-button--muted artdeco-button--2 artdeco-button--secondary ember-view" id="ember13"><!-- -->
# <span class="artdeco-button__text">
#     Skip to search
# </span></button>
# <a class="artdeco-button artdeco-button--muted artdeco-button--secondary" data-ember-action="" data-ember-action-14="14" href="#skip-link">
#   Skip to main content
# </a>
# <button class="a11y-menu__close artdeco-button artdeco-button--circle artdeco-button--muted artdeco-button--2 artdeco-button--tertiary ember-view" id="ember15"> <li-icon aria-hidden="true" class="artdeco-button__icon" type="cancel-icon"><svg data-supported-dps="24x24" fill="currentColor" focusable="false" height="24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M20 5.32L13.32 12 20 18.68 18.66 20 12 13.33 5.34 20 4 18.68 10.68 12 4 5.32 5.32 4 12 10.69 18.68 4z"></path>
# </svg></li-icon>
# <span class="artdeco-button__text">
#     Close jump menu
# </span></button>
# </div>
# </div>
# </div><header class="extended-nav nav-main-container global-alert-offset-top is-loading-nav" data-test-main-nav="" id="extended-nav" role="banner" style="display: block;" tabindex="-1"><div class="nav-main__content full-height display-flex align-items-center"><div class="nav-main__inbug-container"><div class="nav-item--inbug" id="inbug-nav-item" lang="en"><a class="nav-item__link js-nav-item-link" data-alias="" data-control-name="" data-link-to="feed" data-resource="feed/badge" href="/feed/"><span class="nav-item__icon nav-item__icon--inbug" lang="en" role="presentation"><li-icon aria-hidden="true" color="brand" size="34dp" type="linkedin-bug"><svg focusable="false" preserveaspectratio="xMinYMin meet" xmlns="http://www.w3.org/2000/svg"><g class="scaling-icon" style="fill-opacity: 1"><defs></defs><g class="bug-14dp" fill="none" fill-rule="evenodd" stroke="none" stroke-width="1"><g class="dp-1"><path class="bug-text-color" d="M14,1.25 L14,12.75 C14,13.44 13.44,14 12.75,14 L1.25,14 C0.56,14 0,13.44 0,12.75 L0,1.25 C0,0.56 0.56,0 1.25,0 L12.75,0 C13.44,0 14,0.56 14,1.25" fill="#FFFFFF"></path><path class="background" d="M14,1.25 L14,12.75 C14,13.44 13.44,14 12.75,14 L1.25,14 C0.56,14 0,13.44 0,12.75 L0,1.25 C0,0.56 0.56,0 1.25,0 L12.75,0 C13.44,0 14,0.56 14,1.25 Z M5,5 L6.85,5 L6.85,6.016 L6.893,6.016 C7.259,5.541 8.018,4.938 9.25,4.938 C11.125,4.938 12,5.808 12,8 L12,12 L10,12 L10,8.75 C10,7.313 9.672,6.875 8.632,6.875 C7.5,6.875 7,7.75 7,9 L7,12 L5,12 L5,5 Z M2,12 L4,12 L4,5 L2,5 L2,12 Z M4.335,3 C4.335,3.737 3.737,4.335 3,4.335 C2.263,4.335 1.665,3.737 1.665,3 C1.665,2.263 2.263,1.665 3,1.665 C3.737,1.665 4.335,2.263 4.335,3 Z" fill="#0073B2"></path></g><g class="dpi-gt1" transform="scale(0.2917)"><rect class="bug-text-color" fill="#FFFFFF" height="46" rx="4" width="46" x="1" y="1"></rect><path class="background" d="M0,4.00989318 C0,1.79529033 1.79405245,0 4.00989318,0 L43.9901068,0 C46.2047097,0 48,1.79405245 48,4.00989318 L48,43.9901068 C48,46.2047097 46.2059475,48 43.9901068,48 L4.00989318,48 C1.79529033,48 0,46.2059475 0,43.9901068 L0,4.00989318 Z M19,18.3 L25.5,18.3 L25.5,21.566 C26.437,19.688 28.838,18 32.445,18 C39.359,18 41,21.738 41,28.597 L41,41.3 L34,41.3 L34,30.159 C34,26.253 33.063,24.05 30.68,24.05 C27.375,24.05 26,26.425 26,30.159 L26,41.3 L19,41.3 L19,18.3 Z M7,41 L14,41 L14,18 L7,18 L7,41 Z M15,10.5 C15,12.985 12.985,15 10.5,15 C8.015,15 6,12.985 6,10.5 C6,8.015 8.015,6 10.5,6 C12.985,6 15,8.015 15,10.5 Z" fill="#0077B5"></path></g></g><g class="bug-21dp" fill="none" fill-rule="evenodd" stroke="none" stroke-width="1"><g class="dp-1"><path class="bug-text-color" d="M19.479,0 L1.583,0 C0.728,0 0,0.677 0,1.511 L0,19.488 C0,20.323 0.478,21 1.333,21 L19.229,21 C20.086,21 21,20.323 21,19.488 L21,1.511 C21,0.677 20.336,0 19.479,0" fill="#FFFFFF"></path><path class="background" d="M19.479,0 L1.583,0 C0.728,0 0,0.677 0,1.511 L0,19.488 C0,20.323 0.478,21 1.333,21 L19.229,21 C20.086,21 21,20.323 21,19.488 L21,1.511 C21,0.677 20.336,0 19.479,0 Z M8,8 L10.827,8 L10.827,9.441 L10.858,9.441 C11.289,8.664 12.562,7.875 14.136,7.875 C17.157,7.875 18,9.479 18,12.45 L18,18 L15,18 L15,12.997 C15,11.667 14.469,10.5 13.227,10.5 C11.719,10.5 11,11.521 11,13.197 L11,18 L8,18 L8,8 Z M3,18 L6,18 L6,8 L3,8 L3,18 Z M6.375,4.5 C6.375,5.536 5.536,6.375 4.5,6.375 C3.464,6.375 2.625,5.536 2.625,4.5 C2.625,3.464 3.464,2.625 4.5,2.625 C5.536,2.625 6.375,3.464 6.375,4.5 Z" fill="#0077B5"></path></g><g class="dpi-gt1" transform="scale(0.4375)"><rect class="bug-text-color" fill="#FFFFFF" height="46" rx="4" width="46" x="1" y="1"></rect><path class="background" d="M0,4.00989318 C0,1.79529033 1.79405245,0 4.00989318,0 L43.9901068,0 C46.2047097,0 48,1.79405245 48,4.00989318 L48,43.9901068 C48,46.2047097 46.2059475,48 43.9901068,48 L4.00989318,48 C1.79529033,48 0,46.2059475 0,43.9901068 L0,4.00989318 Z M19,18.3 L25.5,18.3 L25.5,21.566 C26.437,19.688 28.838,18 32.445,18 C39.359,18 41,21.738 41,28.597 L41,41.3 L34,41.3 L34,30.159 C34,26.253 33.063,24.05  ...
# <div class="search-global-typeahead ember-view" id="ember28"><div class="search-typeahead-v2 search-global-typeahead__typeahead ember-view" id="global-nav-typeahead"> <div class="ember-view" id="ember30"><input aria-activedescendant="" aria-autocomplete="list" aria-expanded="false" aria-label="Search" aria-owns="" class="search-global-typeahead__input always-show-placeholder" placeholder="Search" role="combobox" type="text"/></div>
# <!-- -->
# </div><div class="search-global-typeahead__controls">
# <button class="search-global-typeahead__button" data-control-name="nav.search_button" data-ember-action="" data-ember-action-31="31" tabindex="-1" type="button">
# <li-icon aria-label="i18n_search_button" class="search-global-typeahead__icon" role="img" size="medium" type="search-icon"><svg data-supported-dps="24x24" fill="currentColor" focusable="false" height="24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M21 19.67l-5.44-5.44a7 7 0 10-1.33 1.33L19.67 21zm-11-4.54A5.13 5.13 0 1115.13 10 5.13 5.13 0 0110 15.13z"></path>
# </svg></li-icon>
# </button>
# </div>
# <div class="ember-view" id="ember32"><!-- --></div>
# </div>
# </div>
# </div></div></form><nav aria-label="Primary" class="display-flex full-height" data-nav="main"><ul class="nav-main nav-container display-flex full-height"><li class="nav-item nav-item--feed" id="feed-nav-item" lang="en"><a class="nav-item__link nav-item__link--underline js-nav-item-link" data-alias="" data-control-name="" data-link-to="feed" data-resource="feed/badge" href="/feed/"><span class="nav-item__badge nav-item__badge--doughnut"><span aria-hidden="true" class="nav-item__badge-count">3</span><span class="visually-hidden">3</span></span><span class="nav-item__icon" id="feed-tab-icon" lang="en" role="presentation"><li-icon aria-hidden="true" color="true" type="nav-small-home-icon"><svg class="nav-icon" focusable="false" height="24px" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" xmlns="http://www.w3.org/2000/svg" y="0"><path class="active-item" d="M22,8.45L12.85,2.26a1.5,1.5,0,0,0-1.69,0L2,8.45,3.06,10,4,9.37V19a1,1,0,0,0,1,1h5V15h4v5h5a1,1,0,0,0,1-1V9.37L20.94,10Z" style="fill-opacity: 1"></path><path class="inactive-item" d="M22,9.45L12.85,3.26a1.5,1.5,0,0,0-1.69,0L2,9.45,3.06,11,4,10.37V20a1,1,0,0,0,1,1h6V16h2v5h6a1,1,0,0,0,1-1V10.37L20.94,11ZM18,19H15V15a1,1,0,0,0-1-1H10a1,1,0,0,0-1,1v4H6V8.89l6-4,6,4V19Z" style="fill: currentColor"></path></svg></li-icon></span><span class="nav-item__title">Home</span></a></li><li class="nav-item nav-item--mynetwork" id="mynetwork-nav-item" lang="en"><a class="nav-item__link nav-item__link--underline js-nav-item-link" data-alias="relationships" data-control-name="" data-link-to="mynetwork" data-resource="voyagerCommunicationsTabBadges" href="/mynetwork/"><span class="nav-item__icon" id="mynetwork-tab-icon" lang="en" role="presentation"><li-icon aria-hidden="true" color="true" type="nav-small-people-icon"><svg class="nav-icon" focusable="false" height="24px" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" xmlns="http://www.w3.org/2000/svg" y="0"><path class="active-item" d="M16,17.85V20a1,1,0,0,1-1,1H1a1,1,0,0,1-1-1V17.85a4,4,0,0,1,2.55-3.73l2.95-1.2V11.71l-0.73-1.3A6,6,0,0,1,4,7.47V6a4,4,0,0,1,4.39-4A4.12,4.12,0,0,1,12,6.21V7.47a6,6,0,0,1-.77,2.94l-0.73,1.3v1.21l2.95,1.2A4,4,0,0,1,16,17.85Zm4.75-3.65L19,13.53v-1a6,6,0,0,0,1-3.31V9a3,3,0,0,0-6,0V9.18a6,6,0,0,0,.61,2.58A3.61,3.61,0,0,0,16,13a3.62,3.62,0,0,1,2,3.24V21h4a1,1,0,0,0,1-1V17.47A3.5,3.5,0,0,0,20.75,14.2Z" style="fill-opacity: 1"></path><path class="inactive-item" d="M20.74,14.2L19,13.54V12.86l0.25-.41A5,5,0,0,0,20,9.82V9a3,3,0,0,0-6,0V9.82a5,5,0,0,0,.75,2.63L15,12.86v0.68l-1,.37a4,4,0,0,0-.58-0.28l-2.45-1V10.83A8,8,0,0,0,12,7V6A4,4,0,0,0,4,6V7a8,8,0,0,0,1,3.86v1.84l-2.45,1A4,4,0,0,0,0,17.35V20a1,1,0,0,0,1,1H22a1,1,0,0,0,1-1V17.47A3.5,3.5,0,0,0,20.74,14.2ZM16,8.75a1,1,0,0,1,2,0v1.44a3,3,0,0,1-.38,1.46l-0.33.6a0.25,0.25,0,0,1-.22.13H16.93a0.25,0.25,0,0,1-.22-0.13l-0.33-.6A3,3,0,0,1,16,10.19V8.75ZM6,5.85a2,2,0,0,1,4,0V7.28a6,6,0,0,1-.71,2.83L9,10.72a1,1,0,0,1-.88.53H7.92A1,1,0,0,1,7,10.72l-0.33-.61A6,6,0,0,1,6,7.28V5.85ZM14,19H2V17.25a2,2,0,0,1,1.26-1.86L7,13.92v-1a3,3,0,0,0,1,.18H8a3,3,0,0,0,1-.18v1l3.72,1.42A2,2,0,0,1,14,17.21V19Zm7,0H16V17.35a4,4,0,0,0-.55-2l1.05-.4V14.07a2,2,0,0,0,.4.05h0.2a2,2,0,0,0,.4-0.05v0.88l2.53,1a1.5,1.5,0,0,1,1,1.4V19Z" style="fill: currentColor"></path></svg></li-icon></span><span class="nav-item__title">My Network</span></a></li><li class="nav-item nav-item--jobs" id="jobs-nav-item" lang="en"><a class="nav-item__link nav-item__link--underline js-nav-item-link" data-alias="" data-control-name="" data-link-to="jobs" data-resource="" href="/jobs/"><span class="nav-item__icon" id="jobs-tab-icon" lang="en" role="presentation"><li-icon aria-hidden="true" color="true" type="nav-small-jobs-icon"><svg class="nav-icon" focusable="false" height="24px" preserveaspectratio="xMinYMin meet" viewbox="0 0 24 24" width="24px" x="0" xmlns="http://www.w3.org/2000/svg" y="0"><path class="active-item" d="M2,13H22v6a1,1,0,0,1-1,1H3a1,1,0,0,1-1-1V13ZM22,8v4H2V8A1,1,0, ...
# <div class="dropdown closed ember-view" id="nav-settings__dropdown"><button aria-controls="nav-settings__dropdown-options" aria-expanded="false" class="t-14 t-black--light t-bold nav-item__link dropdown-trigger ember-view" data-control-name="nav.settings" id="nav-settings__dropdown-trigger" type="button"> <img alt="Pavitrakumar Mohanty" class="nav-item__profile-member-photo nav-item__icon ember-view" height="24" id="ember25" src="https://media-exp1.licdn.com/dms/image/C5103AQEJglB-wun4xA/profile-displayphoto-shrink_100_100/0?e=1588204800&amp;v=beta&amp;t=I85_ggoCeHPnBiH8CQkSGNsuVDAiG2cpMTnGImcxPEY" width="24"/>
# <div class="nav-item__title-container">
# <span class="nav-item__title nav-item__dropdown-trigger--title">Me</span>
# <li-icon aria-hidden="true" class="nav-item__dropdown-trigger--icon" size="small" type="caret-filled-down-icon"><svg data-supported-dps="16x16" fill="currentColor" focusable="false" height="16" width="16" xmlns="http://www.w3.org/2000/svg">
# <path d="M8.8 10.66L14 5.12a.07.07 0 00-.07-.12H2.07a.07.07 0 00-.07.12l5.2 5.54a1.1 1.1 0 001.6 0z"></path>
# </svg></li-icon>
# </div>
# </button>
# <ul class="dropdown-options nav-settings__dropdown-options ember-view" id="nav-settings__dropdown-options" style="display: none;"><!-- --></ul>
# </div>
# </div>
# </li><li class="nav-item nav-item--app-launcher" id="app-launcher-nav-item"> <div class="nav-item__content">
# <div class="ember-view" id="ember19"><button class="nav-item__link nav-panel__trigger " data-control-name="nav.launcher" data-ember-action="" data-ember-action-20="20">
# <li-icon aria-label="Work icon" class="nav-item__icon" role="img" type="grid-icon"><svg data-supported-dps="24x24" fill="currentColor" focusable="false" height="24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M10 10h4v4h-4v-4zm0 11h4v-4h-4v4zm-7-7h4v-4H3v4zm0 7h4v-4H3v4zM3 7h4V3H3v4zm14 7h4v-4h-4v4zm0-11v4h4V3h-4zm-7 4h4V3h-4v4zm7 14h4v-4h-4v4z"></path>
# </svg></li-icon>
# <div class="nav-item__title-container">
# <span class="nav-item__title nav-item__dropdown-trigger--title">Work</span>
# <li-icon aria-hidden="true" class="nav-item__dropdown-trigger--icon" size="small" type="caret-filled-down-icon"><svg data-supported-dps="16x16" fill="currentColor" focusable="false" height="16" width="16" xmlns="http://www.w3.org/2000/svg">
# <path d="M8.8 10.66L14 5.12a.07.07 0 00-.07-.12H2.07a.07.07 0 00-.07.12l5.2 5.54a1.1 1.1 0 001.6 0z"></path>
# </svg></li-icon>
# </div>
# </button>
# <div class="ember-view" id="ember21"><!-- --></div></div> </div>
# </li><li class="nav-item nav-item--spotlight-one nav-item__spotlight" id="spotlight-one-nav-item">
# <div class="nav-item__wormhole">
# <a class="nav-item__link ember-view" href="https://www.linkedin.com/learning/?trk=nav_neptune_learning" id="ember17" rel="noopener noreferrer" tabindex="0" target="_blank"> <li-icon aria-hidden="true" class="nav-item__icon" type="learning-app-icon"><svg data-supported-dps="24x24" fill="currentColor" focusable="false" height="24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M22 5v14H2V5h20m1-2H1a1 1 0 00-1 1v16a1 1 0 001 1h22a1 1 0 001-1V4a1 1 0 00-1-1z"></path>
# <path d="M2 5v14h10V5H2zm8 12H4v-2h6v2zm0-4H4v-2h6v2zm0-4H4V7h6v2z" opacity=".25"></path>
# <path d="M14 7h6v2h-6zM14 11h6v2h-6zM14 15h6v2h-6z" opacity=".55"></path>
# <path d="M10 7.53v8.93a.28.28 0 00.44.23l6.43-4.44a.33.33 0 000-.52L10.44 7.3a.28.28 0 00-.44.23z"></path>
# </svg></li-icon>
# <span class="nav-item__title">Learning</span>
# </a>
# </div>
# </li></ul></nav></div></header>
# <!-- EMBER_CLI_FASTBOOT_BODY -->
# <script src="https://static-exp1.licdn.com/sc/h/br/1sjgqyf4rwm5ts07y4oqqouqa"></script>
# <script nomodule="" src="https://static-exp1.licdn.com/sc/h/br/52g70kyi3tjeiq5sddlwyb8vh"></script>
# <script src="https://static-exp1.licdn.com/sc/h/br/44lpm3xommt4uaobb0rsjjk0w"></script>
# <div class="app-boot-bg-skeleton" id="app-boot-bg-loader">
# <div class="top-bar"></div>
# <div class="content">
# <div class="initial-load-animation fade-load">
# <div class="linkedin-image">
# <li-icon aria-hidden="true" color="brand" size="48dp" type="linkedin-bug"><svg focusable="false" preserveaspectratio="xMinYMin meet" xmlns="http://www.w3.org/2000/svg"><g class="scaling-icon" style="fill-opacity: 1"><defs></defs><g class="bug-14dp" fill="none" fill-rule="evenodd" stroke="none" stroke-width="1"><g class="dp-1"><path class="bug-text-color" d="M14,1.25 L14,12.75 C14,13.44 13.44,14 12.75,14 L1.25,14 C0.56,14 0,13.44 0,12.75 L0,1.25 C0,0.56 0.56,0 1.25,0 L12.75,0 C13.44,0 14,0.56 14,1.25" fill="#FFFFFF"></path><path class="background" d="M14,1.25 L14,12.75 C14,13.44 13.44,14 12.75,14 L1.25,14 C0.56,14 0,13.44 0,12.75 L0,1.25 C0,0.56 0.56,0 1.25,0 L12.75,0 C13.44,0 14,0.56 14,1.25 Z M5,5 L6.85,5 L6.85,6.016 L6.893,6.016 C7.259,5.541 8.018,4.938 9.25,4.938 C11.125,4.938 12,5.808 12,8 L12,12 L10,12 L10,8.75 C10,7.313 9.672,6.875 8.632,6.875 C7.5,6.875 7,7.75 7,9 L7,12 L5,12 L5,5 Z M2,12 L4,12 L4,5 L2,5 L2,12 Z M4.335,3 C4.335,3.737 3.737,4.335 3,4.335 C2.263,4.335 1.665,3.737 1.665,3 C1.665,2.263 2.263,1.665 3,1.665 C3.737,1.665 4.335,2.263 4.335,3 Z" fill="#0073B2"></path></g><g class="dpi-gt1" transform="scale(0.2917)"><rect class="bug-text-color" fill="#FFFFFF" height="46" rx="4" width="46" x="1" y="1"></rect><path class="background" d="M0,4.00989318 C0,1.79529033 1.79405245,0 4.00989318,0 L43.9901068,0 C46.2047097,0 48,1.79405245 48,4.00989318 L48,43.9901068 C48,46.2047097 46.2059475,48 43.9901068,48 L4.00989318,48 C1.79529033,48 0,46.2059475 0,43.9901068 L0,4.00989318 Z M19,18.3 L25.5,18.3 L25.5,21.566 C26.437,19.688 28.838,18 32.445,18 C39.359,18 41,21.738 41,28.597 L41,41.3 L34,41.3 L34,30.159 C34,26.253 33.063,24.05 30.68,24.05 C27.375,24.05 26,26.425 26,30.159 L26,41.3 L19,41.3 L19,18.3 Z M7,41 L14,41 L14,18 L7,18 L7,41 Z M15,10.5 C15,12.985 12.985,15 10.5,15 C8.015,15 6,12.985 6,10.5 C6,8.015 8.015,6 10.5,6 C12.985,6 15,8.015 15,10.5 Z" fill="#0077B5"></path></g></g><g class="bug-21dp" fill="none" fill-rule="evenodd" stroke="none" stroke-width="1"><g class="dp-1"><path class="bug-text-color" d="M19.479,0 L1.583,0 C0.728,0 0,0.677 0,1.511 L0,19.488 C0,20.323 0.478,21 1.333,21 L19.229,21 C20.086,21 21,20.323 21,19.488 L21,1.511 C21,0.677 20.336,0 19.479,0" fill="#FFFFFF"></path><path class="background" d="M19.479,0 L1.583,0 C0.728,0 0,0.677 0,1.511 L0,19.488 C0,20.323 0.478,21 1.333,21 L19.229,21 C20.086,21 21,20.323 21,19.488 L21,1.511 C21,0.677 20.336,0 19.479,0 Z M8,8 L10.827,8 L10.827,9.441 L10.858,9.441 C11.289,8.664 12.562,7.875 14.136,7.875 C17.157,7.875 18,9.479 18,12.45 L18,18 L15,18 L15,12.997 C15,11.667 14.469,10.5 13.227,10.5 C11.719,10.5 11,11.521 11,13.197 L11,18 L8,18 L8,8 Z M3,18 L6,18 L6,8 L3,8 L3,18 Z M6.375,4.5 C6.375,5.536 5.536,6.375 4.5,6.375 C3.464,6.375 2.625,5.536 2.625,4.5 C2.625,3.464 3.464,2.625 4.5,2.625 C5.536,2.625 6.375,3.464 6.375,4.5 Z" fill="#0077B5"></path></g><g class="dpi-gt1" transform="scale(0.4375)"><rect class="bug-text-color" fill="#FFFFFF" height="46" rx="4" width="46" x="1" y="1"></rect><path class="background" d="M0,4.00989318 C0,1.79529033 1.79405245,0 4.00989318,0 L43.9901068,0 C46.2047097,0 48,1.79405245 48,4.00989318 L48,43.9901068 C48,46.2047097 46.2059475,48 43.9901068,48 L4.00989318,48 C1.79529033,48 0,46.2059475 0,43.9901068 L0,4.00989318 Z M19,18.3 L25.5,18.3 L25.5,21.566 C26.437,19.688 28.838,18 32.445,18 C39.359,18 41,21.738 41,28.597 L41,41.3 L34,41.3 L34,30.159 C34,26.253 33.063,24.05 30.68,24.05 C27.375,24.05 26,26.425 26,30.159 L26,41.3 L19,41.3 L19,18.3 Z M7,41 L14,41 L14,18 L7,18 L7,41 Z M15,10.5 C15,12.985 12.985,15 10.5,15 C8.015,15 6,12.985 6,10.5 C6,8.015 8.015,6 10.5,6 C12.985,6 15,8.015 15,10.5 Z" fill="#0077B5"></path></g></g><g class="bug-28dp" fill="none" fill-rule="evenodd" stroke="none" stroke-width="1"><g class="dp-1"><path class="bug-text-color" d="M25.375,0 L2.625,0 C1.175,0 0,1.175 0,2.625 L0,25.375 C0,26.825 1.175,28 2.625,28 L25.375,28 C26.825,28 28,26.825 28,25.375 L28,2.625 C28,1.175 26.825,0 25.375,0" fill="#FFFFFF"></path><path ...
# </div>
# <div class="loading-bar">
# <div class="blue-bar"></div>
# </div>
# </div>
# </div>
# </div>
# <script crossorigin="" src="https://static-exp1.licdn.com/sc/h/br/9sffows66bc78wcyu5rk58gkm"></script>
# <script crossorigin="" src="https://static-exp1.licdn.com/sc/h/br/5i61kwl4np2yop1pbfoskdaqr"></script>
# <script crossorigin="" src="https://static-exp1.licdn.com/sc/h/br/76qu0u7j2zbuo9uux4v4hax2s"></script>
# <script src="https://static-exp1.licdn.com/sc/h/br/7e5trnxie9nqiavmddyzor8ng"></script><script src="https://static-exp1.licdn.com/sc/h/br/2g2cj1wtzemdci9c3r3e2l7w"></script><script src="https://static-exp1.licdn.com/sc/h/br/2f19oce63tg0w0f22qye8gl6j"></script><script src="https://static-exp1.licdn.com/sc/h/br/fxkpwnmj3zcb7v1gnlgjupph"></script><script src="https://static-exp1.licdn.com/sc/h/br/7li028o0desv4foa4w26bxm3n"></script>
# <script crossorigin="" src="https://static-exp1.licdn.com/sc/h/br/cts34u690yuzxacptwibjaufx"></script>
# <div id="artdeco-modal-outlet"></div>
# <code id="bpr-guid-263463" style="display: none">
# ...
# </span>
# </p>
# </div>
# </div>
# <div class="msg-conversation-card__conversation-status fr pl2 align-items-center flex-grow-1">
# <!-- --><!-- --> </div>
# </div>
# </div>
# </div>
# </div>
# <div class="msg-overlay-list-bubble__convo-item--hoverable msg-overlay-list-bubble__convo-item ember-view" data-control-name="overlay.view_message" id="ember397" role="button" tabindex="0"><div class="msg-conversation-listitem__link msg-overlay-list-bubble__convo-item-link">
# <div class="msg-conversation-card msg-overlay-list-bubble__convo-card">
# <div class="msg-facepile-grid msg-facepile-grid--no-facepile msg-facepile-grid--small ember-view" id="ember399"> <img alt="LinkedIn Member" class="lazy-image msg-facepile-grid__img msg-facepile-grid__img--person ember-view" id="ember401" loading="lazy" src="https://media-exp1.licdn.com/dms/image/C560CAQE7c6xTJ3Gi1w/spinmail-customsender-displayphoto-shrink_100_100/0?e=1583017200&amp;v=beta&amp;t=fdywegPgwRjt6Rq22DRbejm8PfO-vgPVqy8b7SCFgq0"/>
# </div>
# <div class="msg-overlay-list-bubble__convo-card-content overflow-hidden">
# <div class="msg-overlay-list-bubble__convo-card-content-wrapper fl">
# <!-- --> <div class="msg-conversation-card__row">
# <h4 class="msg-conversation-listitem__participant-names msg-conversation-card__participant-names truncate t-14 t-black t-normal">
#               Cassie from LinkedIn Premium
#           </h4>
# </div>
# <div class="msg-conversation-card__row">
# <p class="msg-overlay-list-bubble__message-snippet msg-overlay-participant-headline m0 truncate t-12 t-black t-normal">
# <span class="ember-view" id="ember402">
# <span class="msg-conversation-card__pill t-14 t-black t-bold pr1">
#     LinkedIn Offer •
#   </span>
#   Your profile is getting hits
# </span>
# </p>
# </div>
# </div>
# <div class="msg-conversation-card__conversation-status fr pl2 align-items-center flex-grow-1">
# <!-- --><!-- --> </div>
# </div>
# </div>
# </div>
# </div>
# <div class="msg-overlay-list-bubble__convo-item--hoverable msg-overlay-list-bubble__convo-item ember-view" data-control-name="overlay.view_message" id="ember404" role="button" tabindex="0"><div class="msg-conversation-listitem__link msg-overlay-list-bubble__convo-item-link">
# <div class="msg-conversation-card msg-overlay-list-bubble__convo-card">
# <div class="presence-entity msg-conversation-card__presence-entity presence-entity--size-2 ember-view" id="ember406"><img alt="Anish Shah" class=" presence-entity__image EntityPhoto-circle-2 lazy-image ember-view" id="ember407" loading="lazy" src="https://media-exp1.licdn.com/dms/image/C5103AQGSYeZcSzC-qQ/profile-displayphoto-shrink_100_100/0?e=1588204800&amp;v=beta&amp;t=HKs8hpnwdY2ELXjdi3h-mey0nKORkxuSBFqkLF5gsAs" title="Anish Shah"/>
# <div class=" presence-entity__indicator presence-entity__indicator--size-2 presence-indicator presence-indicator--is-reachable presence-indicator--size-2 ember-view" id="ember408">
# <span class="visually-hidden">
#     Status is reachable
# </span></div></div>
# <div class="msg-overlay-list-bubble__convo-card-content overflow-hidden">
# <div class="msg-overlay-list-bubble__convo-card-content-wrapper fl">
# <!-- --> <div class="msg-conversation-card__row">
# <h4 class="msg-conversation-listitem__participant-names msg-conversation-card__participant-names truncate t-14 t-black t-normal">
#               Anish Shah
#                       </h4>
# </div>
# <div class="msg-conversation-card__row">
# <p class="msg-overlay-list-bubble__message-snippet msg-overlay-participant-headline m0 truncate t-12 t-black t-normal">
# <span class="ember-view" id="ember409">
# <span class="msg-conversation-card__message-snippet-body">
# <!-- -->      Anish: Loans and Credit Card
#
# manushree financial mall is a leading Loans and Credit Card distributer to help for your need of Loans and Credit card.
# we provide all type of loans like
# Personal Loan,
# Business Loan,
# Home Loan,
# Mortgage Loan,
#
#
# All bank Credit Cards like
#
# RBL bank Credit card,
# INDUSIND Bank C.card,
# ICICI Bank Credit card,
# HDFC Bank Credit card,
# YES Bank Credit card.
#
# On applying any product you get gift worth RS 1999/- on your credit card or loan approval.
# we provide 100% service and valuable gifts and offers to our valuable customer.
#
# Customer is a God for us and we always ready to provide best service to them
#
# Pls reply below mention link for apply any type of loan and credit card
#
# https://wa.me/919979487567
#
# 🙏Regards🙏
# Manushreeee financial mall
#       </span>
# </span>
# </p>
# </div>
# </div>
# <div class="msg-conversation-card__conversation-status fr pl2 align-items-center flex-grow-1">
# <!-- --><!-- --> </div>
# </div>
# </div>
# </div>
# </div>
# <div class="msg-overlay-list-bubble__convo-item--hoverable msg-overlay-list-bubble__convo-item ember-view" data-control-name="overlay.view_message" id="ember411" role="button" tabindex="0"><div class="msg-conversation-listitem__link msg-overlay-list-bubble__convo-item-link">
# <div class="msg-conversation-card msg-overlay-list-bubble__convo-card">
# <div class="msg-facepile-grid msg-facepile-grid--no-facepile msg-facepile-grid--small ember-view" id="ember413"> <img alt="LinkedIn Member" class="lazy-image msg-facepile-grid__img msg-facepile-grid__img--person ember-view" id="ember415" loading="lazy" src="https://media-exp1.licdn.com/dms/image/C560CAQEMTKy4pFZanQ/spinmail-customsender-displayphoto-shrink_100_100/0?e=1583017200&amp;v=beta&amp;t=AWwM_yKtU_LqKFP4vWIX_sBd_GaVEbDm_vevBopSuhI"/>
# </div>
# <div class="msg-overlay-list-bubble__convo-card-content overflow-hidden">
# <div class="msg-overlay-list-bubble__convo-card-content-wrapper fl">
# <!-- --> <div class="msg-conversation-card__row">
# <h4 class="msg-conversation-listitem__participant-names msg-conversation-card__participant-names truncate t-14 t-black t-normal">
#               Cassie from LinkedIn Premium
#           </h4>
# </div>
# <div class="msg-conversation-card__row">
# <p class="msg-overlay-list-bubble__message-snippet msg-overlay-participant-headline m0 truncate t-12 t-black t-normal">
# <span class="ember-view" id="ember416">
# <span class="msg-conversation-card__pill t-14 t-black t-bold pr1">
#     LinkedIn Offer •
#   </span>
#   Thanks for being an active member
# </span>
# </p>
# </div>
# </div>
# <div class="msg-conversation-card__conversation-status fr pl2 align-items-center flex-grow-1">
# <!-- --><!-- --> </div>
# </div>
# </div>
# </div>
# </div>
# <div class="msg-overlay-list-bubble__convo-item--hoverable msg-overlay-list-bubble__convo-item ember-view" data-control-name="overlay.view_message" id="ember418" role="button" tabindex="0"><div class="msg-conversation-listitem__link msg-overlay-list-bubble__convo-item-link">
# <div class="msg-conversation-card msg-overlay-list-bubble__convo-card">
# <div class="presence-entity msg-conversation-card__presence-entity presence-entity--size-2 ember-view" id="ember420"><img alt="Shalini Awasthi" class=" presence-entity__image EntityPhoto-circle-2 lazy-image ember-view" id="ember421" loading="lazy" src="https://media-exp1.licdn.com/dms/image/C5603AQE_2MoXRJ0gag/profile-displayphoto-shrink_100_100/0?e=1588204800&amp;v=beta&amp;t=2uQFFKd4G3cYXK6yN-UDYzQeH0kdqgCko_t5Q5AqKHo" title="Shalini Awasthi"/>
# <div class=" presence-entity__indicator presence-entity__indicator--size-2 presence-indicator hidden presence-indicator--size-2 ember-view" id="ember422">
# <span class="visually-hidden">
#     Status is offline
#   </span></div></div>
# <div class="msg-overlay-list-bubble__convo-card-content overflow-hidden">
# <div class="msg-overlay-list-bubble__convo-card-content-wrapper fl">
# <!-- --> <div class="msg-conversation-card__row">
# <h4 class="msg-conversation-listitem__participant-names msg-conversation-card__participant-names truncate t-14 t-black t-normal">
#               Shalini Awasthi
#                       </h4>
# </div>
# <div class="msg-conversation-card__row">
# <p class="msg-overlay-list-bubble__message-snippet msg-overlay-participant-headline m0 truncate t-12 t-black t-normal">
# <span class="ember-view" id="ember423">
# <span class="msg-conversation-card__message-snippet-body">
# <!-- -->      Shalini: Hello Pavitrakumar,
#
# If you are interested for studying abroad with the top world ranked universities in USA/UK/Canada/Ireland/Australia &amp; need assistance on admission requirement or application filing please feel free to share your number &amp; my team of specialist counselor will connect with you a.s.a.p.
#
# Regards,
# Shalini Awasthi
#       </span>
# </span>
# </p>
# </div>
# </div>
# <div class="msg-conversation-card__conversation-status fr pl2 align-items-center flex-grow-1">
# <!-- --><!-- --> </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- --> <div class="msg-overlay-list-bubble__loader hidden">
# <artdeco-loader class="artdeco-loader ember-view" id="ember424" size="small"><!-- --><span class="artdeco-spinner--bars"></span>
# <span class="artdeco-spinner--bars"></span>
# <span class="artdeco-spinner--bars"></span>
# <span class="artdeco-spinner--bars"></span>
# <span class="artdeco-spinner--bars"></span>
# <span class="artdeco-spinner--bars"></span>
# <span class="artdeco-spinner--bars"></span>
# <span class="artdeco-spinner--bars"></span>
# <span class="artdeco-spinner--bars"></span>
# <span class="artdeco-spinner--bars"></span>
# <span class="artdeco-spinner--bars"></span>
# <span class="artdeco-spinner--bars"></span></artdeco-loader>
# </div>
# </div>
# </section>
# <!-- --></div>
# <!-- --></aside>
# <img class="third-party-tracking-pixel hidden ember-view" id="ember131" src="https://px.ads.linkedin.com/collect/?pid=6883&amp;fmt=gif&amp;_t=1582929448362"/>
# </div>
# <div id="li-modal-container"></div>
# <div id="artdeco-hoverable-outlet"></div>
# <!-- -->
# <div class="ember-view" id="ember35"><div class="ember-view" id="ember36"><!-- --></div></div>
# <div class="entity-hovercard-container hidden ember-view" id="ember37"><div class="entity-hovercard p4" role="tooltip" tabindex="-1">
# <section class="entity-hovercard__loading-state">
#       Loading…
#     </section>
# </div>
# </div>
# <!-- -->
# <!-- -->
# <div class="type-ahead type-ahead-wormhole" id="type-ahead-wormhole">
# </div>
# <div class="toast-wormhole" id="toast-wormhole">
# </div>
# <!-- -->
# <div class="ember-view" id="ember38"><!-- --></div>
# </div>
# <code id="datalet-bpr-guid-263477" style="display: none">
#   {"request":"/voyager/api/identity/dash/profiles?q\u003DmemberIdentity\u0026memberIdentity\u003Dsimran-gandhi-024593128\u0026decorationId\u003Dcom.linkedin.voyager.dash.deco.identity.profile.FullProfileWithEntities-35","status":200,"body":"bpr-guid-263477","method":"GET"}
# </code>
# <img class="datalet-bpr-guid-263477" src="..." style="display: none"/><code id="bpr-guid-263479" style="display: none">
#   {"data":{"firstName":"Simran","lastName":"Gandhi","occupation":"District Lead | National Nutrition Mission | Ministry of Woman and Child Development | Bhopal","objectUrn":"urn:li:member:526969180","entityUrn":"urn:li:fs_miniProfile:ACoAAB9o6VwBR8M9LtXSXK00Z5JDO7C9WcoNU4E","backgroundImage":null,"publicIdentifier":"simran-gandhi-024593128","picture":{"artifacts":[{"width":100,"fileIdentifyingUrlPathSegment":"100_100/0?e=1588204800&amp;v=beta&amp;t=GrjaccFiP4HwQ2GYwEkGDHrIn4BSh1M5zzB5EMZqQFI","expiresAt":1588204800000,"height":100,"$type":"com.linkedin.common.VectorArtifact"},{"width":200,"fileIdentifyingUrlPathSegment":"200_200/0?e=1588204800&amp;v=beta&amp;t=wkupAO7R_dxvRnWju36Z54WJcuBtyw9tmTyBVsefouc","expiresAt":1588204800000,"height":200,"$type":"com.linkedin.common.VectorArtifact"},{"width":400,"fileIdentifyingUrlPathSegment":"400_400/0?e=1588204800&amp;v=beta&amp;t=4SShfqS_L_A-aK_RyZUv3Vq070nqCd8ZavPdoqP5yEg","expiresAt":1588204800000,"height":400,"$type":"com.linkedin.common.VectorArtifact"},{"width":800,"fileIdentifyingUrlPathSegment":"800_800/0?e=1588204800&amp;v=beta&amp;t=xiCErYaCHnu3eKVJGUqd5FPJpnJ8Ob5evKhJAMSIGkY","expiresAt":1588204800000,"height":800,"$type":"com.linkedin.common.VectorArtifact"}],"rootUrl":"https://media-exp1.licdn.com/dms/image/C5103AQGetQm2J_e_tQ/profile-displayphoto-shrink_","$type":"com.linkedin.common.VectorImage"},"trackingId":"Qebxl1OQRp6TsVDUkjwWsA==","$type":"com.linkedin.voyager.identity.shared.MiniProfile"},"included":[]}
# </code>
# <code id="datalet-bpr-guid-263479" style="display: none">
#   {"request":"/voyager/api/identity/miniprofiles/ACoAAB9o6VwBR8M9LtXSXK00Z5JDO7C9WcoNU4E","status":200,"body":"bpr-guid-263479","method":"GET"}
# </code>
# <img class="datalet-bpr-guid-263479" src="..." style="display: none"/><code id="bpr-guid-263480" style="display: none">
#   {"data":{"primaryExternalAction":null,"primaryAction":{"action":{"composeOption":{"icon":{"attributes":[{"sourceType":"ART_DECO_ICON","artDecoIcon":"IC_LOCK_24DP","$type":"com.linkedin.voyager.common.ImageAttribute"}],"accessibilityTextAttributes":[],"$type":"com.linkedin.voyager.common.ImageViewModel"},"displayText":{"textDirection":"USER_LOCALE","attributes":[],"text":"Message","$type":"com.linkedin.voyager.common.TextViewModel"},"composeOptionType":"UPSELL","textStartIcon":{"attributes":[{"sourceType":"ART_DECO_ICON","artDecoIcon":"IC_LOCK_24DP","$type":"com.linkedin.voyager.common.ImageAttribute"}],"accessibilityTextAttributes":[],"$type":"com.linkedin.voyager.common.ImageViewModel"},"targetUrl":"https://www.linkedin.com/premium/upsell?upsellOrderOrigin=PREMIUM_INMAIL_PROFILE_UPSELL_MODAL&amp;contextUrn=urn%3Ali%3Afs_profile%3A%28ACoAAB9o6VwBR8M9LtXSXK00Z5JDO7C9WcoNU4E%2Cen_US%29&amp;channel=INMAIL","$type":"com.linkedin.voyager.messaging.compose.ComposeOption"},"profileActionType":"COMPOSE_MESSAGE","$type":"com.linkedin.voyager.identity.profile.actions.GenericProfileAction"},"$type":"com.linkedin.voyager.identity.profile.actions.ProfileAction"},"entityUrn":"urn:li:fs_profileactions:ACoAAB9o6VwBR8M9LtXSXK00Z5JDO7C9WcoNU4E","secondaryAction":null,"overflowActions":[{"action":{"requestUrl":"https://www.linkedin.com/profile/pdf?id=ACoAAB9o6VwBR8M9LtXSXK00Z5JDO7C9WcoNU4E&amp;locale=en_US&amp;authType=name&amp;authToken=QC6o&amp;disablePdfCompression=true&amp;trk=pdf_pro_full","$type":"com.linkedin.voyager.identity.profile.actions.SaveToPdf"},"$type":"com.linkedin.voyager.identity.profile.actions.ProfileAction"},{"action":{"$type":"com.linkedin.voyager.identity.profile.actions.Follow"},"$type":"com.linkedin.voyager.identity.profile.actions.ProfileAction"},{"action":{"$type":"com.linkedin.voyager.identity.profile.actions.Connect"},"$type":"com.linkedin.voyager.identity.profile.actions.ProfileAction"},{"action":{"$type":"com.linkedin.voyager.identity.profile.actions.Report"},"$type":"com.linkedin.voyager.identity.profile.actions.ProfileAction"}],"actions":[],"$type":"com.linkedin.voyager.identity.profile.actions.ProfileActions"},"included":[]}
# </code>
# <code id="datalet-bpr-guid-263480" style="display: none">
#   {"request":"/voyager/api/identity/profiles/simran-gandhi-024593128/profileActions?contextType\u003DNON_SELF_PROFILE_VIEW\u0026profileActionTypes\u003DList(ACCEPT,BLOCK,BUILD_RESUME,CONNECT,DISCONNECT,FOLLOW,IGNORE,INVITATION_PENDING,PERSONALIZED_CONNECT,RECOMMEND,REPORT,REQUEST_RECOMMENDATION,SAVE_TO_PDF,SIGNUP,UNFOLLOW,VIEW_PROFILE_IN_RECRUITER,VIEW_PROFILE_IN_SALES_NAVIGATOR,APPRECIATE,COMPOSE_MESSAGE,ADD_TEAMMATE)","status":200,"body":"bpr-guid-263480","method":"GET"}
# </code>
# <img class="datalet-bpr-guid-263480" src="..." style="display: none"/><code id="bpr-guid-263481" style="display: none">
#   {"data":{"entityUrn":"urn:li:collectionResponse:6BQ2Hs4biNvdKcc3MR5iWuzJEcbXZY11NAFXg8+xJ3Q=","elements":[],"paging":{"count":10,"start":0,"links":[]},"$type":"com.linkedin.restli.common.CollectionResponse"},"included":[]}
# </code>
# <code id="datalet-bpr-guid-263481" style="display: none">
#   {"request":"/voyager/api/identity/profiles/simran-gandhi-024593128/opportunityCards?q\u003Dgoals","status":200,"body":"bpr-guid-263481","method":"GET"}
# </code>
# <img class="datalet-bpr-guid-263481" src="..." style="display: none"/><code id="clientPageInstance" style="display: none">
#   urn:li:page:d_flagship3_profile_view_base;PCOG95nkQDiyJzVWn+1IoQ==
# </code>
# <img class="terminatorlet" src="..." style="display: none"/>
# <div aria-live="polite" class="visually-hidden" id="a11y-notification" role="region"></div>
# </body></html>

# %%
name_div = soup.find('div', {'class': 'flex-1 mr5'})
name_div
# Out:
# <div class="flex-1 mr5">
# <ul class="pv-top-card--list inline-flex align-items-center">
# <li class="inline t-24 t-black t-normal break-words">
#             Simran Gandhi
#           </li>
# <li class="pv-top-card__distance-badge inline-block v-align-text-bottom t-16 t-black--light t-normal"><span class="distance-badge separator">
# <span class="visually-hidden">3rd degree connection</span><span aria-hidden="true" class="dist-value">3rd</span>
# </span></li>
# <li class="inline-flex ml2">
# <span class="pv-member-badge--for-top-card inline-flex pv-member-badge ember-view" id="ember87" style="display: none;"><!-- -->
# <!-- -->
# <span class="visually-hidden">
#   Simran has a  account
# </span>
# <!-- --></span>
# </li>
# </ul>
# <h2 class="mt1 t-18 t-black t-normal">
#             District Lead | National Nutrition Mission | Ministry of Woman and Child Development | Bhopal
#           </h2>
# <ul class="pv-top-card--list pv-top-card--list-bullet mt1">
# <li class="t-16 t-black t-normal inline-block">
#               Bhopal, Madhya Pradesh, India
#             </li>
# <!-- -->
# <li class="inline-block">
# <span class="t-16 t-black t-normal">
#                   147 connections
#                 </span>
# </li>
# <li class="inline-block">
# <a class="ember-view" data-control-name="contact_see_more" href="/in/simran-gandhi-024593128/detail/contact-info/" id="ember88"> <span class="t-16 t-bold">
#                 Contact info
#               </span>
# </a> </li>
# </ul>
# </div>

# %%
name_loc = name_div.find_all('ul')
name = name_loc[0].find('li').get_text().strip()
name
# Out:
# 'Simran Gandhi'

# %%
loc = name_loc[1].find('li').get_text().strip()
loc
# Out:
# 'Bhopal, Madhya Pradesh, India'

# %%
profile_title = name_div.find('h2').get_text().strip()
profile_title
# Out:
# 'District Lead | National Nutrition Mission | Ministry of Woman and Child Development | Bhopal'

# %%
connection = name_loc[1].find_all('li')
connection = connection[1].get_text().strip()
connection
# Out:
# '147 connections'

# %%
info = []
info.append(link)
info.append(name)
info.append(profile_title)
info.append(loc)
info.append(connection)
info
# Out:
# ['https://www.linkedin.com/in/simran-gandhi-024593128/',
#  'Simran Gandhi',
#  'District Lead | National Nutrition Mission | Ministry of Woman and Child Development | Bhopal',
#  'Bhopal, Madhya Pradesh, India',
#  '147 connections']

# %% [markdown]
# ### Experience

# %%
exp_section = soup.find('section', {'id': 'experience-section'})
exp_section
# Out:
# <section class="pv-profile-section experience-section ember-view" id="experience-section"><header class="pv-profile-section__card-header">
# <h2 class="pv-profile-section__card-heading">
#     Experience
#   </h2>
# <!-- --></header>
# <ul class="pv-profile-section__section-info section-info pv-profile-section__section-info--has-no-more">
# <li class="pv-entity__position-group-pager pv-profile-section__list-item ember-view" id="ember196"> <section class="pv-profile-section__card-item-v2 pv-profile-section pv-position-entity ember-view" id="1354467155"> <div class="display-flex justify-space-between full-width">
# <div class="display-flex flex-column full-width">
# <a class="full-width ember-view" data-control-name="background_details_company" href="/search/results/all/?keywords=National%20Nutrition%20Mission" id="ember199"> <div class="pv-entity__logo company-logo">
# <img alt="National Nutrition Mission" class="pv-entity__logo-img pv-entity__logo-img EntityPhoto-square-5 lazy-image ghost-company loaded ember-view" id="ember201" loading="lazy" src="..."/>
# </div>
# <div class="pv-entity__summary-info pv-entity__summary-info--background-section ">
# <h3 class="t-16 t-black t-bold">District Leader</h3>
# <p class="visually-hidden">Company Name</p>
# <p class="pv-entity__secondary-title t-14 t-black t-normal">National Nutrition Mission</p>
# <!-- -->
# <div class="display-flex">
# <h4 class="pv-entity__date-range t-14 t-black--light t-normal">
# <span class="visually-hidden">Dates Employed</span>
# <span>Jul 2018 – Present</span>
# </h4>
# <h4 class="t-14 t-black--light t-normal">
# <span class="visually-hidden">Employment Duration</span>
# <span class="pv-entity__bullet-item-v2">1 yr 8 mos</span>
# </h4>
# </div>
# <h4 class="pv-entity__location t-14 t-black--light t-normal block">
# <span class="visually-hidden">Location</span>
# <span>Bhopal Area, India</span>
# </h4>
# </div>
# </a>
# <!-- --> </div>
# <!-- --> </div>
# </section>
# </li><li class="pv-entity__position-group-pager pv-profile-section__list-item ember-view" id="ember204"> <section class="pv-profile-section__card-item-v2 pv-profile-section pv-position-entity ember-view" id="1212720528"> <div class="display-flex justify-space-between full-width">
# <div class="display-flex flex-column full-width">
# <a class="full-width ember-view" data-control-name="background_details_company" href="/search/results/all/?keywords=Ministry%20Of%20Drinking%20Water%20and%20Sanitation" id="ember207"> <div class="pv-entity__logo company-logo">
# <img alt="Ministry Of Drinking Water and Sanitation" class="pv-entity__logo-img pv-entity__logo-img EntityPhoto-square-5 lazy-image ghost-company loaded ember-view" id="ember209" loading="lazy" src="..."/>
# </div>
# <div class="pv-entity__summary-info pv-entity__summary-info--background-section mb2">
# <h3 class="t-16 t-black t-bold">Zila Swachh Bharat Prerak</h3>
# <p class="visually-hidden">Company Name</p>
# <p class="pv-entity__secondary-title t-14 t-black t-normal">Ministry Of Drinking Water and Sanitation</p>
# <!-- -->
# <div class="display-flex">
# <h4 class="pv-entity__date-range t-14 t-black--light t-normal">
# <span class="visually-hidden">Dates Employed</span>
# <span>May 2017 – May 2018</span>
# </h4>
# <h4 class="t-14 t-black--light t-normal">
# <span class="visually-hidden">Employment Duration</span>
# <span class="pv-entity__bullet-item-v2">1 yr 1 mo</span>
# </h4>
# </div>
# <h4 class="pv-entity__location t-14 t-black--light t-normal block">
# <span class="visually-hidden">Location</span>
# <span>Karauli Area, India</span>
# </h4>
# </div>
# </a>
# <div class="pv-entity__extra-details t-14 t-black--light ember-view" id="ember211"><p class="pv-entity__description t-14 t-black t-normal inline-show-more-text inline-show-more-text--is-collapsed ember-view" id="ember212" style="line-height:2rem;max-height:8rem;">The ZSBP is an initiative of the Ministry of Drinking Water and Saniation, Government of India (GoI) and Tata Trusts; to be implemented in collaboration with State Governments to provide coordination, management and monitoring support to the district administration for effective implementation of the Swach Bharat Mission (G).<br/>Key tasks in this regard are:<br/>(i) Develop District level Swachta Action, Finance, and Sustainability plan for SBM (G);<br/>(ii) Support in putting in place monitoring mechanism, quality supervision protocols<br/>(iii) Monitor, analyze and ensure updation of MIS data and support in developing decision support mechanism.
#
#     <span class="inline-show-more-text__link-container-collapsed">
# <span>…</span>
# <button aria-expanded="false" class="inline-show-more-text__button link" data-ember-action="" data-ember-action-236="236">
#         see more
#       </button>
# </span>
# <!-- --></p><!-- --></div>
# </div>
# <!-- --> </div>
# </section>
# </li><li class="pv-entity__position-group-pager pv-profile-section__list-item ember-view" id="ember214"> <section class="pv-profile-section__card-item-v2 pv-profile-section pv-position-entity ember-view" id="908525699"> <div class="display-flex justify-space-between full-width">
# <div class="display-flex flex-column full-width">
# <a class="full-width ember-view" data-control-name="background_details_company" href="/search/results/all/?keywords=smart%20city%20laundry%20(startup)" id="ember217"> <div class="pv-entity__logo company-logo">
# <img alt="smart city laundry (startup)" class="pv-entity__logo-img pv-entity__logo-img EntityPhoto-square-5 lazy-image ghost-company loaded ember-view" id="ember219" loading="lazy" src="..."/>
# </div>
# <div class="pv-entity__summary-info pv-entity__summary-info--background-section mb2">
# <h3 class="t-16 t-black t-bold">Co-Founder</h3>
# <p class="visually-hidden">Company Name</p>
# <p class="pv-entity__secondary-title t-14 t-black t-normal">smart city laundry (startup)</p>
# <!-- -->
# <div class="display-flex">
# <h4 class="pv-entity__date-range t-14 t-black--light t-normal">
# <span class="visually-hidden">Dates Employed</span>
# <span>Apr 2016 – Sep 2016</span>
# </h4>
# <h4 class="t-14 t-black--light t-normal">
# <span class="visually-hidden">Employment Duration</span>
# <span class="pv-entity__bullet-item-v2">6 mos</span>
# </h4>
# </div>
# <h4 class="pv-entity__location t-14 t-black--light t-normal block">
# <span class="visually-hidden">Location</span>
# <span>Indore, Madhya Pradesh, India</span>
# </h4>
# </div>
# </a>
# <div class="pv-entity__extra-details t-14 t-black--light ember-view" id="ember221"><p class="pv-entity__description t-14 t-black t-normal inline-show-more-text inline-show-more-text--is-collapsed ember-view" id="ember222" style="line-height:2rem;max-height:8rem;">Pre startup research works - Operations handling - Client handling - Business boosting and marketing
#
# <!-- --></p><!-- --></div>
# </div>
# <!-- --> </div>
# </section>
# </li> </ul>
# <!-- --></section>

# %%
exp_section = exp_section.find('ul')
exp_section
# Out:
# <ul class="pv-profile-section__section-info section-info pv-profile-section__section-info--has-no-more">
# <li class="pv-entity__position-group-pager pv-profile-section__list-item ember-view" id="ember196"> <section class="pv-profile-section__card-item-v2 pv-profile-section pv-position-entity ember-view" id="1354467155"> <div class="display-flex justify-space-between full-width">
# <div class="display-flex flex-column full-width">
# <a class="full-width ember-view" data-control-name="background_details_company" href="/search/results/all/?keywords=National%20Nutrition%20Mission" id="ember199"> <div class="pv-entity__logo company-logo">
# <img alt="National Nutrition Mission" class="pv-entity__logo-img pv-entity__logo-img EntityPhoto-square-5 lazy-image ghost-company loaded ember-view" id="ember201" loading="lazy" src="..."/>
# </div>
# <div class="pv-entity__summary-info pv-entity__summary-info--background-section ">
# <h3 class="t-16 t-black t-bold">District Leader</h3>
# <p class="visually-hidden">Company Name</p>
# <p class="pv-entity__secondary-title t-14 t-black t-normal">National Nutrition Mission</p>
# <!-- -->
# <div class="display-flex">
# <h4 class="pv-entity__date-range t-14 t-black--light t-normal">
# <span class="visually-hidden">Dates Employed</span>
# <span>Jul 2018 – Present</span>
# </h4>
# <h4 class="t-14 t-black--light t-normal">
# <span class="visually-hidden">Employment Duration</span>
# <span class="pv-entity__bullet-item-v2">1 yr 8 mos</span>
# </h4>
# </div>
# <h4 class="pv-entity__location t-14 t-black--light t-normal block">
# <span class="visually-hidden">Location</span>
# <span>Bhopal Area, India</span>
# </h4>
# </div>
# </a>
# <!-- --> </div>
# <!-- --> </div>
# </section>
# </li><li class="pv-entity__position-group-pager pv-profile-section__list-item ember-view" id="ember204"> <section class="pv-profile-section__card-item-v2 pv-profile-section pv-position-entity ember-view" id="1212720528"> <div class="display-flex justify-space-between full-width">
# <div class="display-flex flex-column full-width">
# <a class="full-width ember-view" data-control-name="background_details_company" href="/search/results/all/?keywords=Ministry%20Of%20Drinking%20Water%20and%20Sanitation" id="ember207"> <div class="pv-entity__logo company-logo">
# <img alt="Ministry Of Drinking Water and Sanitation" class="pv-entity__logo-img pv-entity__logo-img EntityPhoto-square-5 lazy-image ghost-company loaded ember-view" id="ember209" loading="lazy" src="..."/>
# </div>
# <div class="pv-entity__summary-info pv-entity__summary-info--background-section mb2">
# <h3 class="t-16 t-black t-bold">Zila Swachh Bharat Prerak</h3>
# <p class="visually-hidden">Company Name</p>
# <p class="pv-entity__secondary-title t-14 t-black t-normal">Ministry Of Drinking Water and Sanitation</p>
# <!-- -->
# <div class="display-flex">
# <h4 class="pv-entity__date-range t-14 t-black--light t-normal">
# <span class="visually-hidden">Dates Employed</span>
# <span>May 2017 – May 2018</span>
# </h4>
# <h4 class="t-14 t-black--light t-normal">
# <span class="visually-hidden">Employment Duration</span>
# <span class="pv-entity__bullet-item-v2">1 yr 1 mo</span>
# </h4>
# </div>
# <h4 class="pv-entity__location t-14 t-black--light t-normal block">
# <span class="visually-hidden">Location</span>
# <span>Karauli Area, India</span>
# </h4>
# </div>
# </a>
# <div class="pv-entity__extra-details t-14 t-black--light ember-view" id="ember211"><p class="pv-entity__description t-14 t-black t-normal inline-show-more-text inline-show-more-text--is-collapsed ember-view" id="ember212" style="line-height:2rem;max-height:8rem;">The ZSBP is an initiative of the Ministry of Drinking Water and Saniation, Government of India (GoI) and Tata Trusts; to be implemented in collaboration with State Governments to provide coordination, management and monitoring support to the district administration for effective implementation of the Swach Bharat Mission (G).<br/>Key tasks in this regard are:<br/>(i) Develop District level Swachta Action, Finance, and Sustainability plan for SBM (G);<br/>(ii) Support in putting in place monitoring mechanism, quality supervision protocols<br/>(iii) Monitor, analyze and ensure updation of MIS data and support in developing decision support mechanism.
#
#     <span class="inline-show-more-text__link-container-collapsed">
# <span>…</span>
# <button aria-expanded="false" class="inline-show-more-text__button link" data-ember-action="" data-ember-action-236="236">
#         see more
#       </button>
# </span>
# <!-- --></p><!-- --></div>
# </div>
# <!-- --> </div>
# </section>
# </li><li class="pv-entity__position-group-pager pv-profile-section__list-item ember-view" id="ember214"> <section class="pv-profile-section__card-item-v2 pv-profile-section pv-position-entity ember-view" id="908525699"> <div class="display-flex justify-space-between full-width">
# <div class="display-flex flex-column full-width">
# <a class="full-width ember-view" data-control-name="background_details_company" href="/search/results/all/?keywords=smart%20city%20laundry%20(startup)" id="ember217"> <div class="pv-entity__logo company-logo">
# <img alt="smart city laundry (startup)" class="pv-entity__logo-img pv-entity__logo-img EntityPhoto-square-5 lazy-image ghost-company loaded ember-view" id="ember219" loading="lazy" src="..."/>
# </div>
# <div class="pv-entity__summary-info pv-entity__summary-info--background-section mb2">
# <h3 class="t-16 t-black t-bold">Co-Founder</h3>
# <p class="visually-hidden">Company Name</p>
# <p class="pv-entity__secondary-title t-14 t-black t-normal">smart city laundry (startup)</p>
# <!-- -->
# <div class="display-flex">
# <h4 class="pv-entity__date-range t-14 t-black--light t-normal">
# <span class="visually-hidden">Dates Employed</span>
# <span>Apr 2016 – Sep 2016</span>
# </h4>
# <h4 class="t-14 t-black--light t-normal">
# <span class="visually-hidden">Employment Duration</span>
# <span class="pv-entity__bullet-item-v2">6 mos</span>
# </h4>
# </div>
# <h4 class="pv-entity__location t-14 t-black--light t-normal block">
# <span class="visually-hidden">Location</span>
# <span>Indore, Madhya Pradesh, India</span>
# </h4>
# </div>
# </a>
# <div class="pv-entity__extra-details t-14 t-black--light ember-view" id="ember221"><p class="pv-entity__description t-14 t-black t-normal inline-show-more-text inline-show-more-text--is-collapsed ember-view" id="ember222" style="line-height:2rem;max-height:8rem;">Pre startup research works - Operations handling - Client handling - Business boosting and marketing
#
# <!-- --></p><!-- --></div>
# </div>
# <!-- --> </div>
# </section>
# </li> </ul>

# %%
new_data=soup.find_all('h3',{'class':'t-16 t-black t-bold'})
new_data
# Out:
# [<h3 class="t-16 t-black t-bold">District Leader</h3>,
#  <h3 class="t-16 t-black t-bold">Zila Swachh Bharat Prerak</h3>,
#  <h3 class="t-16 t-black t-bold">Co-Founder</h3>]

# %%
li_tags = exp_section.find('div')
a_tags = li_tags.find('a')
a_tags
# Out:
# <a class="full-width ember-view" data-control-name="background_details_company" href="/search/results/all/?keywords=National%20Nutrition%20Mission" id="ember199"> <div class="pv-entity__logo company-logo">
# <img alt="National Nutrition Mission" class="pv-entity__logo-img pv-entity__logo-img EntityPhoto-square-5 lazy-image ghost-company loaded ember-view" id="ember201" loading="lazy" src="..."/>
# </div>
# <div class="pv-entity__summary-info pv-entity__summary-info--background-section ">
# <h3 class="t-16 t-black t-bold">District Leader</h3>
# <p class="visually-hidden">Company Name</p>
# <p class="pv-entity__secondary-title t-14 t-black t-normal">National Nutrition Mission</p>
# <!-- -->
# <div class="display-flex">
# <h4 class="pv-entity__date-range t-14 t-black--light t-normal">
# <span class="visually-hidden">Dates Employed</span>
# <span>Jul 2018 – Present</span>
# </h4>
# <h4 class="t-14 t-black--light t-normal">
# <span class="visually-hidden">Employment Duration</span>
# <span class="pv-entity__bullet-item-v2">1 yr 8 mos</span>
# </h4>
# </div>
# <h4 class="pv-entity__location t-14 t-black--light t-normal block">
# <span class="visually-hidden">Location</span>
# <span>Bhopal Area, India</span>
# </h4>
# </div>
# </a>

# %%
a_tags
# Out:
# <a class="full-width ember-view" data-control-name="background_details_company" href="/search/results/all/?keywords=National%20Nutrition%20Mission" id="ember199"> <div class="pv-entity__logo company-logo">
# <img alt="National Nutrition Mission" class="pv-entity__logo-img pv-entity__logo-img EntityPhoto-square-5 lazy-image ghost-company loaded ember-view" id="ember201" loading="lazy" src="..."/>
# </div>
# <div class="pv-entity__summary-info pv-entity__summary-info--background-section ">
# <h3 class="t-16 t-black t-bold">District Leader</h3>
# <p class="visually-hidden">Company Name</p>
# <p class="pv-entity__secondary-title t-14 t-black t-normal">National Nutrition Mission</p>
# <!-- -->
# <div class="display-flex">
# <h4 class="pv-entity__date-range t-14 t-black--light t-normal">
# <span class="visually-hidden">Dates Employed</span>
# <span>Jul 2018 – Present</span>
# </h4>
# <h4 class="t-14 t-black--light t-normal">
# <span class="visually-hidden">Employment Duration</span>
# <span class="pv-entity__bullet-item-v2">1 yr 8 mos</span>
# </h4>
# </div>
# <h4 class="pv-entity__location t-14 t-black--light t-normal block">
# <span class="visually-hidden">Location</span>
# <span>Bhopal Area, India</span>
# </h4>
# </div>
# </a>

# %%
job_title = a_tags.find('h3').get_text().strip()
job_title
# Out:
# 'District Leader'

# %%
company_name = a_tags.find_all('p')[1].get_text().strip()
company_name
# Out:
# 'National Nutrition Mission'

# %%
joining_date = a_tags.find_all('h4')[0].find_all('span')[1].get_text().strip()
joining_date
# Out:
# 'Jul 2018 – Present'

# %%
exp = a_tags.find_all('h4')[1].find_all('span')[1].get_text().strip()
exp
# Out:
# '1 yr 8 mos'

# %%
info
# Out:
# ['https://www.linkedin.com/in/simran-gandhi-024593128/',
#  'Simran Gandhi',
#  'District Lead | National Nutrition Mission | Ministry of Woman and Child Development | Bhopal',
#  'Bhopal, Madhya Pradesh, India',
#  '147 connections']

# %%
info.append(company_name)
info.append(job_title)
info.append(joining_date)
info.append(exp)

# %%
info
# Out:
# ['https://www.linkedin.com/in/simran-gandhi-024593128/',
#  'Simran Gandhi',
#  'District Lead | National Nutrition Mission | Ministry of Woman and Child Development | Bhopal',
#  'Bhopal, Madhya Pradesh, India',
#  '147 connections',
#  'National Nutrition Mission',
#  'District Leader',
#  'Jul 2018 – Present',
#  '1 yr 8 mos']

# %% [markdown]
# ### Education

# %%
edu_section = soup.find('section', {'id': 'education-section'}).find('ul')
edu_section
# Out:
# <ul class="pv-profile-section__section-info section-info pv-profile-section__section-info--has-no-more">
# <li class="pv-profile-section__list-item pv-education-entity pv-profile-section__card-item ember-view" id="361888760"><div class="display-flex justify-space-between full-width">
# <div class="display-flex flex-column full-width">
# <a class="ember-view" data-control-name="background_details_school" href="/search/results/all/?keywords=international%20institute%20of%20professional%20studies" id="ember227"> <div class="pv-entity__logo">
# <img alt="international institute of professional studies" class="pv-entity__logo-img pv-entity__logo-img EntityPhoto-square-4 lazy-image ghost-school loaded ember-view" id="ember229" loading="lazy" src="..."/>
# </div>
# <div class="pv-entity__summary-info pv-entity__summary-info--background-section">
# <div class="pv-entity__degree-info">
# <h3 class="pv-entity__school-name t-16 t-black t-bold">international institute of professional studies</h3>
# <p class="pv-entity__secondary-title pv-entity__degree-name t-14 t-black t-normal">
# <span class="visually-hidden">Degree Name</span>
# <span class="pv-entity__comma-item">5 year integrated course (BBA+MBA) </span>
# </p>
# <p class="pv-entity__secondary-title pv-entity__fos t-14 t-black t-normal">
# <span class="visually-hidden">Field Of Study</span>
# <span class="pv-entity__comma-item">Marketing</span>
# </p>
# <!-- --> </div>
# <p class="pv-entity__dates t-14 t-black--light t-normal">
# <span class="visually-hidden">Dates attended or expected graduation</span>
# <span>
# <time>2013</time> – <time>2017</time>
# </span>
# </p>
# <!-- --></div>
# </a>
# <div class="pv-entity__extra-details t-14 t-black--light ember-view" id="ember230"><p class="pv-entity__description t-14 t-normal mt4">
#   Good Academics, Member of cricket team, Second runner up in Annual Management and cultural fest
# </p>
# <!-- --></div>
# </div>
# <!-- --></div>
# </li>
# <li class="pv-profile-section__list-item pv-education-entity pv-profile-section__card-item ember-view" id="392301840"><div class="display-flex justify-space-between full-width">
# <div class="display-flex flex-column full-width">
# <a class="ember-view" data-control-name="background_details_school" href="/search/results/all/?keywords=swami%20vivekanand%20public%20school" id="ember233"> <div class="pv-entity__logo">
# <img alt="swami vivekanand public school" class="pv-entity__logo-img pv-entity__logo-img EntityPhoto-square-4 lazy-image ghost-school loaded ember-view" id="ember235" loading="lazy" src="..."/>
# </div>
# <div class="pv-entity__summary-info pv-entity__summary-info--background-section">
# <div class="pv-entity__degree-info">
# <h3 class="pv-entity__school-name t-16 t-black t-bold">swami vivekanand public school</h3>
# <p class="pv-entity__secondary-title pv-entity__degree-name t-14 t-black t-normal">
# <span class="visually-hidden">Degree Name</span>
# <span class="pv-entity__comma-item">high school</span>
# </p>
# <p class="pv-entity__secondary-title pv-entity__fos t-14 t-black t-normal">
# <span class="visually-hidden">Field Of Study</span>
# <span class="pv-entity__comma-item">commerce</span>
# </p>
# <!-- --> </div>
# <p class="pv-entity__dates t-14 t-black--light t-normal">
# <span class="visually-hidden">Dates attended or expected graduation</span>
# <span>
# <time>2011</time> – <time>2012</time>
# </span>
# </p>
# <p class="pv-entity__secondary-title t-14 t-black--light t-normal">
# <span class="activities-label">Activities and Societies:</span>
# <span class="activities-societies">Good Academics, School house captain, Anchore of school annual fest</span>
# </p>
# </div>
# </a>
# <!-- --> </div>
# <!-- --></div>
# </li>
# </ul>

# %%
college_name = edu_section.find('h3').get_text().strip()
college_name
# Out:
# 'international institute of professional studies'

# %%
degree_name = edu_section.find('p', {'class': 'pv-entity__secondary-title pv-entity__degree-name t-14 t-black t-normal'}).find_all('span')[1].get_text().strip()
degree_name
# Out:
# '5 year integrated course (BBA+MBA)'

# %%
stream = edu_section.find('p', {'class': 'pv-entity__secondary-title pv-entity__fos t-14 t-black t-normal'}).find_all('span')[1].get_text().strip()
stream
# Out:
# 'Marketing'

# %%
degree_year = edu_section.find('p', {'class': 'pv-entity__dates t-14 t-black--light t-normal'}).find_all('span')[1].get_text().strip()
degree_year
# Out:
# '2013 – 2017'

# %%
info
# Out:
# ['https://www.linkedin.com/in/simran-gandhi-024593128/',
#  'Simran Gandhi',
#  'District Lead | National Nutrition Mission | Ministry of Woman and Child Development | Bhopal',
#  'Bhopal, Madhya Pradesh, India',
#  '144 connections',
#  'National Nutrition Mission',
#  'District Leader',
#  'Jul 2018 – Present',
#  '1 yr 8 mos']

# %%
info.append(college_name)
info.append(degree_name)
info.append(stream)
info.append(degree_year)

# %%
info
# Out:
# ['https://www.linkedin.com/in/simran-gandhi-024593128/',
#  'Simran Gandhi',
#  'District Lead | National Nutrition Mission | Ministry of Woman and Child Development | Bhopal',
#  'Bhopal, Madhya Pradesh, India',
#  '144 connections',
#  'National Nutrition Mission',
#  'District Leader',
#  'Jul 2018 – Present',
#  '1 yr 8 mos',
#  'international institute of professional studies',
#  '5 year integrated course (BBA+MBA)',
#  'Marketing',
#  '2013 – 2017']
